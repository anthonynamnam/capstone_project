# %% [markdown]
# # Import Package

# %%
from google.colab import drive
drive.mount('/content/drive')

volatility_folder = "/content/drive/MyDrive/fyp/Final report/4. Backtesting/Volatility_result/"
backtest_summary_folder = volatility_folder + "backtest_summary/"
record_folder = volatility_folder + "trade_record/"
user_test_folder = volatility_folder + "user_test/"
model_folder = "/content/drive/MyDrive/fyp/Final report/4. Backtesting/VWAP_TWAP/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import floor

import torch.nn as nn
import os.path as osp
import torch.utils.data as data
import torch.nn.functional as F

from tqdm import tqdm
import time, matplotlib, torch, os
from statsmodels.tsa.arima_model import ARIMA
from torch.utils.tensorboard import SummaryWriter

# %%
import os
from os import walk

import plotly
# %matplotlib inline
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from datetime import datetime
#import seaborn as sns

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
#For DNN / CNN+LSTM
import keras.backend as K
from keras.models import Sequential
from keras.layers import Conv1D, LSTM, Flatten, Dense

# %%
# !pip install -q stockstats

# %% [markdown]
# # Backtesting Setting

# %%
start_date = []
num_period = 10
period_year = 1

start = 2022-(num_period+period_year-1)
for i in range(num_period):
    start_date.append((start+i)*10000+101)


date_range_list={}
for i in start_date:
    date_range_list[i] = (i-101)+(period_year-1)*10000+1231

print(date_range_list)

stock_list = {"BlockChain":["COIN","NVDA","FB"],
              "Airline":["BA","GD","LMT",],
              "Traveling":["UBER","ABNB","MAR","BKNG"],
              "Semiconductors":["INTC","NVDA","QCOM","MU","AMD"],
              "Cloud Computing":["IBM", "AMZN","GOOG","CRM"],
              "Social Media":["TWTR","SNAP","PINS","FB"],
              "Entertainment":["DIS","NFLX","FB"],
              "Retail":["WMT","COST","TGT","BBY","HD"],
              "Franchise":["MCD", "YUM", "SBUX", "DPZ"],
              "Real Estate":["HST", "EQR", "AVB", "PLD", "SPG"],
              "Telecommunication":["T","TMUS","VZ","CMCSA","CHTR"],
              "Energy & Resources":["DOW", "DD"],
              "Luxury goods":["RACE","EL","PVH"]
                            }

#stock_list = {"Entertainment":["DIS","NFLX","FB"]}

start_date = "2000-01-01"
end_date = "2022-12-31"


do_nth_name = "Buy&Hold"
model_name = "WithModel"

backtest_col = ["Sector","Stock",
                "Range_Start","Range_End",
                do_nth_name+"_Profit",model_name+"_Profit",
                do_nth_name+"_CAGR(in %)",model_name+"_CAGR(in %)",
                "CAGR_Performance(in %)",
                do_nth_name+"_MDD(in %)",model_name+"_MDD(in %)",
                "MDD_Performance(in %)"]
# Out:
# {20120101: 20121231, 20130101: 20131231, 20140101: 20141231, 20150101: 20151231, 20160101: 20161231, 20170101: 20171231, 20180101: 20181231, 20190101: 20191231, 20200101: 20201231, 20210101: 20211231}

# %% [markdown]
# # Backtesting Module

# %%
################### Input ##########################
# For hist_price_data: index=["date"], columns = ["Open"]
# For pred_action: index=["date"], columns = ["Action"] (Buy/Sell)
################### Output #########################
# 1. trading record
# 2. total profit
class backtest:
    hpd = "" # Historical Price Data
    pred_action=pd.DataFrame() # Prediction Action
    trade_record=pd.DataFrame(index=[], # Trading Record
                              columns=["Action","Price","Position","Cash","Pos_Bal","Cash_Bal","Cum_Profit","Total_Bal"],
                             )
    capital = 0
    cash_balance = 0
    profit = 0
    handle_fee = 0
    position = 0
    last_price = 0
    do_nth_profit = 0
    num_year = 0
    _tested = False
    
    _stock_trough = 0
    _stock_peak = 0
    _stock_all_time_low = 0
    _stock_all_time_high = 0
    
    _portfolio_trough = 0
    _portfolio_peak = 0
    _portfolio_all_time_low = 0
    _portfolio_all_time_high = 0
    
    def __init__(self,hist_price_data,pred_action,capital,handling_fee,num_year=1):
        self.hpd = hist_price_data
        self.pred_action = pred_action
        self.capital = capital
        self.cash_balance = capital
        self._portfolio_trough = capital
        self._portfolio_peak = capital
        self._portfolio_all_time_low = capital
        self._portfolio_all_time_high = capital
        self.handle_fee = handling_fee
        self.num_year = num_year  
        
    def clear_trade_record(self,sec):
        self.trade_record=pd.DataFrame(index=[],
                                       columns=["Action","Price","Position","Cash","Pos_Bal","Cash_Bal","Cum_Profit","Total_Bal"],
                                       )
        print("Clearing trade_record...")
        time.sleep(sec)
        
    def start_test(self): 
        if not self._tested:
            status = "sell"
            self._tested = True
            print("Start Backtesting...")  
            self._stock_all_time_low = self.hpd.iloc[0,0]
            self._stock_all_time_high = self.hpd.iloc[0,0]
            self._stock_trough = self.hpd.iloc[0,0]
            self._stock_peak = self.hpd.iloc[0,0]
            
            # For loop to iterate the data
            for ind in self.pred_action.index:
                # Update latest price
                self.last_price = self.hpd.loc[ind,"Open"]
                
                # Mark All Time Low,High , Trough and Peak for MDD of stock price (using "Buy&Hold")
                if self.last_price > self._stock_all_time_high:
                    self._stock_all_time_high = self.last_price
                if self.last_price < self._stock_all_time_low:
                    self._stock_all_time_low = self.last_price
                if self.last_price > self._stock_all_time_low and self._stock_trough != self._stock_all_time_low:
                    self._stock_trough = self._stock_all_time_low
                if self.last_price < self._stock_all_time_high and self._stock_peak != self._stock_all_time_high:
                    self._stock_peak = self._stock_all_time_high
                
                # Do the action
                if self.pred_action.loc[ind,"Action"].lower() == "buy" and status == "sell":
                    self._buy(ind,self.last_price)
                    status = "buy"
                elif self.pred_action.loc[ind,"Action"].lower() == "sell" and status == "buy":
                    self._sell(ind,self.last_price)
                    status = "sell"
                else:
                    self._hold(ind,self.last_price) # newly added
                    
                
                curr_portfolio_val = self.get_capital()+self.get_profit()
                
                # Mark All Time Low,High , Trough and Peak for MDD of our portfolio balance (using our model)
                if curr_portfolio_val > self._portfolio_all_time_high:
                    self._portfolio_all_time_high = curr_portfolio_val
                if curr_portfolio_val < self._portfolio_all_time_low:
                    self._portfolio_all_time_low = curr_portfolio_val
                if curr_portfolio_val > self._portfolio_all_time_low and self._portfolio_trough != self._portfolio_all_time_low:
                    self._portfolio_trough = self._portfolio_all_time_low
                if curr_portfolio_val < self._portfolio_all_time_high and self._portfolio_peak != self._portfolio_all_time_high:
                    self._portfolio_peak = self._portfolio_all_time_high
                            
            # =================================================
            self._run_do_nothing() # Calculate do nothing profit
        else:
            print("Backtesting has been completed...")
              
                
        
    def _mark_down_record(self,date,action,price,pos_delta,cash_delta):
        self.trade_record.loc[date] = [action,price,pos_delta,cash_delta,
                                       round(self.position,4),round(self.cash_balance,3),
                                       round(self.get_profit(),3),round(self.get_amount(),3)]
        
    def _buy(self,date,price):
        # Assume use all money to buy all
        buy_pos = floor(self.cash_balance / price)
        for i in range(buy_pos+1):
            act_buy_pos = buy_pos - i
            if act_buy_pos == 0:
                #print("You do not have enough money to buy!")
                return
            total_amt = act_buy_pos*price*(1+self.handle_fee)
            if self.cash_balance > total_amt:
                self.position += act_buy_pos
                self.cash_balance -= total_amt
                self._mark_down_record(date,
                                       "Buy",
                                       price,
                                       act_buy_pos,
                                       -total_amt)
                print("Bought at",date,"with price =", price, "\tPos:", act_buy_pos)
                return
        
    
    def _sell(self,date,price):
        # Assume sell all position
        sell_pos = self.position
        total_amt = sell_pos*price*(1-self.handle_fee)
        if self.position >= 1:
            self.position -= sell_pos
            self.cash_balance += total_amt
            self._mark_down_record(date,
                                   "Sell",
                                   price,
                                   -sell_pos,
                                   total_amt)
            print("Sold at",date,"with price =", price, "\tPos:", sell_pos)
            
            return
        
    def _hold(self,date,price): # newly added
        self._mark_down_record(date,"Hold",price,0,0)

    def _run_do_nothing(self):
        balance = self.capital
        first_day_price = self.hpd.iloc[0,0]
        last_day_price = self.hpd.iloc[-1,0]
        buy_pos = floor(self.capital / first_day_price) # Calculate how many position can buy
        total_amt = buy_pos*first_day_price*(1+self.handle_fee) # Check if okay to buy (including fee)
        while self.capital < total_amt: # If not enough, reduce buy_pos by 1
            buy_pos -= 1
            total_amt = buy_pos*first_day_price*(1+self.handle_fee)
        position = buy_pos # Buy in 
        balance -= total_amt
        self.do_nth_profit = last_day_price*position+balance-self.capital

    def get_performance(self):
        if self._tested:
            model_profit = self.get_profit()
            do_nth_profit = self.get_do_nothing()
            perf = (model_profit-do_nth_profit)/abs(do_nth_profit)
            return perf
        else:
            print("No Backtesting Record.")

    def get_do_nothing(self):
        if self._tested:
            return self.do_nth_profit
        else:
            print("No Backtesting Record.")

    def get_profit(self):
        if self._tested:
            return self.get_cash_balance()+self.get_last_price()*self.get_position()-self.get_capital()
        else:
            print("No Backtesting Record.")

    def get_last_price(self):
        if self._tested:
            return self.last_price
        else:
            print("No Backtesting Record.")
    
    def get_position(self):
        if self._tested:
            return self.position
        else:
            print("No Backtesting Record.")
    
    def get_do_nothing_CAGR(self):
        if self._tested:
            start_bal = self.get_capital()
            end_bal = self.get_do_nothing()+self.get_capital()
            num_year = self.get_num_year()
            return pow(end_bal/start_bal,1/num_year)-1
        else:
            print("No Backtesting Record.")
            
    def get_model_CAGR(self):
        if self._tested:
            start_bal = self.get_capital()
            end_bal = self.get_profit()+self.get_capital()
            num_year = self.get_num_year()
            return pow(end_bal/start_bal,1/num_year)-1
        else:
            print("No Backtesting Record.")
            
    def get_diff_in_CAGR(self):
        if self._tested:
            return self.get_model_CAGR() - self.get_do_nothing_CAGR()
        else:
            print("No Backtesting Record.")
    
    def get_do_nothing_MDD(self):
        if self._tested:
            return (self._stock_trough-self._stock_peak)/self._stock_peak
        else:
            print("No Backtesting Record.")
            
    def get_model_MDD(self):
        if self._tested:
            return (self._portfolio_trough-self._portfolio_peak)/self._portfolio_peak
        else:
            print("No Backtesting Record.")
            
    def get_diff_in_MDD(self):
        if self._tested:
            return self.get_model_MDD() - self.get_do_nothing_MDD()
        else:
            print("No Backtesting Record.")
    
    def get_num_year(self):
        return self.num_year
    
    def get_cash_balance(self):
        return self.cash_balance
    
    def get_capital(self):
        return self.capital
    
    def get_amount(self):
        return self.get_capital()+self.get_profit()

    def print_do_nothing(self):
        if self._tested:
            print("If buy at", self.hpd.index[0],"with price =",self.hpd.iloc[0,0])
            print("and do nothing")
            print("Current Profit:",self.get_do_nothing())
        else:
            print("No Backtesting Record.")
            
    def print_performance(self):
        if self._tested:
            print("Performance:", str(round(self.get_performance()*100,2))+"%")
        else:
            print("No Backtesting Record.")
            
    def print_CAGR_performance(self):
        if self._tested:
            print("CAGR Performance:", str(round(self.get_diff_in_CAGR()*100,2))+"%")
        else:
            print("No Backtesting Record.")
    
    def print_trade_record(self):
        if self._tested:
            print(self.trade_record)
        else:
            print("No Backtesting Record.")
            print(self.trade_record)
    
    def print_profit(self):
        if self._tested:
            print("Current Profit with model:",self.get_profit())
        else:
            print("No Backtesting Record.")
    
    def export_trade_record(self,stock,add_msg = ""):
        if self._tested:
            # Save the trade record to the path
            if not add_msg == "":
                add_msg = "_" + add_msg
            self.trade_record = self.trade_record.sort_index()
            self.trade_record.to_csv(record_folder+stock+add_msg+".csv")
            print("Trade record exported.")
        else:
            print("No Backtesting Record.")

# %% [markdown]
# # Processing Function

# %%
# Split the train and test data
def custom_split(data,start,end):
    train = (data.index >= start) & (data.index <= end)
    train_X = data[train]
    
    return train_X

# %%
# Assume we use 10 days price data to predict closing price of the 11th day
num_day_to_predict = 5

# %%
def produce_result_target_price(X,num_day = 5,result_col_name = "result_price"):
    y = pd.DataFrame(np.nan, index=X.index, columns=[result_col_name])
    for i in range(5,len(X)):
        y.loc[X.index[i-1],result_col_name] = X.loc[X.index[i],"open"]
    
    return y

# %%
def transform_x_data_to_one_vector(X,num_day):
    col_name = []
    for i in range(num_day):
        for j in X.columns:
            col_name.append(j+"-"+str(i))
    new_X = pd.DataFrame(np.nan, index=X.index, columns=col_name)
    
    for i in range(num_day-1,len(X)):
        for col in col_name:
            split_list = col.split("-")
            new_X.loc[X.index[i],col] = X.loc[X.index[i-int(split_list[1])],split_list[0]]
    
    return new_X

# %%
def drop_nan_row_y(y,num_day = 5):
    drop_list = [y.index[i] for i in range(num_day-1)]
    drop_list.append(y.index[-1])
    return y.drop(drop_list)

def drop_nan_row_X_5(X,num_day = 5):
    drop_list = [X.index[i] for i in range(num_day-1)]
    drop_list.append(X.index[-1])
    return X.drop(drop_list)

# %%
def normalize_data_by_row(X,y):
    norm_X = X.sub(X.mean(axis=0), axis=1).div(X.std(axis=0), axis=1)
    
    col_list =[] 
    for col in X.columns:
        if "open" in col:
            col_list.append(col)
    
    temp_y = y.loc[:,"result_price"]
    mean_5_day = np.mean(X.loc[:,col_list],axis=1)
    mean_5_day.index = temp_y.index
    std_5_day = np.std(X.loc[:,col_list],axis=1)
    std_5_day.index = temp_y.index
    

    norm_y = pd.DataFrame((temp_y-mean_5_day)/std_5_day,
                          columns=["result_price"])
                         
    return (norm_X,norm_y)

# %%
def convert_prediction(X,y,pred):

    col_list =[] 
    for col in X.columns:
        if "open" in col:
            col_list.append(col)
    mean_5_day = np.mean(X.loc[:,col_list],axis=1)
    mean_5_day.index = y.index
    std_5_day = np.std(X.loc[:,col_list],axis=1)
    std_5_day.index = y.index
    a = pd.DataFrame(index = y.index,columns=['mean','std','pred'])
    a.loc[:,"mean"] = mean_5_day
    a.loc[:,"std"] = std_5_day
    a.loc[:,"pred"] = pred
    a.loc[:,"converted"] = pred*std_5_day+mean_5_day
    return a["converted"]

# %%
def convert_decision(stock_,pred):
    h = np.array(pred)
    action = []
    status = "N"
    five_sma = stock_['open'].rolling(window=5,min_periods=1).mean()

    ind_sma = five_sma.index
    ind_pred = pred.index
    union_ind = list(ind_sma.intersection(ind_pred))

    five_sma = five_sma.filter(items = union_ind)
    pred = pred.filter(items = union_ind)

    for i in range(len(union_ind)):

        if pred.iloc[i] >= five_sma.iloc[i]:
            if status == "N":
                action.append("Buy")
                status = "Buy"
            else:
                action.append("Hold")
        else:
            if status == "Buy":
                action.append("Sell")
                status = "N"
            else:
                action.append("Hold")

    result = (pd.DataFrame(action,
                         columns=["Action"], index = pred.index))
                
    return result

# %%
def get_last_n_day_mean(df,n):
    series = df["open"]
    windows = series.rolling(n)
    n_days_averages = windows.mean()
    n_days_list = n_days_averages.tolist()
    final_list = n_days_list[n:]
    new_df = pd.DataFrame(final_list,columns=["mean_"+str(n)],index=df.index[n:])
    return new_df

# %% [markdown]
# # Load Model

# %%
with open(model_folder+"TWAP.pickle", "rb") as f:
    twap_test = pickle.load(f)

# %% [markdown]
# # Backtesting for TWAP

# %%
import os

file_list = list(filter(lambda name: "TWAP_" in name ,os.listdir(record_folder)))
if len(file_list) == 0:
  print("No such files...")
else:
  for f in file_list:
    print(file_list)
    os.remove(record_folder+f)
  print("All old files deleted...")
# Out:
# No such files...

# %%
#### TWAP Backtest
backtest_summary = pd.DataFrame(columns=backtest_col)

for sector, stocks in stock_list.items():
    for stock in stocks:
        print("Runninng stock: "+ stock)
        stock_data_1 = web.DataReader(stock, "stooq",start=start_date, end=end_date)
        stock_data_1.columns = ["open","high","low","close","volume"]
        x_1 = StockDataFrame(stock_data_1)
        print("entire dataset",len(x_1))
        data_1 = x_1[['open','high','low','close','volume',
                      'boll', 'boll_ub', 'boll_lb',
                      'macd', 'macdh', 'macds',
                      'rsi_11', 'rsi_14', 'rsi_21']]
        data_1.index = [int(str(ind)[0:4]+str(ind)[5:7]+str(ind)[8:10]) for ind in data_1.index]
        data_1 = data_1.sort_index()

        print("data_1 length",len(data_1))
        
        print(stock + " Data loaded...")
        
        for k,v in date_range_list.items():
         
            print("Getting Data... - " + stock + " from " + str(k))
            if (data_1.index[0]>v):
                print("No data for this testing period... - " + stock + " from " + str(k))
                continue
            test_X = custom_split(data_1,start = k,end = v)
            if len(test_X) <= num_day_to_predict:
                print("No enough data for testing... - " + stock + " from " + str(k))
                continue
                
            print("Transforming Data... - " + stock + " from " + str(k))
            test_y = produce_result_target_price(test_X,num_day_to_predict)
            test_X_5 = transform_x_data_to_one_vector(test_X,num_day_to_predict)
            new_test_X_5  = drop_nan_row_X_5(test_X_5,num_day_to_predict)
            new_test_y = drop_nan_row_y(test_y,num_day_to_predict)
            old_test_X_5 = new_test_X_5.copy()
            old_test_y = new_test_y.copy()
            new_test_X_5,new_test_y = normalize_data_by_row(new_test_X_5,new_test_y)

            final_train = twap(new_train_X_5)
            final_valid = twap(new_valid_X_5)
            final_test = twap(new_test_X_5)
            final_pred = twap(new_pred_X_5)

            for i in range(5):
              #df_ = final.filter(like=f"-{i}")
              final_train[f"TWAP_{i}"] = (final_train[f"open-{i}"]+final_train[f"close-{i}"]+final_train[f"high-{i}"]+final_train[f"low-{i}"])/4
              final_test[f"TWAP_{i}"] = (final_test[f"open-{i}"]+final_test[f"close-{i}"]+final_test[f"high-{i}"]+final_test[f"low-{i}"])/4
              final_valid[f"TWAP_{i}"] = (final_valid[f"open-{i}"]+final_valid[f"close-{i}"]+final_valid[f"high-{i}"]+final_valid[f"low-{i}"])/4
              final_pred[f"TWAP_{i}"] = (final_pred[f"open-{i}"]+final_pred[f"close-{i}"]+final_pred[f"high-{i}"]+final_pred[f"low-{i}"])/4


            new_train_X_5 = final_train
            new_test_X_5 = final_test 
            new_valid_X_5 = final_valid
            new_pred_X_5 = final_pred


            #print("lengths of train,test,valid,pred",len(new_train_X_5),len(new_test_X_5),len(new_valid_X_5),len(new_pred_X_5))
            #print("length of data_1 ", len(data_1))

            print("Predicting... - " + stock + " from " + str(k))
            twap_pred = twap_test.predict(new_test_X_5)
            #print("input length",len(new_test_X_5))
            #print("prediction length",len(twap_pred))
            
            print("Converting... - " + stock + " from " + str(k))
            pred_price = convert_prediction(old_test_X_5,old_test_y,twap_pred.flatten())

            data_copy = data_1

            pred_action = convert_decision(data_copy,pred_price)
            #pred_df["Action"] = pred_df.apply(lambda row: "Buy" if row["converted"] > row["mean"] else "Sell", axis=1)
            #final_pred = pred_df.drop(columns=["mean","std","pred","converted"])
            final_test_y = old_test_y.rename(columns={"result_price":"Open"})
            #final_pred = final_pred.sort_index()
            
            print("Backtesting... - " + stock + " from " + str(k))
            back1 = backtest(final_test_y,pred_action,10000,0.0005,period_year)
            back1.clear_trade_record(3)
            
            print("Start Iteration... - " + stock + " from " + str(k))
            back1.start_test()
            
            print("======= from "+ str(k) + " to " + str(v)+" =========")
            back1.print_do_nothing()
            back1.print_profit()
            back1.print_CAGR_performance()
            back1.export_trade_record("TWAP_"+sector+"-"+stock,str(k)+"-to-"+str(v)+"("+str(round(back1.get_diff_in_CAGR()*100,2))+"%)")
            backtest_summary = backtest_summary.append({"Sector":sector,
                                                        "Stock":stock,
                                                        "Range_Start":str(k),
                                                        "Range_End":str(v),
                                                        do_nth_name+"_Profit":round(back1.get_do_nothing(),2),
                                                        model_name+"_Profit":round(back1.get_profit(),2),
                                                        do_nth_name+"_CAGR(in %)":round(back1.get_do_nothing_CAGR()*100,2),
                                                        model_name+"_CAGR(in %)":round(back1.get_model_CAGR()*100,2),
                                                        "CAGR_Performance(in %)":round(back1.get_diff_in_CAGR()*100,2),
                                                        do_nth_name+"_MDD(in %)":round(back1.get_do_nothing_MDD()*100,2),
                                                        model_name+"_MDD(in %)":round(back1.get_model_MDD()*100,2),
                                                        "MDD_Performance(in %)":round(back1.get_diff_in_MDD()*100,2)}, ignore_index=True)
            print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
            time.sleep(3)

print("Backtesting Completed...")
backtest_summary.to_csv(backtest_summary_folder+"backtest_summary_twap.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# Sold at 20131202 with price = 34.006 	Pos: 313
# Bought at 20131203 with price = 34.063 	Pos: 312
# Sold at 20131205 with price = 33.627 	Pos: 312
# Bought at 20131209 with price = 33.791 	Pos: 310
# Sold at 20131210 with price = 33.454 	Pos: 310
# Bought at 20131218 with price = 33.252 	Pos: 312
# ======= from 20130101 to 20131231 =========
# If buy at 20130108 with price = 28.335
# and do nothing
# Current Profit: 1925.7330399999992
# Current Profit with model: 566.9519830000208
# CAGR Performance: -13.59%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - VZ from 20140101
# Transforming Data... - VZ from 20140101
# Predicting... - VZ from 20140101
# Converting... - VZ from 20140101
# Backtesting... - VZ from 20140101
# Clearing trade_record...
# Start Iteration... - VZ from 20140101
# Start Backtesting...
# Bought at 20140115 with price = 33.31 	Pos: 300
# Sold at 20140122 with price = 32.465 	Pos: 300
# Bought at 20140131 with price = 33.144 	Pos: 293
# Sold at 20140203 with price = 31.976 	Pos: 293
# Bought at 20140210 with price = 32.465 	Pos: 288
# Sold at 20140214 with price = 32.073 	Pos: 288
# Bought at 20140220 with price = 32.818 	Pos: 282
# Sold at 20140225 with price = 31.812 	Pos: 282
# Bought at 20140227 with price = 32.749 	Pos: 273
# Sold at 20140306 with price = 32.723 	Pos: 273
# Bought at 20140318 with price = 32.179 	Pos: 278
# Sold at 20140326 with price = 32.427 	Pos: 278
# Bought at 20140327 with price = 32.876 	Pos: 274
# Sold at 20140410 with price = 33.044 	Pos: 274
# Bought at 20140417 with price = 33.337 	Pos: 271
# Sold at 20140423 with price = 33.08 	Pos: 271
# Bought at 20140429 with price = 32.592 	Pos: 275
# Sold at 20140513 with price = 33.5 	Pos: 275
# Bought at 20140516 with price = 34.287 	Pos: 268
# Sold at 20140603 with price = 34.418 	Pos: 268
# Bought at 20140609 with price = 34.508 	Pos: 267
# Sold at 20140612 with price = 34.146 	Pos: 267
# Bought at 20140616 with price = 34.341 	Pos: 265
# Sold at 20140617 with price = 34.203 	Pos: 265
# Bought at 20140618 with price = 34.489 	Pos: 263
# Sold at 20140624 with price = 34.293 	Pos: 263
# Bought at 20140701 with price = 34.559 	Pos: 261
# Sold at 20140708 with price = 34.557 	Pos: 261
# Bought at 20140710 with price = 35.163 	Pos: 256
# Sold at 20140717 with price = 35.704 	Pos: 256
# Bought at 20140718 with price = 35.85 	Pos: 255
# Sold at 20140731 with price = 35.579 	Pos: 255
# Bought at 20140813 with price = 34.577 	Pos: 262
# Sold at 20140815 with price = 34.601 	Pos: 262
# Bought at 20140821 with price = 34.446 	Pos: 263
# Sold at 20140822 with price = 34.369 	Pos: 263
# Bought at 20140825 with price = 34.711 	Pos: 260
# Sold at 20140908 with price = 34.862 	Pos: 260
# Bought at 20140916 with price = 34.601 	Pos: 261
# Sold at 20140925 with price = 34.93 	Pos: 261
# Bought at 20140929 with price = 35.039 	Pos: 260
# Sold at 20141001 with price = 35.055 	Pos: 260
# Bought at 20141003 with price = 35.226 	Pos: 259
# Sold at 20141009 with price = 34.952 	Pos: 259
# Bought at 20141020 with price = 34.303 	Pos: 263
# Sold at 20141106 with price = 35.901 	Pos: 263
# Bought at 20141107 with price = 36.178 	Pos: 261
# Sold at 20141119 with price = 35.958 	Pos: 261
# Bought at 20141126 with price = 35.831 	Pos: 262
# Sold at 20141202 with price = 34.966 	Pos: 262
# Bought at 20141217 with price = 33.739 	Pos: 271
# Sold at 20141229 with price = 33.893 	Pos: 271
# ======= from 20140101 to 20141231 =========
# If buy at 20140108 with price = 33.427
# and do nothing
# Current Profit: 41.94566350000241
# Current Profit with model: -800.9166549999627
# CAGR Performance: -8.43%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - VZ from 20150101
# Transforming Data... - VZ from 20150101
# Predicting... - VZ from 20150101
# Converting... - VZ from 20150101
# Backtesting... - VZ from 20150101
# Clearing trade_record...
# Start Iteration... - VZ from 20150101
# Start Backtesting...
# Bought at 20150108 with price = 34.087 	Pos: 293
# Sold at 20150114 with price = 34.11 	Pos: 293
# Bought at 20150116 with price = 34.714 	Pos: 287
# Sold at 20150123 with price = 33.914 	Pos: 287
# Bought at 20150202 with price = 34.135 	Pos: 285
# Sold at 20150217 with price = 35.524 	Pos: 285
# Bought at 20150224 with price = 35.627 	Pos: 284
# Sold at 20150304 with price = 35.516 	Pos: 284
# Bought at 20150312 with price = 35.012 	Pos: 288
# Sold at 20150325 with price = 35.092 	Pos: 288
# Bought at 20150330 with price = 35.43 	Pos: 285
# Sold at 20150331 with price = 34.967 	Pos: 285
# Bought at 20150401 with price = 35.343 	Pos: 282
# Sold at 20150417 with price = 35.806 	Pos: 282
# Bought at 20150420 with price = 35.74 	Pos: 282
# Sold at 20150505 with price = 36.544 	Pos: 282
# Bought at 20150513 with price = 36.421 	Pos: 282
# Sold at 20150515 with price = 36.332 	Pos: 282
# Bought at 20150521 with price = 36.321 	Pos: 282
# Sold at 20150526 with price = 36.135 	Pos: 282
# Bought at 20150611 with price = 34.852 	Pos: 292
# Sold at 20150612 with price = 34.405 	Pos: 292
# Bought at 20150618 with price = 34.778 	Pos: 289
# Sold at 20150624 with price = 34.763 	Pos: 289
# Bought at 20150707 with price = 34.398 	Pos: 292
# Sold at 20150709 with price = 34.598 	Pos: 292
# Bought at 20150710 with price = 34.987 	Pos: 288
# Sold at 20150721 with price = 34.552 	Pos: 288
# Bought at 20150729 with price = 34.459 	Pos: 289
# Sold at 20150805 with price = 34.404 	Pos: 289
# Bought at 20150810 with price = 35.107 	Pos: 283
# Sold at 20150817 with price = 35.124 	Pos: 283
# Bought at 20150827 with price = 34.015 	Pos: 292
# Sold at 20150901 with price = 33.601 	Pos: 292
# Bought at 20150903 with price = 33.459 	Pos: 292
# Sold at 20150904 with price = 33.661 	Pos: 292
# Bought at 20150908 with price = 34.153 	Pos: 288
# Sold at 20150909 with price = 33.506 	Pos: 288
# Bought at 20150911 with price = 33.807 	Pos: 285
# Sold at 20150914 with price = 33.91 	Pos: 285
# Bought at 20150915 with price = 34.294 	Pos: 282
# Sold at 20150917 with price = 33.349 	Pos: 282
# Bought at 20150925 with price = 32.502 	Pos: 289
# Sold at 20150928 with price = 32.332 	Pos: 289
# Bought at 20151005 with price = 32.494 	Pos: 287
# Sold at 20151014 with price = 33.094 	Pos: 287
# Bought at 20151015 with price = 33.589 	Pos: 282
# Sold at 20151103 with price = 34.844 	Pos: 282
# Bought at 20151116 with price = 33.67 	Pos: 292
# Sold at 20151123 with price = 33.474 	Pos: 292
# Bought at 20151127 with price = 33.851 	Pos: 288
# Sold at 20151202 with price = 33.577 	Pos: 288
# Bought at 20151204 with price = 34.008 	Pos: 285
# Sold at 20151210 with price = 33.657 	Pos: 285
# Bought at 20151214 with price = 34.051 	Pos: 281
# Sold at 20151221 with price = 34.561 	Pos: 281
# Bought at 20151222 with price = 34.794 	Pos: 279
# Sold at 20151230 with price = 34.799 	Pos: 279
# ======= from 20150101 to 20151231 =========
# If buy at 20150108 with price = 34.087
# and do nothing
# Current Profit: 203.62225449999823
# Current Profit with model: -286.745640499983
# CAGR Performance: -4.9%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - VZ from 20160101
# Transforming Data... - VZ from 20160101
# Predicting... - VZ from 20160101
# Converting... - VZ from 20160101
# Backtesting... - VZ from 20160101
# Clearing trade_record...
# Start Iteration... - VZ from 20160101
# Start Backtesting...
# Bought at 20160121 with price = 35.142 	Pos: 284
# Sold at 20160209 with price = 38.008 	Pos: 284
# Bought at 20160216 with price = 38.175 	Pos: 282
# Sold at 20160223 with price = 38.066 	Pos: 282
# Bought at 20160225 with price = 38.733 	Pos: 277
# Sold at 20160226 with price = 38.515 	Pos: 277
# Bought at 20160301 with price = 38.901 	Pos: 274
# Sold at 20160314 with price = 39.559 	Pos: 274
# Bought at 20160315 with price = 39.886 	Pos: 272
# Sold at 20160322 with price = 40.232 	Pos: 272
# Bought at 20160324 with price = 40.558 	Pos: 269
# Sold at 20160407 with price = 39.947 	Pos: 269
# Bought at 20160418 with price = 39.64 	Pos: 271
# Sold at 20160421 with price = 38.377 	Pos: 271
# Bought at 20160427 with price = 39.258 	Pos: 265
# Sold at 20160429 with price = 39.199 	Pos: 265
# Bought at 20160502 with price = 39.115 	Pos: 265
# Sold at 20160503 with price = 38.63 	Pos: 265
# Bought at 20160509 with price = 39.318 	Pos: 260
# Sold at 20160511 with price = 39.199 	Pos: 260
# Bought at 20160512 with price = 39.342 	Pos: 259
# Sold at 20160513 with price = 38.855 	Pos: 259
# Bought at 20160525 with price = 38.148 	Pos: 263
# Sold at 20160601 with price = 38.623 	Pos: 263
# Bought at 20160602 with price = 38.855 	Pos: 262
# Sold at 20160606 with price = 38.722 	Pos: 262
# Bought at 20160607 with price = 39.417 	Pos: 257
# Sold at 20160707 with price = 42.816 	Pos: 257
# Bought at 20160708 with price = 43.093 	Pos: 255
# Sold at 20160712 with price = 42.963 	Pos: 255
# Bought at 20160713 with price = 42.994 	Pos: 254
# Sold at 20160719 with price = 42.963 	Pos: 254
# Bought at 20160722 with price = 43.363 	Pos: 252
# Sold at 20160726 with price = 42.477 	Pos: 252
# Bought at 20160729 with price = 42.963 	Pos: 249
# Sold at 20160801 with price = 42.09 	Pos: 249
# Bought at 20160810 with price = 41.596 	Pos: 251
# Sold at 20160812 with price = 41.479 	Pos: 251
# Bought at 20160825 with price = 40.693 	Pos: 256
# Sold at 20160826 with price = 40.473 	Pos: 256
# Bought at 20160901 with price = 40.813 	Pos: 254
# Sold at 20160909 with price = 40.002 	Pos: 254
# Bought at 20160921 with price = 40.311 	Pos: 251
# Sold at 20160928 with price = 40.071 	Pos: 251
# Bought at 20161014 with price = 39.254 	Pos: 256
# Sold at 20161018 with price = 39.443 	Pos: 256
# Bought at 20161027 with price = 37.965 	Pos: 266
# Sold at 20161028 with price = 37.715 	Pos: 266
# Bought at 20161108 with price = 36.751 	Pos: 273
# Sold at 20161110 with price = 36.51 	Pos: 273
# Bought at 20161115 with price = 37.128 	Pos: 268
# Sold at 20161130 with price = 38.935 	Pos: 268
# Bought at 20161206 with price = 39.654 	Pos: 263
# ======= from 20160101 to 20161231 =========
# If buy at 20160108 with price = 34.159
# and do nothing
# Current Profit: 2244.872786
# Current Profit with model: 1024.2422270000388
# CAGR Performance: -12.21%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - VZ from 20170101
# Transforming Data... - VZ from 20170101
# Predicting... - VZ from 20170101
# Converting... - VZ from 20170101
# Backtesting... - VZ from 20170101
# Clearing trade_record...
# Start Iteration... - VZ from 20170101
# Start Backtesting...
# Bought at 20170117 with price = 41.5 	Pos: 240
# Sold at 20170118 with price = 41.521 	Pos: 240
# Bought at 20170120 with price = 41.451 	Pos: 241
# Sold at 20170123 with price = 39.709 	Pos: 241
# Bought at 20170209 with price = 38.669 	Pos: 247
# Sold at 20170214 with price = 37.928 	Pos: 247
# Bought at 20170216 with price = 38.173 	Pos: 245
# Sold at 20170228 with price = 39.158 	Pos: 245
# Bought at 20170303 with price = 39.533 	Pos: 242
# Sold at 20170307 with price = 38.955 	Pos: 242
# Bought at 20170314 with price = 38.922 	Pos: 242
# Sold at 20170322 with price = 39.31 	Pos: 242
# Bought at 20170403 with price = 38.797 	Pos: 245
# Sold at 20170405 with price = 38.795 	Pos: 245
# Bought at 20170407 with price = 38.956 	Pos: 244
# Sold at 20170410 with price = 38.789 	Pos: 244
# Bought at 20170411 with price = 38.802 	Pos: 244
# Sold at 20170420 with price = 38.316 	Pos: 244
# Bought at 20170505 with price = 37.354 	Pos: 250
# Sold at 20170510 with price = 37.029 	Pos: 250
# Bought at 20170519 with price = 36.291 	Pos: 255
# Sold at 20170524 with price = 36.02 	Pos: 255
# Bought at 20170526 with price = 36.188 	Pos: 253
# Sold at 20170606 with price = 37.196 	Pos: 253
# Bought at 20170609 with price = 37.419 	Pos: 251
# Sold at 20170613 with price = 37.283 	Pos: 251
# Bought at 20170626 with price = 35.957 	Pos: 260
# Sold at 20170627 with price = 35.965 	Pos: 260
# Bought at 20170703 with price = 36.02 	Pos: 260
# Sold at 20170705 with price = 35.622 	Pos: 260
# Bought at 20170713 with price = 35.344 	Pos: 262
# Sold at 20170718 with price = 35.119 	Pos: 262
# Bought at 20170720 with price = 35.831 	Pos: 256
# Sold at 20170724 with price = 35.562 	Pos: 256
# Bought at 20170725 with price = 36.291 	Pos: 251
# Sold at 20170809 with price = 39.032 	Pos: 251
# Bought at 20170814 with price = 39.337 	Pos: 248
# Sold at 20170817 with price = 38.764 	Pos: 248
# Bought at 20170822 with price = 39.094 	Pos: 246
# Sold at 20170830 with price = 39.094 	Pos: 246
# Bought at 20170912 with price = 37.895 	Pos: 254
# Sold at 20170928 with price = 39.937 	Pos: 254
# Bought at 20171003 with price = 40.213 	Pos: 252
# Sold at 20171006 with price = 40.14 	Pos: 252
# Bought at 20171009 with price = 40.4 	Pos: 250
# Sold at 20171011 with price = 39.711 	Pos: 250
# Bought at 20171018 with price = 41.031 	Pos: 241
# Sold at 20171024 with price = 39.908 	Pos: 241
# Bought at 20171116 with price = 36.588 	Pos: 263
# Sold at 20171206 with price = 41.474 	Pos: 263
# Bought at 20171208 with price = 41.992 	Pos: 260
# Sold at 20171219 with price = 43.541 	Pos: 260
# Bought at 20171221 with price = 43.541 	Pos: 259
# ======= from 20170101 to 20171231 =========
# If buy at 20170109 with price = 41.634
# and do nothing
# Current Profit: 503.08392000000094
# Current Profit with model: 1368.648662000027
# CAGR Performance: 8.66%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - VZ from 20180101
# Transforming Data... - VZ from 20180101
# Predicting... - VZ from 20180101
# Converting... - VZ from 20180101
# Backtesting... - VZ from 20180101
# Clearing trade_record...
# Start Iteration... - VZ from 20180101
# Start Backtesting...
# Bought at 20180111 with price = 43.066 	Pos: 232
# Sold at 20180112 with price = 42.851 	Pos: 232
# Bought at 20180122 with price = 45.273 	Pos: 219
# Sold at 20180130 with price = 44.765 	Pos: 219
# Bought at 20180201 with price = 44.997 	Pos: 218
# Sold at 20180202 with price = 43.549 	Pos: 218
# Bought at 20180216 with price = 41.325 	Pos: 229
# Sold at 20180220 with price = 40.463 	Pos: 229
# Bought at 20180226 with price = 39.833 	Pos: 233
# Sold at 20180227 with price = 40.43 	Pos: 233
# Bought at 20180305 with price = 40.42 	Pos: 232
# Sold at 20180312 with price = 40.629 	Pos: 232
# Bought at 20180327 with price = 39.707 	Pos: 238
# Sold at 20180402 with price = 39.151 	Pos: 238
# Bought at 20180404 with price = 39.784 	Pos: 233
# Sold at 20180406 with price = 39.485 	Pos: 233
# Bought at 20180410 with price = 40.239 	Pos: 229
# Sold at 20180413 with price = 40.258 	Pos: 229
# Bought at 20180416 with price = 40.796 	Pos: 226
# Sold at 20180419 with price = 40.559 	Pos: 226
# Bought at 20180424 with price = 42.027 	Pos: 218
# Sold at 20180430 with price = 41.552 	Pos: 218
# Bought at 20180511 with price = 40.862 	Pos: 221
# Sold at 20180516 with price = 40.183 	Pos: 221
# Bought at 20180521 with price = 40.575 	Pos: 219
# Sold at 20180525 with price = 40.55 	Pos: 219
# Bought at 20180606 with price = 40.268 	Pos: 220
# Sold at 20180612 with price = 40.678 	Pos: 220
# Bought at 20180619 with price = 40.837 	Pos: 219
# Sold at 20180627 with price = 41.501 	Pos: 219
# Bought at 20180628 with price = 42.592 	Pos: 213
# Sold at 20180718 with price = 43.4 	Pos: 213
# Bought at 20180724 with price = 43.903 	Pos: 210
# Sold at 20180725 with price = 43.424 	Pos: 210
# Bought at 20180726 with price = 43.725 	Pos: 209
# Sold at 20180731 with price = 44.181 	Pos: 209
# Bought at 20180803 with price = 44.274 	Pos: 208
# Sold at 20180810 with price = 44.793 	Pos: 208
# Bought at 20180814 with price = 44.785 	Pos: 208
# Sold at 20180822 with price = 45.998 	Pos: 208
# Bought at 20180824 with price = 46.695 	Pos: 205
# Sold at 20180831 with price = 45.479 	Pos: 205
# Bought at 20180906 with price = 45.973 	Pos: 202
# Sold at 20180918 with price = 46.389 	Pos: 202
# Bought at 20180921 with price = 46.127 	Pos: 203
# Sold at 20180924 with price = 45.439 	Pos: 203
# Bought at 20181001 with price = 45.695 	Pos: 202
# Sold at 20181011 with price = 46.214 	Pos: 202
# Bought at 20181017 with price = 46.248 	Pos: 201
# Sold at 20181026 with price = 47.922 	Pos: 201
# Bought at 20181029 with price = 48.876 	Pos: 197
# Sold at 20181101 with price = 48.377 	Pos: 197
# Bought at 20181105 with price = 48.962 	Pos: 195
# Sold at 20181120 with price = 50.884 	Pos: 195
# Bought at 20181127 with price = 52.122 	Pos: 190
# Sold at 20181203 with price = 49.891 	Pos: 190
# Bought at 20181210 with price = 50.466 	Pos: 188
# Sold at 20181212 with price = 48.946 	Pos: 188
# Bought at 20181227 with price = 47.546 	Pos: 193
# ======= from 20180101 to 20181231 =========
# If buy at 20180108 with price = 43.216
# and do nothing
# Current Profit: 1026.6545520000018
# Current Profit with model: -780.1857579999833
# CAGR Performance: -18.07%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - VZ from 20190101
# Transforming Data... - VZ from 20190101
# Predicting... - VZ from 20190101
# Converting... - VZ from 20190101
# Backtesting... - VZ from 20190101
# Clearing trade_record...
# Start Iteration... - VZ from 20190101
# Start Backtesting...
# Bought at 20190108 with price = 50.043 	Pos: 199
# Sold at 20190116 with price = 49.591 	Pos: 199
# Bought at 20190123 with price = 49.982 	Pos: 197
# Sold at 20190124 with price = 49.608 	Pos: 197
# Bought at 20190131 with price = 47.902 	Pos: 204
# Sold at 20190206 with price = 46.513 	Pos: 204
# Bought at 20190208 with price = 46.961 	Pos: 202
# Sold at 20190214 with price = 47.267 	Pos: 202
# Bought at 20190215 with price = 47.769 	Pos: 200
# Sold at 20190301 with price = 49.583 	Pos: 200
# Bought at 20190308 with price = 49.244 	Pos: 201
# Sold at 20190319 with price = 49.896 	Pos: 201
# Bought at 20190321 with price = 50.46 	Pos: 199
# Sold at 20190328 with price = 51.363 	Pos: 199
# Bought at 20190408 with price = 51.161 	Pos: 199
# Sold at 20190417 with price = 50.406 	Pos: 199
# Bought at 20190430 with price = 50.161 	Pos: 200
# Sold at 20190501 with price = 49.793 	Pos: 200
# Bought at 20190502 with price = 50.092 	Pos: 199
# Sold at 20190506 with price = 49.687 	Pos: 199
# Bought at 20190510 with price = 49.715 	Pos: 198
# Sold at 20190514 with price = 49.529 	Pos: 198
# Bought at 20190515 with price = 49.96 	Pos: 196
# Sold at 20190528 with price = 51.424 	Pos: 196
# Bought at 20190605 with price = 49.969 	Pos: 202
# Sold at 20190610 with price = 49.52 	Pos: 202
# Bought at 20190612 with price = 50.398 	Pos: 198
# Sold at 20190618 with price = 50.302 	Pos: 198
# Bought at 20190624 with price = 50.995 	Pos: 195
# Sold at 20190626 with price = 50.101 	Pos: 195
# Bought at 20190702 with price = 50.941 	Pos: 192
# Sold at 20190709 with price = 50.218 	Pos: 192
# Bought at 20190712 with price = 50.739 	Pos: 190
# Sold at 20190717 with price = 50.678 	Pos: 190
# Bought at 20190725 with price = 50.022 	Pos: 192
# Sold at 20190731 with price = 50.581 	Pos: 192
# Bought at 20190808 with price = 49.288 	Pos: 197
# Sold at 20190814 with price = 49.18 	Pos: 197
# Bought at 20190815 with price = 50.022 	Pos: 193
# Sold at 20190820 with price = 50.289 	Pos: 193
# Bought at 20190827 with price = 50.66 	Pos: 192
# Sold at 20190916 with price = 52.537 	Pos: 192
# Bought at 20190917 with price = 52.794 	Pos: 191
# Sold at 20190927 with price = 53.583 	Pos: 191
# Bought at 20191004 with price = 53.069 	Pos: 192
# Sold at 20191024 with price = 54.226 	Pos: 192
# Bought at 20191030 with price = 54.406 	Pos: 191
# Sold at 20191101 with price = 53.402 	Pos: 191
# Bought at 20191106 with price = 53.919 	Pos: 189
# Sold at 20191108 with price = 53.062 	Pos: 189
# Bought at 20191115 with price = 53.205 	Pos: 189
# Sold at 20191125 with price = 53.286 	Pos: 189
# Bought at 20191126 with price = 53.697 	Pos: 187
# Sold at 20191213 with price = 54.34 	Pos: 187
# Bought at 20191216 with price = 54.941 	Pos: 185
# Sold at 20191218 with price = 54.493 	Pos: 185
# Bought at 20191220 with price = 55.486 	Pos: 181
# Sold at 20191223 with price = 54.995 	Pos: 181
# Bought at 20191226 with price = 54.933 	Pos: 181
# Sold at 20191230 with price = 54.771 	Pos: 181
# ======= from 20190101 to 20191231 =========
# If buy at 20190108 with price = 50.043
# and do nothing
# Current Profit: 935.8927215000003
# Current Profit with model: -46.57110549996469
# CAGR Performance: -9.82%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - VZ from 20200101
# Transforming Data... - VZ from 20200101
# Predicting... - VZ from 20200101
# Converting... - VZ from 20200101
# Backtesting... - VZ from 20200101
# Clearing trade_record...
# Start Iteration... - VZ from 20200101
# Start Backtesting...
# Bought at 20200113 with price = 53.342 	Pos: 187
# Sold at 20200114 with price = 53.569 	Pos: 187
# Bought at 20200115 with price = 53.687 	Pos: 186
# Sold at 20200127 with price = 54.23 	Pos: 186
# Bought at 20200128 with price = 55.016 	Pos: 183
# Sold at 20200129 with price = 53.071 	Pos: 183
# Bought at 20200205 with price = 53.524 	Pos: 182
# Sold at 20200211 with price = 52.963 	Pos: 182
# Bought at 20200302 with price = 51.724 	Pos: 186
# Sold at 20200303 with price = 51.182 	Pos: 186
# Bought at 20200304 with price = 51.417 	Pos: 185
# Sold at 20200309 with price = 50.694 	Pos: 185
# Bought at 20200310 with price = 50.052 	Pos: 187
# Sold at 20200311 with price = 46.968 	Pos: 187
# Bought at 20200317 with price = 48.814 	Pos: 180
# Sold at 20200323 with price = 46.977 	Pos: 180
# Bought at 20200326 with price = 47.149 	Pos: 179
# Sold at 20200415 with price = 52.355 	Pos: 179
# Bought at 20200416 with price = 53.058 	Pos: 176
# Sold at 20200421 with price = 52.463 	Pos: 176
# Bought at 20200422 with price = 53.113 	Pos: 174
# Sold at 20200423 with price = 52.675 	Pos: 174
# Bought at 20200427 with price = 52.84 	Pos: 173
# Sold at 20200430 with price = 52.783 	Pos: 173
# Bought at 20200508 with price = 51.97 	Pos: 176
# Sold at 20200511 with price = 51.862 	Pos: 176
# Bought at 20200518 with price = 50.653 	Pos: 180
# Sold at 20200519 with price = 49.842 	Pos: 180
# Bought at 20200527 with price = 50.793 	Pos: 176
# Sold at 20200611 with price = 51.75 	Pos: 176
# Bought at 20200618 with price = 52.409 	Pos: 174
# Sold at 20200619 with price = 51.092 	Pos: 174
# Bought at 20200629 with price = 50.189 	Pos: 177
# Sold at 20200707 with price = 50.363 	Pos: 177
# Bought at 20200708 with price = 50.502 	Pos: 176
# Sold at 20200709 with price = 49.755 	Pos: 176
# Bought at 20200710 with price = 50.594 	Pos: 173
# Sold at 20200713 with price = 50.299 	Pos: 173
# Bought at 20200714 with price = 51.389 	Pos: 169
# Sold at 20200722 with price = 51.574 	Pos: 169
# Bought at 20200724 with price = 52.675 	Pos: 166
# Sold at 20200803 with price = 52.857 	Pos: 166
# Bought at 20200804 with price = 53.746 	Pos: 163
# Sold at 20200828 with price = 54.56 	Pos: 163
# Bought at 20200831 with price = 54.633 	Pos: 162
# Sold at 20200901 with price = 54.661 	Pos: 162
# Bought at 20200902 with price = 56.212 	Pos: 158
# Sold at 20200910 with price = 55.059 	Pos: 158
# Bought at 20200914 with price = 55.549 	Pos: 156
# Sold at 20200921 with price = 55.197 	Pos: 156
# Bought at 20200929 with price = 54.948 	Pos: 157
# Sold at 20201002 with price = 55.105 	Pos: 157
# Bought at 20201005 with price = 55.225 	Pos: 156
# Sold at 20201014 with price = 54.27 	Pos: 156
# Bought at 20201023 with price = 53.719 	Pos: 158
# Sold at 20201028 with price = 52.448 	Pos: 158
# Bought at 20201102 with price = 53.991 	Pos: 153
# Sold at 20201118 with price = 56.409 	Pos: 153
# Bought at 20201124 with price = 56.661 	Pos: 152
# Sold at 20201210 with price = 56.111 	Pos: 152
# Bought at 20201215 with price = 56.221 	Pos: 152
# Sold at 20201216 with price = 56.018 	Pos: 152
# Bought at 20201218 with price = 56.092 	Pos: 151
# Sold at 20201221 with price = 55.4 	Pos: 151
# ======= from 20200101 to 20201231 =========
# If buy at 20200108 with price = 53.244
# and do nothing
# Current Profit: 178.46868600000016
# Current Profit with model: -1593.010998499958
# CAGR Performance: -17.71%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - VZ from 20210101
# Transforming Data... - VZ from 20210101
# Predicting... - VZ from 20210101
# Converting... - VZ from 20210101
# Backtesting... - VZ from 20210101
# Clearing trade_record...
# Start Iteration... - VZ from 20210101
# Start Backtesting...
# Bought at 20210115 with price = 54.219 	Pos: 184
# Sold at 20210126 with price = 53.463 	Pos: 184
# Bought at 20210204 with price = 52.104 	Pos: 188
# Sold at 20210210 with price = 51.934 	Pos: 188
# Bought at 20210217 with price = 53.747 	Pos: 182
# Sold at 20210225 with price = 53.303 	Pos: 182
# Bought at 20210305 with price = 52.812 	Pos: 183
# Sold at 20210312 with price = 52.681 	Pos: 183
# Bought at 20210318 with price = 53.263 	Pos: 181
# Sold at 20210408 with price = 54.953 	Pos: 181
# Bought at 20210414 with price = 54.915 	Pos: 181
# Sold at 20210422 with price = 54.504 	Pos: 181
# Bought at 20210429 with price = 54.715 	Pos: 180
# Sold at 20210511 with price = 55.573 	Pos: 180
# Bought at 20210513 with price = 56.297 	Pos: 178
# Sold at 20210514 with price = 56.184 	Pos: 178
# Bought at 20210524 with price = 54.381 	Pos: 184
# Sold at 20210525 with price = 53.876 	Pos: 184
# Bought at 20210602 with price = 54.094 	Pos: 183
# Sold at 20210616 with price = 54.047 	Pos: 183
# Bought at 20210624 with price = 53.684 	Pos: 184
# Sold at 20210628 with price = 53.618 	Pos: 184
# Bought at 20210701 with price = 53.79 	Pos: 183
# Sold at 20210719 with price = 53.978 	Pos: 183
# Bought at 20210727 with price = 54.257 	Pos: 182
# Sold at 20210728 with price = 53.919 	Pos: 182
# Bought at 20210729 with price = 54.055 	Pos: 181
# Sold at 20210730 with price = 54.083 	Pos: 181
# Bought at 20210810 with price = 53.65 	Pos: 182
# Sold at 20210818 with price = 53.35 	Pos: 182
# Bought at 20210831 with price = 53.061 	Pos: 183
# Sold at 20210907 with price = 52.858 	Pos: 183
# Bought at 20210915 with price = 52.694 	Pos: 184
# Sold at 20210916 with price = 52.232 	Pos: 184
# Bought at 20210923 with price = 52.443 	Pos: 183
# Sold at 20210928 with price = 52.184 	Pos: 183
# Bought at 20210929 with price = 52.579 	Pos: 181
# Sold at 20210930 with price = 52.115 	Pos: 181
# Bought at 20211004 with price = 52.714 	Pos: 179
# Sold at 20211008 with price = 51.993 	Pos: 179
# Bought at 20211015 with price = 50.919 	Pos: 182
# Sold at 20211025 with price = 51.447 	Pos: 182
# Bought at 20211029 with price = 51.973 	Pos: 180
# Sold at 20211102 with price = 51.339 	Pos: 180
# Bought at 20211103 with price = 51.651 	Pos: 179
# Sold at 20211104 with price = 50.783 	Pos: 179
# Bought at 20211110 with price = 51.485 	Pos: 177
# Sold at 20211112 with price = 51.193 	Pos: 177
# Bought at 20211122 with price = 50.333 	Pos: 179
# Sold at 20211130 with price = 49.299 	Pos: 179
# Bought at 20211203 with price = 50.411 	Pos: 175
# Sold at 20211208 with price = 49.201 	Pos: 175
# Bought at 20211214 with price = 49.621 	Pos: 174
# Sold at 20211223 with price = 51.437 	Pos: 174
# ======= from 20210101 to 20211231 =========
# If buy at 20210108 with price = 54.51
# and do nothing
# Current Profit: -654.8206649999975
# Current Profit with model: -1047.5834049999703
# CAGR Performance: -3.93%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Runninng stock: CMCSA
# entire dataset 5607
# data_1 length 5607
# CMCSA Data loaded...
# Getting Data... - CMCSA from 20120101
# Transforming Data... - CMCSA from 20120101
# Predicting... - CMCSA from 20120101
# Converting... - CMCSA from 20120101
# Backtesting... - CMCSA from 20120101
# Clearing trade_record...
# Start Iteration... - CMCSA from 20120101
# Start Backtesting...
# Bought at 20120109 with price = 10.537 	Pos: 948
# Sold at 20120112 with price = 10.487 	Pos: 948
# Bought at 20120119 with price = 10.675 	Pos: 930
# Sold at 20120123 with price = 10.648 	Pos: 930
# Bought at 20120126 with price = 10.855 	Pos: 912
# Sold at 20120127 with price = 10.816 	Pos: 912
# Bought at 20120201 with price = 11.058 	Pos: 891
# Sold at 20120202 with price = 11.125 	Pos: 891
# Bought at 20120203 with price = 11.182 	Pos: 885
# Sold at 20120206 with price = 11.138 	Pos: 885
# Bought at 20120209 with price = 11.246 	Pos: 876
# Sold at 20120210 with price = 11.303 	Pos: 876
# Bought at 20120215 with price = 11.848 	Pos: 835
# Sold at 20120224 with price = 11.929 	Pos: 835
# Bought at 20120308 with price = 12.299 	Pos: 809
# Sold at 20120314 with price = 12.288 	Pos: 809
# Bought at 20120323 with price = 12.415 	Pos: 800
# Sold at 20120328 with price = 12.295 	Pos: 800
# Bought at 20120412 with price = 12.295 	Pos: 799
# Sold at 20120419 with price = 12.257 	Pos: 799
# Bought at 20120426 with price = 12.563 	Pos: 779
# Sold at 20120503 with price = 12.455 	Pos: 779
# Bought at 20120522 with price = 11.918 	Pos: 813
# Sold at 20120523 with price = 11.956 	Pos: 813
# Bought at 20120524 with price = 12.03 	Pos: 807
# Sold at 20120525 with price = 12.017 	Pos: 807
# Bought at 20120529 with price = 12.039 	Pos: 805
# Sold at 20120530 with price = 12.01 	Pos: 805
# Bought at 20120606 with price = 12.488 	Pos: 773
# Sold at 20120613 with price = 12.488 	Pos: 773
# Bought at 20120614 with price = 12.798 	Pos: 754
# Sold at 20120621 with price = 12.754 	Pos: 754
# Bought at 20120627 with price = 12.789 	Pos: 751
# Sold at 20120705 with price = 13.047 	Pos: 751
# Bought at 20120713 with price = 13.214 	Pos: 741
# Sold at 20120723 with price = 13.109 	Pos: 741
# Bought at 20120727 with price = 13.474 	Pos: 720
# Sold at 20120809 with price = 14.396 	Pos: 720
# Bought at 20120810 with price = 14.445 	Pos: 717
# Sold at 20120813 with price = 14.516 	Pos: 717
# Bought at 20120824 with price = 14.152 	Pos: 735
# Sold at 20120830 with price = 14.097 	Pos: 735
# Bought at 20120906 with price = 14.454 	Pos: 716
# Sold at 20120926 with price = 14.747 	Pos: 716
# Bought at 20121002 with price = 15.05 	Pos: 701
# Sold at 20121009 with price = 14.845 	Pos: 701
# Bought at 20121012 with price = 15.009 	Pos: 692
# Sold at 20121023 with price = 15.335 	Pos: 692
# Bought at 20121026 with price = 15.749 	Pos: 673
# Sold at 20121106 with price = 15.421 	Pos: 673
# Bought at 20121119 with price = 15.059 	Pos: 689
# Sold at 20121127 with price = 15.189 	Pos: 689
# Bought at 20121128 with price = 15.373 	Pos: 680
# Sold at 20121213 with price = 15.434 	Pos: 680
# Bought at 20121217 with price = 15.796 	Pos: 664
# Sold at 20121221 with price = 15.545 	Pos: 664
# ======= from 20120101 to 20121231 =========
# If buy at 20120109 with price = 10.537
# and do nothing
# Current Profit: 4524.549461999999
# Current Profit with model: 319.7744665000191
# CAGR Performance: -42.05%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - CMCSA from 20130101
# Transforming Data... - CMCSA from 20130101
# Predicting... - CMCSA from 20130101
# Converting... - CMCSA from 20130101
# Backtesting... - CMCSA from 20130101
# Clearing trade_record...
# Start Iteration... - CMCSA from 20130101
# Start Backtesting...
# Bought at 20130109 with price = 16.262 	Pos: 614
# Sold at 20130124 with price = 16.795 	Pos: 614
# Bought at 20130205 with price = 16.47 	Pos: 626
# Sold at 20130207 with price = 16.278 	Pos: 626
# Bought at 20130212 with price = 17.615 	Pos: 578
# Sold at 20130220 with price = 17.132 	Pos: 578
# Bought at 20130227 with price = 16.859 	Pos: 586
# Sold at 20130228 with price = 16.712 	Pos: 586
# Bought at 20130301 with price = 16.773 	Pos: 584
# Sold at 20130312 with price = 17.163 	Pos: 584
# Bought at 20130314 with price = 17.195 	Pos: 582
# Sold at 20130315 with price = 16.934 	Pos: 582
# Bought at 20130320 with price = 17.154 	Pos: 574
# Sold at 20130321 with price = 17.097 	Pos: 574
# Bought at 20130322 with price = 17.427 	Pos: 562
# Sold at 20130401 with price = 17.523 	Pos: 562
# Bought at 20130402 with price = 17.872 	Pos: 551
# Sold at 20130405 with price = 17.583 	Pos: 551
# Bought at 20130411 with price = 17.738 	Pos: 546
# Sold at 20130415 with price = 17.533 	Pos: 546
# Bought at 20130423 with price = 17.335 	Pos: 551
# Sold at 20130424 with price = 17.221 	Pos: 551
# Bought at 20130425 with price = 17.246 	Pos: 550
# Sold at 20130430 with price = 17.747 	Pos: 550
# Bought at 20130501 with price = 17.63 	Pos: 553
# Sold at 20130510 with price = 18.208 	Pos: 553
# Bought at 20130514 with price = 18.369 	Pos: 548
# Sold at 20130516 with price = 18.248 	Pos: 548
# Bought at 20130604 with price = 17.313 	Pos: 577
# Sold at 20130605 with price = 17.017 	Pos: 577
# Bought at 20130607 with price = 17.407 	Pos: 563
# Sold at 20130610 with price = 17.104 	Pos: 563
# Bought at 20130618 with price = 17.123 	Pos: 562
# Sold at 20130620 with price = 16.577 	Pos: 562
# Bought at 20130625 with price = 17.087 	Pos: 545
# Sold at 20130717 with price = 18.705 	Pos: 545
# Bought at 20130719 with price = 19.226 	Pos: 529
# Sold at 20130725 with price = 18.607 	Pos: 529
# Bought at 20130731 with price = 19.444 	Pos: 506
# Sold at 20130806 with price = 19.012 	Pos: 506
# Bought at 20130829 with price = 18.078 	Pos: 532
# Sold at 20130905 with price = 18.172 	Pos: 532
# Bought at 20130911 with price = 18.626 	Pos: 518
# Sold at 20130918 with price = 18.905 	Pos: 518
# Bought at 20130919 with price = 18.887 	Pos: 518
# Sold at 20130920 with price = 18.719 	Pos: 518
# Bought at 20130927 with price = 18.865 	Pos: 514
# Sold at 20131008 with price = 19.127 	Pos: 514
# Bought at 20131010 with price = 19.264 	Pos: 509
# Sold at 20131023 with price = 20.158 	Pos: 509
# Bought at 20131024 with price = 20.456 	Pos: 501
# Sold at 20131029 with price = 20.355 	Pos: 501
# Bought at 20131101 with price = 20.759 	Pos: 491
# Sold at 20131105 with price = 20.423 	Pos: 491
# Bought at 20131108 with price = 20.45 	Pos: 490
# Sold at 20131111 with price = 20.183 	Pos: 490
# Bought at 20131114 with price = 20.364 	Pos: 485
# Sold at 20131118 with price = 20.176 	Pos: 485
# Bought at 20131119 with price = 20.346 	Pos: 481
# Sold at 20131120 with price = 20.109 	Pos: 481
# Bought at 20131122 with price = 21.104 	Pos: 458
# Sold at 20131202 with price = 21.015 	Pos: 458
# Bought at 20131210 with price = 21.055 	Pos: 456
# Sold at 20131211 with price = 20.696 	Pos: 456
# Bought at 20131218 with price = 21.43 	Pos: 440
# ======= from 20130101 to 20131231 =========
# If buy at 20130108 with price = 16.092
# and do nothing
# Current Profit: 3796.765433999999
# Current Profit with model: -212.0539724999653
# CAGR Performance: -40.09%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - CMCSA from 20140101
# Transforming Data... - CMCSA from 20140101
# Predicting... - CMCSA from 20140101
# Converting... - CMCSA from 20140101
# Backtesting... - CMCSA from 20140101
# Clearing trade_record...
# Start Iteration... - CMCSA from 20140101
# Start Backtesting...
# Bought at 20140108 with price = 22.649 	Pos: 441
# Sold at 20140113 with price = 22.491 	Pos: 441
# Bought at 20140115 with price = 23.153 	Pos: 428
# Sold at 20140121 with price = 22.807 	Pos: 428
# Bought at 20140128 with price = 22.812 	Pos: 427
# Sold at 20140129 with price = 22.82 	Pos: 427
# Bought at 20140130 with price = 22.693 	Pos: 429
# Sold at 20140203 with price = 22.658 	Pos: 429
# Bought at 20140204 with price = 22.781 	Pos: 426
# Sold at 20140205 with price = 23.009 	Pos: 426
# Bought at 20140206 with price = 23.278 	Pos: 421
# Sold at 20140213 with price = 22.697 	Pos: 421
# Bought at 20140228 with price = 21.876 	Pos: 436
# Sold at 20140307 with price = 22.122 	Pos: 436
# Bought at 20140320 with price = 21.705 	Pos: 444
# Sold at 20140321 with price = 21.501 	Pos: 444
# Bought at 20140331 with price = 21.643 	Pos: 441
# Sold at 20140404 with price = 21.554 	Pos: 441
# Bought at 20140416 with price = 21.059 	Pos: 451
# Sold at 20140506 with price = 22.379 	Pos: 451
# Bought at 20140519 with price = 21.846 	Pos: 462
# Sold at 20140612 with price = 22.642 	Pos: 462
# Bought at 20140618 with price = 22.702 	Pos: 460
# Sold at 20140623 with price = 22.554 	Pos: 460
# Bought at 20140625 with price = 22.873 	Pos: 453
# Sold at 20140707 with price = 23.288 	Pos: 453
# Bought at 20140709 with price = 23.462 	Pos: 449
# Sold at 20140717 with price = 23.644 	Pos: 449
# Bought at 20140723 with price = 23.738 	Pos: 447
# Sold at 20140725 with price = 23.548 	Pos: 447
# Bought at 20140729 with price = 23.834 	Pos: 441
# Sold at 20140731 with price = 23.124 	Pos: 441
# Bought at 20140808 with price = 23.152 	Pos: 440
# Sold at 20140819 with price = 23.459 	Pos: 440
# Bought at 20140820 with price = 23.6 	Pos: 437
# Sold at 20140821 with price = 23.578 	Pos: 437
# Bought at 20140825 with price = 23.647 	Pos: 435
# Sold at 20140827 with price = 23.534 	Pos: 435
# Bought at 20140829 with price = 23.63 	Pos: 433
# Sold at 20140917 with price = 24.662 	Pos: 433
# Bought at 20141003 with price = 23.307 	Pos: 458
# Sold at 20141006 with price = 23.063 	Pos: 458
# Bought at 20141008 with price = 23.756 	Pos: 444
# Sold at 20141010 with price = 22.696 	Pos: 444
# Bought at 20141020 with price = 22.414 	Pos: 449
# Sold at 20141104 with price = 23.798 	Pos: 449
# Bought at 20141105 with price = 23.864 	Pos: 448
# Sold at 20141107 with price = 23.96 	Pos: 448
# Bought at 20141114 with price = 23.429 	Pos: 457
# Sold at 20141121 with price = 23.559 	Pos: 457
# Bought at 20141124 with price = 24.133 	Pos: 446
# Sold at 20141204 with price = 24.419 	Pos: 446
# Bought at 20141217 with price = 24.025 	Pos: 453
# ======= from 20140101 to 20141231 =========
# If buy at 20140108 with price = 22.649
# and do nothing
# Current Profit: 1255.383895500001
# Current Profit with model: 1560.6327670000246
# CAGR Performance: 3.05%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - CMCSA from 20150101
# Transforming Data... - CMCSA from 20150101
# Predicting... - CMCSA from 20150101
# Converting... - CMCSA from 20150101
# Backtesting... - CMCSA from 20150101
# Clearing trade_record...
# Start Iteration... - CMCSA from 20150101
# Start Backtesting...
# Bought at 20150108 with price = 24.649 	Pos: 405
# Sold at 20150114 with price = 24.388 	Pos: 405
# Bought at 20150116 with price = 24.709 	Pos: 399
# Sold at 20150120 with price = 24.131 	Pos: 399
# Bought at 20150122 with price = 24.614 	Pos: 391
# Sold at 20150128 with price = 23.884 	Pos: 391
# Bought at 20150203 with price = 24.146 	Pos: 386
# Sold at 20150219 with price = 25.227 	Pos: 386
# Bought at 20150224 with price = 25.687 	Pos: 379
# Sold at 20150310 with price = 25.52 	Pos: 379
# Bought at 20150316 with price = 25.498 	Pos: 379
# Sold at 20150319 with price = 25.751 	Pos: 379
# Bought at 20150320 with price = 25.76 	Pos: 379
# Sold at 20150324 with price = 24.862 	Pos: 379
# Bought at 20150330 with price = 24.579 	Pos: 383
# Sold at 20150413 with price = 25.675 	Pos: 383
# Bought at 20150415 with price = 26.121 	Pos: 376
# Sold at 20150417 with price = 25.68 	Pos: 376
# Bought at 20150423 with price = 26.197 	Pos: 368
# Sold at 20150427 with price = 25.798 	Pos: 368
# Bought at 20150504 with price = 25.721 	Pos: 369
# Sold at 20150505 with price = 25.405 	Pos: 369
# Bought at 20150518 with price = 24.965 	Pos: 375
# Sold at 20150605 with price = 25.666 	Pos: 375
# Bought at 20150611 with price = 25.584 	Pos: 376
# Sold at 20150624 with price = 26.528 	Pos: 376
# Bought at 20150625 with price = 26.784 	Pos: 372
# Sold at 20150629 with price = 26.6 	Pos: 372
# Bought at 20150701 with price = 27.338 	Pos: 361
# Sold at 20150709 with price = 27.487 	Pos: 361
# Bought at 20150710 with price = 28.007 	Pos: 354
# Sold at 20150723 with price = 27.404 	Pos: 354
# Bought at 20150729 with price = 27.404 	Pos: 354
# Sold at 20150805 with price = 26.344 	Pos: 354
# Bought at 20150812 with price = 26.113 	Pos: 357
# Sold at 20150814 with price = 25.802 	Pos: 357
# Bought at 20150817 with price = 26.57 	Pos: 346
# Sold at 20150820 with price = 25.396 	Pos: 346
# Bought at 20150827 with price = 24.852 	Pos: 353
# Sold at 20150901 with price = 24.578 	Pos: 353
# Bought at 20150903 with price = 24.342 	Pos: 356
# Sold at 20150904 with price = 24.912 	Pos: 356
# Bought at 20150908 with price = 25.436 	Pos: 348
# Sold at 20150910 with price = 24.702 	Pos: 348
# Bought at 20150915 with price = 25.133 	Pos: 342
# Sold at 20150922 with price = 25.538 	Pos: 342
# Bought at 20150930 with price = 25.262 	Pos: 346
# Sold at 20151014 with price = 26.701 	Pos: 346
# Bought at 20151015 with price = 27.001 	Pos: 341
# Sold at 20151027 with price = 27.278 	Pos: 341
# Bought at 20151028 with price = 27.386 	Pos: 340
# Sold at 20151104 with price = 27.114 	Pos: 340
# Bought at 20151110 with price = 27.265 	Pos: 337
# Sold at 20151113 with price = 26.661 	Pos: 337
# Bought at 20151116 with price = 26.891 	Pos: 334
# Sold at 20151124 with price = 27.14 	Pos: 334
# Bought at 20151201 with price = 27.136 	Pos: 334
# Sold at 20151202 with price = 26.634 	Pos: 334
# Bought at 20151216 with price = 25.794 	Pos: 345
# Sold at 20151217 with price = 25.138 	Pos: 345
# Bought at 20151224 with price = 25.19 	Pos: 343
# Sold at 20151230 with price = 24.937 	Pos: 343
# ======= from 20150101 to 20151231 =========
# If buy at 20150108 with price = 24.649
# and do nothing
# Current Profit: 111.6485775000001
# Current Profit with model: -1426.1074279999757
# CAGR Performance: -15.38%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - CMCSA from 20160101
# Transforming Data... - CMCSA from 20160101
# Predicting... - CMCSA from 20160101
# Converting... - CMCSA from 20160101
# Backtesting... - CMCSA from 20160101
# Clearing trade_record...
# Start Iteration... - CMCSA from 20160101
# Start Backtesting...
# Bought at 20160114 with price = 23.617 	Pos: 423
# Sold at 20160115 with price = 24.284 	Pos: 423
# Bought at 20160121 with price = 24.595 	Pos: 417
# Sold at 20160125 with price = 23.952 	Pos: 417
# Bought at 20160126 with price = 24.334 	Pos: 410
# Sold at 20160127 with price = 24.136 	Pos: 410
# Bought at 20160129 with price = 24.397 	Pos: 405
# Sold at 20160202 with price = 25.118 	Pos: 405
# Bought at 20160203 with price = 25.775 	Pos: 394
# Sold at 20160209 with price = 25.743 	Pos: 394
# Bought at 20160216 with price = 25.573 	Pos: 397
# Sold at 20160223 with price = 25.278 	Pos: 397
# Bought at 20160224 with price = 25.765 	Pos: 389
# Sold at 20160226 with price = 25.758 	Pos: 389
# Bought at 20160301 with price = 26.121 	Pos: 383
# Sold at 20160307 with price = 26.084 	Pos: 383
# Bought at 20160314 with price = 26.005 	Pos: 384
# Sold at 20160318 with price = 26.452 	Pos: 384
# Bought at 20160324 with price = 26.39 	Pos: 384
# Sold at 20160407 with price = 27.423 	Pos: 384
# Bought at 20160418 with price = 27.784 	Pos: 379
# Sold at 20160420 with price = 27.255 	Pos: 379
# Bought at 20160506 with price = 27.398 	Pos: 377
# Sold at 20160513 with price = 27.354 	Pos: 377
# Bought at 20160520 with price = 27.34 	Pos: 376
# Sold at 20160606 with price = 28.192 	Pos: 376
# Bought at 20160616 with price = 28.107 	Pos: 377
# Sold at 20160617 with price = 28.004 	Pos: 377
# Bought at 20160628 with price = 28.326 	Pos: 372
# Sold at 20160714 with price = 30.191 	Pos: 372
# Bought at 20160719 with price = 29.95 	Pos: 375
# Sold at 20160726 with price = 30.476 	Pos: 375
# Bought at 20160727 with price = 30.26 	Pos: 377
# Sold at 20160729 with price = 30.119 	Pos: 377
# Bought at 20160801 with price = 30.225 	Pos: 376
# Sold at 20160802 with price = 29.945 	Pos: 376
# Bought at 20160805 with price = 29.985 	Pos: 375
# Sold at 20160808 with price = 30.031 	Pos: 375
# Bought at 20160810 with price = 30.05 	Pos: 374
# Sold at 20160819 with price = 29.652 	Pos: 374
# Bought at 20160901 with price = 29.662 	Pos: 374
# Sold at 20160909 with price = 29.021 	Pos: 374
# Bought at 20160915 with price = 29.484 	Pos: 367
# Sold at 20160926 with price = 29.385 	Pos: 367
# Bought at 20161003 with price = 29.646 	Pos: 364
# Sold at 20161004 with price = 29.678 	Pos: 364
# Bought at 20161108 with price = 27.82 	Pos: 388
# Sold at 20161128 with price = 30.736 	Pos: 388
# Bought at 20161129 with price = 31.445 	Pos: 379
# Sold at 20161202 with price = 30.969 	Pos: 379
# Bought at 20161207 with price = 31.039 	Pos: 377
# Sold at 20161228 with price = 31.59 	Pos: 377
# ======= from 20160101 to 20161231 =========
# If buy at 20160108 with price = 24.313
# and do nothing
# Current Profit: 2952.9706785000017
# Current Profit with model: 1928.7431325000307
# CAGR Performance: -10.24%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - CMCSA from 20170101
# Transforming Data... - CMCSA from 20170101
# Predicting... - CMCSA from 20170101
# Converting... - CMCSA from 20170101
# Backtesting... - CMCSA from 20170101
# Clearing trade_record...
# Start Iteration... - CMCSA from 20170101
# Start Backtesting...
# Bought at 20170109 with price = 31.813 	Pos: 314
# Sold at 20170125 with price = 32.94 	Pos: 314
# Bought at 20170126 with price = 34.008 	Pos: 304
# Sold at 20170202 with price = 33.922 	Pos: 304
# Bought at 20170210 with price = 33.875 	Pos: 304
# Sold at 20170217 with price = 34.265 	Pos: 304
# Bought at 20170314 with price = 33.806 	Pos: 307
# Sold at 20170317 with price = 33.814 	Pos: 307
# Bought at 20170330 with price = 33.712 	Pos: 308
# Sold at 20170405 with price = 33.729 	Pos: 308
# Bought at 20170406 with price = 34.614 	Pos: 300
# Sold at 20170410 with price = 34.082 	Pos: 300
# Bought at 20170418 with price = 34.219 	Pos: 298
# Sold at 20170503 with price = 34.726 	Pos: 298
# Bought at 20170508 with price = 35.457 	Pos: 292
# Sold at 20170512 with price = 35.185 	Pos: 292
# Bought at 20170519 with price = 35.303 	Pos: 291
# Sold at 20170608 with price = 37.024 	Pos: 291
# Bought at 20170613 with price = 37.467 	Pos: 287
# Sold at 20170620 with price = 36.552 	Pos: 287
# Bought at 20170628 with price = 35.801 	Pos: 293
# Sold at 20170629 with price = 35.546 	Pos: 293
# Bought at 20170710 with price = 35.193 	Pos: 295
# Sold at 20170718 with price = 35.666 	Pos: 295
# Bought at 20170719 with price = 35.736 	Pos: 294
# Sold at 20170726 with price = 36.474 	Pos: 294
# Bought at 20170731 with price = 36.701 	Pos: 292
# Sold at 20170803 with price = 36.192 	Pos: 292
# Bought at 20170808 with price = 35.918 	Pos: 294
# Sold at 20170817 with price = 36.448 	Pos: 294
# Bought at 20170821 with price = 37.183 	Pos: 288
# Sold at 20170823 with price = 37.065 	Pos: 288
# Bought at 20170830 with price = 37.144 	Pos: 287
# Sold at 20170907 with price = 34.93 	Pos: 287
# Bought at 20170921 with price = 33.866 	Pos: 296
# Sold at 20171002 with price = 34.465 	Pos: 296
# Bought at 20171003 with price = 34.986 	Pos: 291
# Sold at 20171006 with price = 34.657 	Pos: 291
# Bought at 20171019 with price = 33.936 	Pos: 297
# Sold at 20171023 with price = 33.426 	Pos: 297
# Bought at 20171027 with price = 33.417 	Pos: 297
# Sold at 20171030 with price = 33.307 	Pos: 297
# Bought at 20171107 with price = 33.307 	Pos: 297
# Sold at 20171117 with price = 32.934 	Pos: 297
# Bought at 20171128 with price = 33.06 	Pos: 295
# Sold at 20171208 with price = 34.758 	Pos: 295
# Bought at 20171212 with price = 36.047 	Pos: 284
# Sold at 20171219 with price = 35.943 	Pos: 284
# Bought at 20171220 with price = 36.019 	Pos: 283
# Sold at 20171228 with price = 36.584 	Pos: 283
# ======= from 20170101 to 20171231 =========
# If buy at 20170109 with price = 31.813
# and do nothing
# Current Profit: 1493.0993590000016
# Current Profit with model: 383.7712305000241
# CAGR Performance: -11.09%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - CMCSA from 20180101
# Transforming Data... - CMCSA from 20180101
# Predicting... - CMCSA from 20180101
# Converting... - CMCSA from 20180101
# Backtesting... - CMCSA from 20180101
# Clearing trade_record...
# Start Iteration... - CMCSA from 20180101
# Start Backtesting...
# Bought at 20180108 with price = 37.123 	Pos: 269
# Sold at 20180125 with price = 38.561 	Pos: 269
# Bought at 20180126 with price = 38.743 	Pos: 267
# Sold at 20180129 with price = 38.497 	Pos: 267
# Bought at 20180130 with price = 38.734 	Pos: 265
# Sold at 20180202 with price = 37.884 	Pos: 265
# Bought at 20180213 with price = 35.556 	Pos: 282
# Sold at 20180221 with price = 35.776 	Pos: 282
# Bought at 20180223 with price = 36.208 	Pos: 279
# Sold at 20180227 with price = 33.801 	Pos: 279
# Bought at 20180305 with price = 33.963 	Pos: 277
# Sold at 20180307 with price = 33.313 	Pos: 277
# Bought at 20180308 with price = 33.89 	Pos: 272
# Sold at 20180313 with price = 33.387 	Pos: 272
# Bought at 20180329 with price = 31.226 	Pos: 291
# Sold at 20180402 with price = 30.784 	Pos: 291
# Bought at 20180403 with price = 30.538 	Pos: 293
# Sold at 20180410 with price = 30.916 	Pos: 293
# Bought at 20180419 with price = 30.906 	Pos: 293
# Sold at 20180420 with price = 30.62 	Pos: 293
# Bought at 20180423 with price = 31.404 	Pos: 285
# Sold at 20180424 with price = 30.565 	Pos: 285
# Bought at 20180425 with price = 31.606 	Pos: 275
# Sold at 20180426 with price = 30.462 	Pos: 275
# Bought at 20180504 with price = 29.506 	Pos: 284
# Sold at 20180508 with price = 28.159 	Pos: 284
# Bought at 20180510 with price = 29.051 	Pos: 275
# Sold at 20180521 with price = 29.856 	Pos: 275
# ...
# Sold at 20161212 with price = 102.2 	Pos: 103
# ======= from 20160101 to 20161231 =========
# If buy at 20160108 with price = 69.933
# and do nothing
# Current Profit: 2874.368757
# Current Profit with model: 602.7585770000533
# CAGR Performance: -22.72%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - PVH from 20170101
# Transforming Data... - PVH from 20170101
# Predicting... - PVH from 20170101
# Converting... - PVH from 20170101
# Backtesting... - PVH from 20170101
# Clearing trade_record...
# Start Iteration... - PVH from 20170101
# Start Backtesting...
# Bought at 20170110 with price = 92.804 	Pos: 107
# Sold at 20170111 with price = 91.302 	Pos: 107
# Bought at 20170117 with price = 93.948 	Pos: 104
# Sold at 20170118 with price = 92.456 	Pos: 104
# Bought at 20170125 with price = 94.521 	Pos: 102
# Sold at 20170126 with price = 92.974 	Pos: 102
# Bought at 20170131 with price = 92.674 	Pos: 102
# Sold at 20170201 with price = 88.054 	Pos: 102
# Bought at 20170210 with price = 89.615 	Pos: 100
# Sold at 20170216 with price = 87.646 	Pos: 100
# Bought at 20170221 with price = 89.742 	Pos: 98
# Sold at 20170228 with price = 91.946 	Pos: 98
# Bought at 20170316 with price = 93.819 	Pos: 96
# Sold at 20170320 with price = 93.033 	Pos: 96
# Bought at 20170323 with price = 99.58 	Pos: 89
# Sold at 20170403 with price = 102.93 	Pos: 89
# Bought at 20170420 with price = 100.12 	Pos: 92
# Sold at 20170421 with price = 99.428 	Pos: 92
# Bought at 20170424 with price = 101.81 	Pos: 89
# Sold at 20170428 with price = 100.43 	Pos: 89
# Bought at 20170505 with price = 102.7 	Pos: 87
# Sold at 20170511 with price = 99.6 	Pos: 87
# Bought at 20170522 with price = 102.43 	Pos: 85
# Sold at 20170531 with price = 105.46 	Pos: 85
# Bought at 20170609 with price = 104.79 	Pos: 85
# Sold at 20170615 with price = 104.9 	Pos: 85
# Bought at 20170622 with price = 108.13 	Pos: 83
# Sold at 20170705 with price = 112.43 	Pos: 83
# Bought at 20170713 with price = 113.05 	Pos: 82
# Sold at 20170714 with price = 112.34 	Pos: 82
# Bought at 20170717 with price = 113.08 	Pos: 81
# Sold at 20170718 with price = 112.69 	Pos: 81
# Bought at 20170719 with price = 113.77 	Pos: 81
# Sold at 20170810 with price = 120.69 	Pos: 81
# Bought at 20170811 with price = 123.98 	Pos: 78
# Sold at 20170815 with price = 122.83 	Pos: 78
# Bought at 20170816 with price = 123.34 	Pos: 78
# Sold at 20170817 with price = 120.84 	Pos: 78
# Bought at 20170824 with price = 126.9 	Pos: 74
# Sold at 20170830 with price = 125.93 	Pos: 74
# Bought at 20170901 with price = 126.25 	Pos: 74
# Sold at 20170912 with price = 127.57 	Pos: 74
# Bought at 20170915 with price = 127.97 	Pos: 74
# Sold at 20170919 with price = 127.13 	Pos: 74
# Bought at 20170926 with price = 125.84 	Pos: 74
# Sold at 20170928 with price = 125.04 	Pos: 74
# Bought at 20170929 with price = 125.3 	Pos: 74
# Sold at 20171009 with price = 124.45 	Pos: 74
# Bought at 20171011 with price = 125.16 	Pos: 74
# Sold at 20171012 with price = 124.23 	Pos: 74
# Bought at 20171019 with price = 125.6 	Pos: 73
# Sold at 20171027 with price = 125.92 	Pos: 73
# Bought at 20171101 with price = 128.38 	Pos: 71
# Sold at 20171107 with price = 121.83 	Pos: 71
# Bought at 20171110 with price = 126.6 	Pos: 68
# Sold at 20171130 with price = 134.54 	Pos: 68
# Bought at 20171201 with price = 137.16 	Pos: 67
# Sold at 20171204 with price = 134.12 	Pos: 67
# Bought at 20171208 with price = 134.31 	Pos: 67
# Sold at 20171212 with price = 132.12 	Pos: 67
# Bought at 20171215 with price = 133.73 	Pos: 66
# Sold at 20171222 with price = 134.75 	Pos: 66
# Bought at 20171226 with price = 136.27 	Pos: 65
# ======= from 20170101 to 20171231 =========
# If buy at 20170109 with price = 92.186
# and do nothing
# Current Profit: 4848.973955999998
# Current Profit with model: -994.799732999958
# CAGR Performance: -58.44%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - PVH from 20180101
# Transforming Data... - PVH from 20180101
# Predicting... - PVH from 20180101
# Converting... - PVH from 20180101
# Backtesting... - PVH from 20180101
# Clearing trade_record...
# Start Iteration... - PVH from 20180101
# Start Backtesting...
# Bought at 20180108 with price = 141.32 	Pos: 70
# Sold at 20180202 with price = 149.77 	Pos: 70
# Bought at 20180212 with price = 145.52 	Pos: 72
# Sold at 20180213 with price = 145.46 	Pos: 72
# Bought at 20180214 with price = 150.06 	Pos: 70
# Sold at 20180220 with price = 145.95 	Pos: 70
# Bought at 20180221 with price = 148.19 	Pos: 69
# Sold at 20180227 with price = 147.5 	Pos: 69
# Bought at 20180309 with price = 142.41 	Pos: 71
# Sold at 20180315 with price = 141.98 	Pos: 71
# Bought at 20180316 with price = 143.07 	Pos: 71
# Sold at 20180319 with price = 142.05 	Pos: 71
# Bought at 20180320 with price = 144.03 	Pos: 70
# Sold at 20180322 with price = 141.57 	Pos: 70
# Bought at 20180326 with price = 144.35 	Pos: 68
# Sold at 20180419 with price = 159.2 	Pos: 68
# Bought at 20180423 with price = 160.51 	Pos: 67
# Sold at 20180424 with price = 158.87 	Pos: 67
# Bought at 20180426 with price = 159.89 	Pos: 67
# Sold at 20180501 with price = 153.67 	Pos: 67
# Bought at 20180508 with price = 151.03 	Pos: 68
# Sold at 20180529 with price = 155.33 	Pos: 68
# Bought at 20180531 with price = 161.32 	Pos: 65
# Sold at 20180613 with price = 161.76 	Pos: 65
# Bought at 20180618 with price = 161.0 	Pos: 66
# Sold at 20180619 with price = 159.77 	Pos: 66
# Bought at 20180709 with price = 149.28 	Pos: 70
# Sold at 20180716 with price = 147.62 	Pos: 70
# Bought at 20180717 with price = 150.15 	Pos: 69
# Sold at 20180727 with price = 152.88 	Pos: 69
# Bought at 20180806 with price = 152.08 	Pos: 69
# Sold at 20180815 with price = 148.39 	Pos: 69
# Bought at 20180820 with price = 151.58 	Pos: 68
# Sold at 20180830 with price = 141.72 	Pos: 68
# Bought at 20180911 with price = 137.66 	Pos: 70
# Sold at 20180918 with price = 137.97 	Pos: 70
# Bought at 20180919 with price = 140.65 	Pos: 68
# Sold at 20181002 with price = 137.04 	Pos: 68
# Bought at 20181016 with price = 129.16 	Pos: 72
# Sold at 20181018 with price = 125.88 	Pos: 72
# Bought at 20181025 with price = 118.82 	Pos: 77
# Sold at 20181026 with price = 119.75 	Pos: 77
# Bought at 20181031 with price = 120.15 	Pos: 76
# Sold at 20181107 with price = 123.43 	Pos: 76
# Bought at 20181108 with price = 125.54 	Pos: 75
# Sold at 20181109 with price = 121.22 	Pos: 75
# Bought at 20181121 with price = 110.35 	Pos: 82
# Sold at 20181204 with price = 105.37 	Pos: 82
# Bought at 20181219 with price = 91.318 	Pos: 95
# Sold at 20181224 with price = 86.633 	Pos: 95
# Bought at 20181226 with price = 90.251 	Pos: 91
# ======= from 20180101 to 20181231 =========
# If buy at 20180108 with price = 141.32
# and do nothing
# Current Profit: -3442.3662000000004
# Current Profit with model: -1544.0691279999774
# CAGR Performance: 18.98%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - PVH from 20190101
# Transforming Data... - PVH from 20190101
# Predicting... - PVH from 20190101
# Converting... - PVH from 20190101
# Backtesting... - PVH from 20190101
# Clearing trade_record...
# Start Iteration... - PVH from 20190101
# Start Backtesting...
# Bought at 20190108 with price = 102.49 	Pos: 97
# Sold at 20190122 with price = 105.78 	Pos: 97
# Bought at 20190125 with price = 106.58 	Pos: 96
# Sold at 20190228 with price = 115.98 	Pos: 96
# Bought at 20190311 with price = 111.94 	Pos: 100
# Sold at 20190315 with price = 110.16 	Pos: 100
# Bought at 20190325 with price = 109.98 	Pos: 100
# Sold at 20190403 with price = 124.04 	Pos: 100
# Bought at 20190404 with price = 127.91 	Pos: 96
# Sold at 20190425 with price = 129.59 	Pos: 96
# Bought at 20190426 with price = 130.13 	Pos: 96
# Sold at 20190430 with price = 129.21 	Pos: 96
# Bought at 20190522 with price = 108.41 	Pos: 114
# Sold at 20190523 with price = 107.48 	Pos: 114
# Bought at 20190604 with price = 91.425 	Pos: 134
# Sold at 20190606 with price = 87.625 	Pos: 134
# Bought at 20190613 with price = 89.14 	Pos: 132
# Sold at 20190614 with price = 87.455 	Pos: 132
# Bought at 20190618 with price = 89.469 	Pos: 129
# Sold at 20190619 with price = 88.892 	Pos: 129
# Bought at 20190620 with price = 90.236 	Pos: 127
# Sold at 20190702 with price = 93.857 	Pos: 127
# Bought at 20190715 with price = 90.496 	Pos: 131
# Sold at 20190718 with price = 88.074 	Pos: 131
# Bought at 20190724 with price = 89.1 	Pos: 130
# Sold at 20190729 with price = 88.642 	Pos: 130
# Bought at 20190819 with price = 71.193 	Pos: 162
# Sold at 20190823 with price = 69.677 	Pos: 162
# Bought at 20190828 with price = 77.388 	Pos: 145
# Sold at 20190917 with price = 87.594 	Pos: 145
# Bought at 20190927 with price = 87.814 	Pos: 145
# Sold at 20191001 with price = 84.391 	Pos: 145
# Bought at 20191010 with price = 85.02 	Pos: 143
# Sold at 20191017 with price = 85.869 	Pos: 143
# Bought at 20191021 with price = 89.27 	Pos: 138
# Sold at 20191028 with price = 89.21 	Pos: 138
# Bought at 20191101 with price = 90.796 	Pos: 135
# Sold at 20191113 with price = 96.941 	Pos: 135
# Bought at 20191114 with price = 98.339 	Pos: 133
# Sold at 20191120 with price = 97.541 	Pos: 133
# Bought at 20191122 with price = 100.49 	Pos: 129
# Sold at 20191127 with price = 96.681 	Pos: 129
# Bought at 20191204 with price = 97.949 	Pos: 127
# Sold at 20191219 with price = 105.1 	Pos: 127
# Bought at 20191220 with price = 105.09 	Pos: 127
# Sold at 20191223 with price = 104.87 	Pos: 127
# ======= from 20190101 to 20191231 =========
# If buy at 20190108 with price = 102.49
# and do nothing
# Current Profit: 123.06923500000084
# Current Profit with model: 3381.017520500038
# CAGR Performance: 32.58%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - PVH from 20200101
# Transforming Data... - PVH from 20200101
# Predicting... - PVH from 20200101
# Converting... - PVH from 20200101
# Backtesting... - PVH from 20200101
# Clearing trade_record...
# Start Iteration... - PVH from 20200101
# Start Backtesting...
# Bought at 20200108 with price = 106.34 	Pos: 93
# Sold at 20200109 with price = 103.07 	Pos: 93
# Bought at 20200116 with price = 99.79 	Pos: 97
# Sold at 20200123 with price = 96.96 	Pos: 97
# Bought at 20200130 with price = 90.882 	Pos: 103
# Sold at 20200131 with price = 87.429 	Pos: 103
# Bought at 20200205 with price = 90.453 	Pos: 99
# Sold at 20200207 with price = 85.763 	Pos: 99
# Bought at 20200212 with price = 88.437 	Pos: 96
# Sold at 20200219 with price = 85.843 	Pos: 96
# Bought at 20200220 with price = 85.733 	Pos: 96
# Sold at 20200221 with price = 80.273 	Pos: 96
# Bought at 20200304 with price = 71.121 	Pos: 109
# Sold at 20200305 with price = 67.867 	Pos: 109
# Bought at 20200324 with price = 36.49 	Pos: 203
# Sold at 20200331 with price = 35.301 	Pos: 203
# Bought at 20200406 with price = 43.644 	Pos: 164
# Sold at 20200415 with price = 42.076 	Pos: 164
# Bought at 20200424 with price = 42.126 	Pos: 163
# Sold at 20200501 with price = 43.044 	Pos: 163
# Bought at 20200508 with price = 44.753 	Pos: 157
# Sold at 20200511 with price = 44.384 	Pos: 157
# Bought at 20200518 with price = 43.904 	Pos: 158
# Sold at 20200519 with price = 42.316 	Pos: 158
# Bought at 20200520 with price = 42.136 	Pos: 159
# Sold at 20200529 with price = 45.463 	Pos: 159
# Bought at 20200603 with price = 54.486 	Pos: 132
# Sold at 20200610 with price = 53.756 	Pos: 132
# Bought at 20200629 with price = 48.551 	Pos: 146
# Sold at 20200701 with price = 48.301 	Pos: 146
# Bought at 20200713 with price = 45.263 	Pos: 156
# Sold at 20200720 with price = 47.991 	Pos: 156
# Bought at 20200723 with price = 50.708 	Pos: 148
# Sold at 20200730 with price = 50.129 	Pos: 148
# Bought at 20200805 with price = 51.748 	Pos: 143
# Sold at 20200817 with price = 54.116 	Pos: 143
# Bought at 20200824 with price = 54.456 	Pos: 142
# Sold at 20200918 with price = 66.146 	Pos: 142
# Bought at 20201002 with price = 62.838 	Pos: 149
# Sold at 20201013 with price = 62.498 	Pos: 149
# Bought at 20201022 with price = 65.826 	Pos: 141
# Sold at 20201026 with price = 62.089 	Pos: 141
# Bought at 20201103 with price = 62.169 	Pos: 141
# Sold at 20201106 with price = 66.106 	Pos: 141
# Bought at 20201109 with price = 71.241 	Pos: 131
# Sold at 20201112 with price = 66.565 	Pos: 131
# Bought at 20201113 with price = 73.939 	Pos: 118
# Sold at 20201130 with price = 82.282 	Pos: 118
# Bought at 20201202 with price = 83.271 	Pos: 116
# Sold at 20201222 with price = 92.214 	Pos: 116
# Bought at 20201223 with price = 94.542 	Pos: 113
# ======= from 20200101 to 20201231 =========
# If buy at 20200108 with price = 106.34
# and do nothing
# Current Profit: -1104.0188099999996
# Current Profit with model: 725.6498930000198
# CAGR Performance: 18.3%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - PVH from 20210101
# Transforming Data... - PVH from 20210101
# Predicting... - PVH from 20210101
# Converting... - PVH from 20210101
# Backtesting... - PVH from 20210101
# Clearing trade_record...
# Start Iteration... - PVH from 20210101
# Start Backtesting...
# Bought at 20210108 with price = 101.75 	Pos: 98
# Sold at 20210114 with price = 99.97 	Pos: 98
# Bought at 20210203 with price = 88.287 	Pos: 111
# Sold at 20210217 with price = 92.563 	Pos: 111
# Bought at 20210222 with price = 97.2 	Pos: 105
# Sold at 20210304 with price = 100.57 	Pos: 105
# Bought at 20210305 with price = 105.44 	Pos: 100
# Sold at 20210316 with price = 106.15 	Pos: 100
# Bought at 20210326 with price = 101.06 	Pos: 105
# Sold at 20210329 with price = 97.42 	Pos: 105
# Bought at 20210330 with price = 100.51 	Pos: 102
# Sold at 20210407 with price = 102.4 	Pos: 102
# Bought at 20210408 with price = 105.02 	Pos: 99
# Sold at 20210415 with price = 108.43 	Pos: 99
# Bought at 20210421 with price = 108.18 	Pos: 99
# Sold at 20210510 with price = 112.74 	Pos: 99
# Bought at 20210514 with price = 113.28 	Pos: 99
# Sold at 20210520 with price = 110.49 	Pos: 99
# Bought at 20210526 with price = 116.05 	Pos: 94
# Sold at 20210602 with price = 110.76 	Pos: 94
# Bought at 20210608 with price = 112.77 	Pos: 92
# Sold at 20210610 with price = 109.39 	Pos: 92
# Bought at 20210611 with price = 112.54 	Pos: 89
# Sold at 20210614 with price = 108.95 	Pos: 89
# Bought at 20210623 with price = 107.65 	Pos: 90
# Sold at 20210629 with price = 104.95 	Pos: 90
# Bought at 20210701 with price = 109.9 	Pos: 86
# Sold at 20210706 with price = 105.59 	Pos: 86
# Bought at 20210709 with price = 105.93 	Pos: 86
# Sold at 20210713 with price = 106.28 	Pos: 86
# Bought at 20210720 with price = 100.62 	Pos: 91
# Sold at 20210728 with price = 103.39 	Pos: 91
# Bought at 20210729 with price = 103.35 	Pos: 91
# Sold at 20210817 with price = 105.71 	Pos: 91
# Bought at 20210823 with price = 107.47 	Pos: 89
# Sold at 20210826 with price = 105.81 	Pos: 89
# Bought at 20210827 with price = 109.48 	Pos: 86
# Sold at 20210830 with price = 105.98 	Pos: 86
# Bought at 20210901 with price = 121.27 	Pos: 75
# Sold at 20210908 with price = 108.62 	Pos: 75
# Bought at 20210916 with price = 109.3 	Pos: 75
# Sold at 20210920 with price = 108.09 	Pos: 75
# Bought at 20210923 with price = 109.9 	Pos: 73
# Sold at 20210929 with price = 108.74 	Pos: 73
# Bought at 20211005 with price = 105.54 	Pos: 75
# Sold at 20211006 with price = 107.04 	Pos: 75
# Bought at 20211007 with price = 106.34 	Pos: 76
# Sold at 20211008 with price = 104.5 	Pos: 76
# Bought at 20211012 with price = 107.1 	Pos: 74
# Sold at 20211027 with price = 109.54 	Pos: 74
# Bought at 20211101 with price = 113.63 	Pos: 71
# Sold at 20211110 with price = 121.25 	Pos: 71
# Bought at 20211111 with price = 122.21 	Pos: 70
# Sold at 20211112 with price = 121.4 	Pos: 70
# Bought at 20211116 with price = 122.94 	Pos: 70
# Sold at 20211118 with price = 118.9 	Pos: 70
# Bought at 20211123 with price = 117.77 	Pos: 70
# Sold at 20211124 with price = 113.19 	Pos: 70
# Bought at 20211207 with price = 104.02 	Pos: 76
# Sold at 20211210 with price = 101.15 	Pos: 76
# Bought at 20211221 with price = 98.7 	Pos: 78
# ======= from 20210101 to 20211231 =========
# If buy at 20210108 with price = 101.75
# and do nothing
# Current Profit: 365.4542500000007
# Current Profit with model: -1704.4597399999639
# CAGR Performance: -20.7%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Backtesting Completed...
