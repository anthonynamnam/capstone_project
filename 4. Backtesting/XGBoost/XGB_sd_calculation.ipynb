# %%
import pandas as pd

# %%
backtest_summary = pd.read_csv("backtest_summary_Xgb.csv")

# %%
backtest_summary
# Out:
#      Unnamed: 0        Sector              Stock  Range_Start  Range_End  \
# 0             0    BlockChain    Xgb_BlockChain-     20210101   20211231
# 1             1    BlockChain    Xgb_BlockChain-     20120101   20121231
# 2             2    BlockChain    Xgb_BlockChain-     20130101   20131231
# 3             3    BlockChain    Xgb_BlockChain-     20140101   20141231
# 4             4    BlockChain    Xgb_BlockChain-     20150101   20151231
# ..          ...           ...                ...          ...        ...
# 446         446  Luxury goods  Xgb_Luxury goods-     20170101   20171231
# 447         447  Luxury goods  Xgb_Luxury goods-     20180101   20181231
# 448         448  Luxury goods  Xgb_Luxury goods-     20190101   20191231
# 449         449  Luxury goods  Xgb_Luxury goods-     20200101   20201231
# 450         450  Luxury goods  Xgb_Luxury goods-     20210101   20211231
#
#      Buy&Hold_Profit  WithModel_Profit  Buy&Hold_CAGR(in %)  \
# ...
