# %% [markdown]
# # Import Libraried and packages

# %%
from google.colab import drive
drive.mount('/content/drive')


volatility_folder = "/content/drive/MyDrive/fyp/Final report/4. Backtesting/Volatility_result/"
backtest_summary_folder = volatility_folder + "backtest_summary/"
record_folder = volatility_folder + "trade_record/"
user_test_folder = volatility_folder + "user_test/"
model_folder = "/content/drive/MyDrive/fyp/Final report/4. Backtesting/XGBoost/"
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import floor
import pickle

import torch.nn as nn
import os.path as osp
import torch.utils.data as data
import torch.nn.functional as F

from tqdm import tqdm
import time, matplotlib, torch, os
from statsmodels.tsa.arima_model import ARIMA
from torch.utils.tensorboard import SummaryWriter
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import os
from os import walk

import plotly
# %matplotlib inline
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from datetime import datetime
#import seaborn as sns

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
#For DNN / CNN+LSTM
import keras.backend as K
from keras.models import Sequential
from keras.layers import Conv1D, LSTM, Flatten, Dense

# %%
# !pip install -q stockstats

# %% [markdown]
# # Backtesting Setting

# %%
start_date = []
num_period = 10
period_year = 1

start = 2022-(num_period+period_year-1)
for i in range(num_period):
    start_date.append((start+i)*10000+101)


date_range_list={}
for i in start_date:
    date_range_list[i] = (i-101)+(period_year-1)*10000+1231

print(date_range_list)

stock_list = {"BlockChain":["COIN","NVDA","FB"],
              "Airline":["BA","GD","LMT",],
              "Traveling":["UBER","ABNB","MAR","BKNG"],
              "Semiconductors":["INTC","NVDA","QCOM","MU","AMD"],
              "Cloud Computing":["IBM", "AMZN","GOOG","CRM"],
              "Social Media":["TWTR","SNAP","PINS","FB"],
              "Entertainment":["DIS","NFLX","FB"],
              "Retail":["WMT","COST","TGT","BBY","HD"],
              "Franchise":["MCD", "YUM", "SBUX", "DPZ"],
              "Real Estate":["HST", "EQR", "AVB", "PLD", "SPG"],
              "Telecommunication":["T","TMUS","VZ","CMCSA","CHTR"],
              "Energy & Resources":["DOW", "DD"],
              "Luxury goods":["RACE","EL","PVH"]
                            }

start_date = "2000-01-01"
end_date = "2022-12-31"


do_nth_name = "Buy&Hold"
model_name = "WithModel"

backtest_col = ["Sector","Stock",
                "Range_Start","Range_End",
                do_nth_name+"_Profit",model_name+"_Profit",
                do_nth_name+"_CAGR(in %)",model_name+"_CAGR(in %)",
                "CAGR_Performance(in %)",
                do_nth_name+"_MDD(in %)",model_name+"_MDD(in %)",
                "MDD_Performance(in %)"]
# Out:
# {20120101: 20121231, 20130101: 20131231, 20140101: 20141231, 20150101: 20151231, 20160101: 20161231, 20170101: 20171231, 20180101: 20181231, 20190101: 20191231, 20200101: 20201231, 20210101: 20211231}

# %% [markdown]
# # Backtesting Module

# %%
################### Input ##########################
# For hist_price_data: index=["date"], columns = ["Open"]
# For pred_action: index=["date"], columns = ["Action"] (Buy/Sell)
################### Output #########################
# 1. trading record
# 2. total profit
class backtest:
    hpd = ""
    pred_action=pd.DataFrame()
    trade_record=pd.DataFrame(index=[],
                              columns=["Action","Price","Position","Cash","Pos_Bal","Cash_Bal","Cum_Profit","Total_Bal"],
                             )
    capital = 0
    cash_balance = 0
    profit = 0
    handle_fee = 0
    position = 0
    last_price = 0
    do_nth_profit = 0
    num_year = 0
    _tested = False
    
    _stock_trough = 0
    _stock_peak = 0
    _stock_all_time_low = 0
    _stock_all_time_high = 0
    
    _portfolio_trough = 0
    _portfolio_peak = 0
    _portfolio_all_time_low = 0
    _portfolio_all_time_high = 0
    
    def __init__(self,hist_price_data,pred_action,capital,handling_fee,num_year=1):
        self.hpd = hist_price_data
        self.pred_action = pred_action
        self.capital = capital
        self.cash_balance = capital
        self._portfolio_trough = capital
        self._portfolio_peak = capital
        self._portfolio_all_time_low = capital
        self._portfolio_all_time_high = capital
        self.handle_fee = handling_fee
        self.num_year = num_year  
        
    def clear_trade_record(self,sec):
        self.trade_record=pd.DataFrame(index=[],
                                       columns=["Action","Price","Position","Cash","Pos_Bal","Cash_Bal","Cum_Profit","Total_Bal"],
                                       )
        print("Clearing trade_record...")
        time.sleep(sec)
        
    def start_test(self): 
        if not self._tested:
            status = "sell"
            self._tested = True
            print("Start Backtesting...")  
            self._stock_all_time_low = self.hpd.iloc[0,0]
            self._stock_all_time_high = self.hpd.iloc[0,0]
            self._stock_trough = self.hpd.iloc[0,0]
            self._stock_peak = self.hpd.iloc[0,0]
            # For loop to iterate the data
            for ind in self.pred_action.index:
                # Update latest price
                self.last_price = self.hpd.loc[ind,"Open"]
                
                # Mark All Time Low,High , Trough and Peak for MDD of stock price (using "Buy&Hold")
                if self.last_price > self._stock_all_time_high:
                    self._stock_all_time_high = self.last_price
                if self.last_price < self._stock_all_time_low:
                    self._stock_all_time_low = self.last_price
                if self.last_price > self._stock_all_time_low and self._stock_trough != self._stock_all_time_low:
                    self._stock_trough = self._stock_all_time_low
                if self.last_price < self._stock_all_time_high and self._stock_peak != self._stock_all_time_high:
                    self._stock_peak = self._stock_all_time_high
                
                # Do the action
                if self.pred_action.loc[ind,"Action"].lower() == "buy" and status == "sell":
                    self._buy(ind,self.last_price)
                    status = "buy"
                elif self.pred_action.loc[ind,"Action"].lower() == "sell" and status == "buy":
                    self._sell(ind,self.last_price)
                    status = "sell"
                else:
                    self._hold(ind,self.last_price) # newly added
                    
                
                curr_portfolio_val = self.get_capital()+self.get_profit()
                
                # Mark All Time Low,High , Trough and Peak for MDD of our portfolio balance (using our model)
                if curr_portfolio_val > self._portfolio_all_time_high:
                    self._portfolio_all_time_high = curr_portfolio_val
                if curr_portfolio_val < self._portfolio_all_time_low:
                    self._portfolio_all_time_low = curr_portfolio_val
                if curr_portfolio_val > self._portfolio_all_time_low and self._portfolio_trough != self._portfolio_all_time_low:
                    self._portfolio_trough = self._portfolio_all_time_low
                if curr_portfolio_val < self._portfolio_all_time_high and self._portfolio_peak != self._portfolio_all_time_high:
                    self._portfolio_peak = self._portfolio_all_time_high
                            
            # =================================================
            self._run_do_nothing() # Calculate do nothing profit
        else:
            print("Backtesting has been completed...")
              
                
        
    def _mark_down_record(self,date,action,price,pos_delta,cash_delta):
        self.trade_record.loc[date] = [action,price,pos_delta,cash_delta,
                                       round(self.position,4),round(self.cash_balance,3),
                                       round(self.get_profit(),3),round(self.get_amount(),3)]
        
    def _buy(self,date,price):
        # Assume use all money to buy all
        buy_pos = floor(self.cash_balance / price)
        for i in range(buy_pos+1):
            act_buy_pos = buy_pos - i
            if act_buy_pos == 0:
                #print("You do not have enough money to buy!")
                return
            total_amt = act_buy_pos*price*(1+self.handle_fee)
            if self.cash_balance > total_amt:
                self.position += act_buy_pos
                self.cash_balance -= total_amt
                self._mark_down_record(date,
                                       "Buy",
                                       price,
                                       act_buy_pos,
                                       -total_amt)
                print("Bought at",date,"with price =", price, "\tPos:", act_buy_pos)
                return
        
    
    def _sell(self,date,price):
        # Assume sell all position
        sell_pos = self.position
        total_amt = sell_pos*price*(1-self.handle_fee)
        if self.position >= 1:
            self.position -= sell_pos
            self.cash_balance += total_amt
            self._mark_down_record(date,
                                   "Sell",
                                   price,
                                   -sell_pos,
                                   total_amt)
            print("Sold at",date,"with price =", price, "\tPos:", sell_pos)
            
            return
        
    def _hold(self,date,price): # newly added
        self._mark_down_record(date,"Hold",price,0,0)

    def _run_do_nothing(self):
        balance = self.capital
        first_day_price = self.hpd.iloc[0,0]
        last_day_price = self.hpd.iloc[-1,0]
        buy_pos = floor(self.capital / first_day_price) # Calculate how many position can buy
        total_amt = buy_pos*first_day_price*(1+self.handle_fee) # Check if okay to buy (including fee)
        while self.capital < total_amt: # If not enough, reduce buy_pos by 1
            buy_pos -= 1
            total_amt = buy_pos*first_day_price*(1+self.handle_fee)
        position = buy_pos # Buy in 
        balance -= total_amt
        self.do_nth_profit = last_day_price*position+balance-self.capital

    def get_performance(self):
        if self._tested:
            model_profit = self.get_profit()
            do_nth_profit = self.get_do_nothing()
            perf = (model_profit-do_nth_profit)/abs(do_nth_profit)
            return perf
        else:
            print("No Backtesting Record.")

    def get_do_nothing(self):
        if self._tested:
            return self.do_nth_profit
        else:
            print("No Backtesting Record.")

    def get_profit(self):
        if self._tested:
            return self.get_cash_balance()+self.get_last_price()*self.get_position()-self.get_capital()
        else:
            print("No Backtesting Record.")

    def get_last_price(self):
        if self._tested:
            return self.last_price
        else:
            print("No Backtesting Record.")
    
    def get_position(self):
        if self._tested:
            return self.position
        else:
            print("No Backtesting Record.")
    
    def get_do_nothing_CAGR(self):
        if self._tested:
            start_bal = self.get_capital()
            end_bal = self.get_do_nothing()+self.get_capital()
            num_year = self.get_num_year()
            return pow(end_bal/start_bal,1/num_year)-1
        else:
            print("No Backtesting Record.")
            
    def get_model_CAGR(self):
        if self._tested:
            start_bal = self.get_capital()
            end_bal = self.get_profit()+self.get_capital()
            num_year = self.get_num_year()
            return pow(end_bal/start_bal,1/num_year)-1
        else:
            print("No Backtesting Record.")
            
    def get_diff_in_CAGR(self):
        if self._tested:
            return self.get_model_CAGR() - self.get_do_nothing_CAGR()
        else:
            print("No Backtesting Record.")
    
    def get_do_nothing_MDD(self):
        if self._tested:
            return (self._stock_trough-self._stock_peak)/self._stock_peak
        else:
            print("No Backtesting Record.")
            
    def get_model_MDD(self):
        if self._tested:
            return (self._portfolio_trough-self._portfolio_peak)/self._portfolio_peak
        else:
            print("No Backtesting Record.")
            
    def get_diff_in_MDD(self):
        if self._tested:
            return self.get_model_MDD() - self.get_do_nothing_MDD()
        else:
            print("No Backtesting Record.")
    
    def get_num_year(self):
        return self.num_year
    
    def get_cash_balance(self):
        return self.cash_balance
    
    def get_capital(self):
        return self.capital
    
    def get_amount(self):
        return self.get_capital()+self.get_profit()

    def print_do_nothing(self):
        if self._tested:
            print("If buy at", self.hpd.index[0],"with price =",self.hpd.iloc[0,0])
            print("and do nothing")
            print("Current Profit:",self.get_do_nothing())
        else:
            print("No Backtesting Record.")
            
    def print_performance(self):
        if self._tested:
            print("Performance:", str(round(self.get_performance()*100,2))+"%")
        else:
            print("No Backtesting Record.")
            
    def print_CAGR_performance(self):
        if self._tested:
            print("CAGR Performance:", str(round(self.get_diff_in_CAGR()*100,2))+"%")
        else:
            print("No Backtesting Record.")
    
    def print_trade_record(self):
        if self._tested:
            print(self.trade_record)
        else:
            print("No Backtesting Record.")
            print(self.trade_record)
    
    def print_profit(self):
        if self._tested:
            print("Current Profit with model:",self.get_profit())
        else:
            print("No Backtesting Record.")
    
    def export_trade_record(self,stock,add_msg = ""):
        if self._tested:
            # Save the trade record to the path
            if not add_msg == "":
                add_msg = "_" + add_msg
            self.trade_record = self.trade_record.sort_index()
            self.trade_record.to_csv(record_folder+stock+add_msg+".csv")
            print("Trade record exported.")
        else:
            print("No Backtesting Record.")

# %%
def get_last_n_day_mean(df,n):
    series = df["open"]
    windows = series.rolling(n)
    n_days_averages = windows.mean()
    n_days_list = n_days_averages.tolist()
    final_list = n_days_list[n:]
    new_df = pd.DataFrame(final_list,columns=["mean_"+str(n)],index=df.index[n:])
    return new_df

# %% [markdown]
# # Load stock data from API

# %%
import pandas_datareader.data as web
from stockstats import StockDataFrame

#Setting the index values as timestamp
def process(code):
  print("Enter the code of the model that you want to implement")
  #code = input()
  #final_code = '^'+code
  final_code = code
  start_date = "2012-01-01"
  end_date = "2021-12-31"
  stock = web.DataReader(final_code , 'stooq',start=start_date, end=end_date)
  stock.columns = ["open","high","low","close","volume"]
  
  # Use online package to generate additional features
  x = StockDataFrame(stock)
  stock = x[['open','high','low','close','volume',
          'boll', 'boll_ub', 'boll_lb',
          'macd', 'macdh', 'macds',
          'rsi_11', 'rsi_14', 'rsi_21']]
  stock.index = [int(str(ind)[0:4]+str(ind)[5:7]+str(ind)[8:10]) for ind in stock.index]
  stock = stock.sort_index()

  return stock

# %%
stock = process("IBM")
# Out:
# Enter the code of the model that you want to implement

# %%
stock
# Out:
#             open    high     low   close   volume      boll     boll_ub  \
# 20120103  128.88  130.23  128.38  128.58  8180058  128.1790  134.932612
# 20120104  128.10  128.60  127.63  128.07  6297526  128.3965  135.476771
# 20120105  127.56  127.71  126.38  127.46  6466200  128.6025  135.879775
# 20120106  127.28  127.34  125.83  125.98  7094969  128.9115  136.502568
# 20120109  125.76  125.80  124.42  125.33  7535572  129.2665  136.943913
# ...          ...     ...     ...     ...      ...       ...         ...
# 20211227  129.08  130.08  128.40  130.05  4346229  131.4500  133.282321
# 20211228  130.03  131.63  130.02  131.05  3488601  131.8000  132.899939
# 20211229  130.82  132.61  130.73  131.76  4291007  132.0500  132.611070
# 20211230  132.16  132.77  131.74  132.32  3196152  132.1950  132.548553
# 20211231  132.41  133.38  132.02  132.07  3402558  132.0700         NaN
#
#              boll_lb      macd     macdh     macds      rsi_11      rsi_14  \
# 20120103  121.425388 -1.811274  0.489102 -2.300376   51.281366   47.190995
# 20120104  121.316229 -2.091832  0.330819 -2.422652   48.488535   44.808561
# 20120105  121.325225 -2.367574  0.137783 -2.505356   45.064237   41.897279
# 20120106  121.320432 -2.622973 -0.083171 -2.539802   35.625325   34.061158
# 20120109  121.589087 -2.760113 -0.241104 -2.519009   30.883945   30.223364
# ...              ...       ...       ...       ...         ...         ...
# 20211227  129.617679 -0.099397 -0.058552 -0.040846    8.180361    8.545592
# 20211228  130.700061 -0.042801 -0.026749 -0.016052   14.491914   14.911940
# 20211229  131.488930 -0.010219 -0.007870 -0.002349   28.868360   29.305681
# 20211230  131.841447  0.005609  0.002493  0.003116  100.000000  100.000000
# 20211231         NaN  0.000000  0.000000  0.000000         NaN         NaN
#
#               rsi_21
# 20120103   42.920670
# 20120104   41.192557
# 20120105   39.091982
# 20120106   33.612565
# 20120109   31.016798
# ...              ...
# 20211227    8.997984
# 20211228   15.424720
# 20211229   29.832936
# 20211230  100.000000
# 20211231         NaN
#
# [2517 rows x 14 columns]

# %% [markdown]
# # Data preprocessing for regression models

# %%
from datetime import datetime
def standard_date_format(date_in_num):
    date = str(date_in_num)
    return datetime.strptime(date,'%Y%m%d').strftime('%Y-%m-%d')

# %%
def convert_prediction(X,y,pred):

    print("a")
    col_list =[] 
    for col in X.columns:
        if "open" in col:
            col_list.append(col)
    print("b")
    
    mean_5_day = np.mean(X.loc[:,col_list],axis=1)
    mean_5_day.index = y.index
    std_5_day = np.std(X.loc[:,col_list],axis=1)
    std_5_day.index = y.index
    a = pd.DataFrame(index = y.index,columns=['mean','std','pred'])
    a.loc[:,"mean"] = mean_5_day
    a.loc[:,"std"] = std_5_day
    a.loc[:,"pred"] = pred
    a.loc[:,"converted"] = pred*std_5_day+mean_5_day
    return a["converted"]

# %%
def convert_decision(stock_,pred):
    h = np.array(pred)
    action = []
    status = "N"
    five_sma = stock_['open'].rolling(window=5,min_periods=1).mean()

    ind_sma = five_sma.index
    ind_pred = pred.index
    union_ind = list(ind_sma.intersection(ind_pred))

    five_sma = five_sma.filter(items = union_ind)
    pred = pred.filter(items = union_ind)

    for i in range(len(union_ind)):
      
        if pred.iloc[i] >= five_sma.iloc[i]:
            if status == "N":
                action.append("Buy")
                status = "Buy"
            else:
                action.append("Hold")
        else:
            if status == "Buy":
                action.append("Sell")
                status = "N"
            else:
                action.append("Hold")

    result = (pd.DataFrame(action,
                         columns=["Action"], index = pred.index))
                
    return result

# %%
# Split the train and test data
def custom_split(data,start,end):
    train = (data.index >= start) & (data.index <= end)
    train_X = data[train]
    
    return train_X

# %% [markdown]
#  Split the train and test data

# %%
train_X = custom_split(stock,start = 20130101,end = 20171031)
valid_X = custom_split(stock,start = 20171101,end = 20181231)
test_X = custom_split(stock,start = 20190101,end = 20201231)

# %% [markdown]
# Label the target result (opening price on 11th day)

# %%
# Assume we use 10 days price data to predict closing price of the 11th day
num_day_to_predict = 5

# %%
def produce_result_target_price(X,num_day = 5,result_col_name = "result_price"):
    y = pd.DataFrame(np.nan, index=X.index, columns=[result_col_name])
    for i in range(5,len(X)):
        y.loc[X.index[i-1],result_col_name] = X.loc[X.index[i],"open"]
    
    return y

# %%
train_y = produce_result_target_price(train_X,num_day_to_predict)
valid_y = produce_result_target_price(valid_X,num_day_to_predict)
test_y = produce_result_target_price(test_X,num_day_to_predict)

# %%
pred_y = produce_result_target_price(stock,num_day_to_predict)

# %% [markdown]
# Transform the 10-day data into one vector

# %%
def transform_x_data_to_one_vector(X,num_day):
    col_name = []
    for i in range(num_day):
        for j in X.columns:
            col_name.append(j+"-"+str(i))
    new_X = pd.DataFrame(np.nan, index=X.index, columns=col_name)
    
    for i in range(num_day-1,len(X)):
        for col in col_name:
            split_list = col.split("-")
            new_X.loc[X.index[i],col] = X.loc[X.index[i-int(split_list[1])],split_list[0]]
    
    return new_X

# %%
train_X_5 = transform_x_data_to_one_vector(train_X,num_day_to_predict)
valid_X_5 = transform_x_data_to_one_vector(valid_X,num_day_to_predict)
test_X_5 = transform_x_data_to_one_vector(test_X,num_day_to_predict)

# %%
pred_X_5 = transform_x_data_to_one_vector(stock,num_day_to_predict)

# %% [markdown]
#  Drop out rows with NaN

# %%
def drop_nan_row_y(y,num_day = 5):
    drop_list = [y.index[i] for i in range(num_day-1)]
    drop_list.append(y.index[-1])
    return y.drop(drop_list)

def drop_nan_row_X_5(X,num_day = 5):
    drop_list = [X.index[i] for i in range(num_day-1)]
    drop_list.append(X.index[-1])
    return X.drop(drop_list)

# %%
new_train_X_5 = drop_nan_row_X_5(train_X_5,num_day_to_predict)
new_train_y = drop_nan_row_y(train_y,num_day_to_predict)

new_valid_X_5  = drop_nan_row_X_5(valid_X_5,num_day_to_predict)
new_valid_y = drop_nan_row_y(valid_y,num_day_to_predict)

new_test_X_5  = drop_nan_row_X_5(test_X_5,num_day_to_predict)
new_test_y = drop_nan_row_y(test_y,num_day_to_predict)

# %%
new_pred_X_5  = drop_nan_row_X_5(pred_X_5,num_day_to_predict)
new_pred_y = drop_nan_row_y(pred_y,num_day_to_predict)

# %%
# Keep a copy for reverting prediction result
old_train_X_5 = new_train_X_5
old_train_y = new_train_y
old_valid_X_5 = new_valid_X_5
old_valid_y = new_valid_y
old_test_X_5 = new_test_X_5
old_test_y = new_test_y

# %%
old_pred_X_5 = new_pred_X_5
old_pred_y = new_pred_y

# %%
### Normalize data row by row

# %%
def normalize_data_by_row(X,y):
    norm_X = X.sub(X.mean(axis=0), axis=1).div(X.std(axis=0), axis=1)
    
    col_list =[] 
    for col in X.columns:
        if "open" in col:
            col_list.append(col)
    
    temp_y = y.loc[:,"result_price"]
    mean_5_day = np.mean(X.loc[:,col_list],axis=1)
    mean_5_day.index = temp_y.index
    std_5_day = np.std(X.loc[:,col_list],axis=1)
    std_5_day.index = temp_y.index
    

    norm_y = pd.DataFrame((temp_y-mean_5_day)/std_5_day,
                          columns=["result_price"])
                         
    return (norm_X,norm_y)

# %%
new_train_X_5,new_train_y = normalize_data_by_row(new_train_X_5,new_train_y)
new_valid_X_5,new_valid_y = normalize_data_by_row(new_valid_X_5,new_valid_y)
new_test_X_5,new_test_y = normalize_data_by_row(new_test_X_5,new_test_y)

# %%
new_pred_X_5,new_pred_y = normalize_data_by_row(new_pred_X_5,new_pred_y)

# %%
new_train_X_5 = drop_nan_row_X_5(new_train_X_5,num_day_to_predict)
new_valid_X_5 = drop_nan_row_X_5(new_valid_X_5,num_day_to_predict)
new_test_X_5 = drop_nan_row_X_5(new_test_X_5,num_day_to_predict)

# %%
new_train_y = drop_nan_row_y(new_train_y,num_day_to_predict)
new_valid_y = drop_nan_row_y(new_valid_y,num_day_to_predict)
new_test_y = drop_nan_row_y(new_test_y,num_day_to_predict)

# %%
len(new_test_X_5.columns)
# Out:
# 70

# %% [markdown]
# # XGBboost Training

# %%
from xgboost import XGBRegressor
model_xgb = XGBRegressor(learning_rate = 0.01,n_estimators=1000)
model_xgb.fit(new_train_X_5, new_train_y, early_stopping_rounds=5, eval_set=[(new_valid_X_5, new_valid_y)], verbose=False)
xgb_pred_y = model_xgb.predict(new_test_X_5)
# Out:
# [07:18:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
#Performance evaluation
print('XGBoost PERFORMANCE')
print('r2 score: '+str(r2_score(new_test_y, xgb_pred_y)))
print('RMSE : '+str(np.sqrt(mean_squared_error(new_test_y, xgb_pred_y))))
print("Mean Absolute Error : " + str(mean_absolute_error(new_test_y,xgb_pred_y)))
# Out:
# XGBoost PERFORMANCE
# r2 score: 0.39090347765863553
# RMSE : 1.7580605387765824
# Mean Absolute Error : 1.1670200978605854

# %%
with open(model_folder+"Xgb.pickle", "wb") as f:
    pickle.dump(model_xgb, f)

# %%
xgb_final_pred = model_xgb.predict(new_pred_X_5)

# %%
xgb_final_pred_converted = convert_prediction(old_pred_X_5,old_pred_y,xgb_final_pred)
xgb_final_pred_converted
# Out:
# a
# b
# 20120109    126.271545
# 20120110    126.425993
# 20120111    126.003212
# 20120112    126.228033
# 20120113    125.767039
#                ...
# 20211223    128.973605
# 20211227    130.029607
# 20211228    130.478939
# 20211229    131.012639
# 20211230    133.774986
# Name: converted, Length: 2512, dtype: float64

# %%
action_xgb = convert_decision(stock,xgb_final_pred_converted)
action_xgb['pred_price'] = xgb_final_pred_converted.tolist()

# %%
action_xgb
# Out:
#          Action  pred_price
# 20120109     NA  126.271545
# 20120110     NA  126.425993
# 20120111     NA  126.003212
# 20120112     NA  126.228033
# 20120113     NA  125.767039
# ...         ...         ...
# 20211223   Hold  128.973605
# 20211227   Hold  130.029607
# 20211228   Hold  130.478939
# 20211229   Hold  131.012639
# 20211230   Hold  133.774986
#
# [2512 rows x 2 columns]

# %%
code = "IBM"
file_name = f"XGB_{code}"
action_xgb.to_csv(f"{file_name}.csv")

# %% [markdown]
# # Load model

# %%
with open(model_folder+"Xgb.pickle", "rb") as f:
    xgb_test = pickle.load(f)
# Out:
# [14:21:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %% [markdown]
# # Backtesting for XGB

# %%
import os

file_list = list(filter(lambda name: "XGB_" in name ,os.listdir(record_folder)))
if len(file_list) == 0:
  print("No such files...")
else:
  for f in file_list:
    print(file_list)
    os.remove(record_folder+f)
  print("All old files deleted...")
# Out:
# All old files deleted...

# %%
#### XGB Backtest
backtest_summary = pd.DataFrame(columns=backtest_col)
for sector, stocks in stock_list.items():
    for stock in stocks:
        print("Runninng stock: "+ stock)
        stock_data_1 = web.DataReader(stock, "stooq",start=start_date, end=end_date)
        stock_data_1.columns = ["open","high","low","close","volume"]
        x_1 = StockDataFrame(stock_data_1)
        data_1 = x_1[['open','high','low','close','volume',
                      'boll', 'boll_ub', 'boll_lb',
                      'macd', 'macdh', 'macds',
                      'rsi_11', 'rsi_14', 'rsi_21']]
        data_1.index = [int(str(ind)[0:4]+str(ind)[5:7]+str(ind)[8:10]) for ind in data_1.index]
        data_1 = data_1.sort_index()
        print(stock + " Data loaded...")
        
        for k,v in date_range_list.items():
         
            print("Getting Data... - " + stock + " from " + str(k))
            if (data_1.index[0]>v):
                print("No data for this testing period... - " + stock + " from " + str(k))
                continue
            test_X = custom_split(data_1,start = k,end = v)
            if len(test_X) <= num_day_to_predict:
                print("No enough data for testing... - " + stock + " from " + str(k))
                continue
                
            print("Transforming Data... - " + stock + " from " + str(k))
            test_y = produce_result_target_price(test_X,num_day_to_predict)
            test_X_5 = transform_x_data_to_one_vector(test_X,num_day_to_predict)
            new_test_X_5  = drop_nan_row_X_5(test_X_5,num_day_to_predict)
            new_test_y = drop_nan_row_y(test_y,num_day_to_predict)
            old_test_X_5 = new_test_X_5.copy()
            old_test_y = new_test_y.copy()
            new_test_X_5,new_test_y = normalize_data_by_row(new_test_X_5,new_test_y)
            
            print("Predicting... - " + stock + " from " + str(k))
            xgb_prediction = xgb_test.predict(new_test_X_5)
            
            print("Converting... - " + stock + " from " + str(k))
            pred_price = convert_prediction(old_test_X_5,old_test_y,xgb_prediction)
            data_copy = data_1

            pred_action = convert_decision(data_copy,pred_price)
            final_test_y = old_test_y.rename(columns={"result_price":"Open"})
            
            
            print("Backtesting... - " + stock + " from " + str(k))
            back1 = backtest(final_test_y,pred_action,10000,0.0005,period_year)
            back1.clear_trade_record(3)
            
            print("Start Iteration... - " + stock + " from " + str(k))
            back1.start_test()
            
            print("======= from "+ str(k) + " to " + str(v)+" =========")
            back1.print_do_nothing()
            back1.print_profit()
            back1.print_CAGR_performance()
            
            back1.export_trade_record("XGB_"+sector+"-"+stock,str(k)+"-to-"+str(v)+"("+str(round(back1.get_diff_in_CAGR()*100,2))+"%)")
            #Changed by Thomas
            backtest_summary = backtest_summary.append({"Sector":sector,
                                                        "Stock":stock,
                                                        "Range_Start":str(k),
                                                        "Range_End":str(v),
                                                        do_nth_name+"_Profit":round(back1.get_do_nothing(),2),
                                                        model_name+"_Profit":round(back1.get_profit(),2),
                                                        do_nth_name+"_CAGR(in %)":round(back1.get_do_nothing_CAGR()*100,2),
                                                        model_name+"_CAGR(in %)":round(back1.get_model_CAGR()*100,2),
                                                        "CAGR_Performance(in %)":round(back1.get_diff_in_CAGR()*100,2),
                                                        do_nth_name+"_MDD(in %)":round(back1.get_do_nothing_MDD()*100,2),
                                                        model_name+"_MDD(in %)":round(back1.get_model_MDD()*100,2),
                                                        "MDD_Performance(in %)":round(back1.get_diff_in_MDD()*100,2)}, ignore_index=True)
            print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
            time.sleep(3)

print("Backtesting Completed...")
backtest_summary.to_csv(backtest_summary_folder+"backtest_summary_Xgb.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# Sold at 20170606 with price = 28.721 	Pos: 365
# Bought at 20170609 with price = 28.685 	Pos: 365
# Sold at 20170615 with price = 28.808 	Pos: 365
# Bought at 20170703 with price = 28.174 	Pos: 373
# Sold at 20170706 with price = 27.845 	Pos: 373
# Bought at 20170719 with price = 27.207 	Pos: 382
# Sold at 20170801 with price = 29.193 	Pos: 382
# Bought at 20170808 with price = 28.607 	Pos: 389
# Sold at 20170809 with price = 28.661 	Pos: 389
# Bought at 20170822 with price = 28.347 	Pos: 393
# Sold at 20170828 with price = 28.273 	Pos: 393
# Bought at 20170911 with price = 26.932 	Pos: 412
# Sold at 20171002 with price = 29.351 	Pos: 412
# Bought at 20171103 with price = 25.079 	Pos: 482
# Sold at 20171205 with price = 27.612 	Pos: 482
# Bought at 20171206 with price = 27.4 	Pos: 485
# ======= from 20170101 to 20171231 =========
# If buy at 20170109 with price = 29.704
# and do nothing
# Current Profit: 7.105728000000454
# Current Profit with model: 4441.8322540000245
# CAGR Performance: 44.35%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - T from 20180101
# Transforming Data... - T from 20180101
# Predicting... - T from 20180101
# Converting... - T from 20180101
# a
# b
# Backtesting... - T from 20180101
# Clearing trade_record...
# Start Iteration... - T from 20180101
# Start Backtesting...
# Bought at 20180116 with price = 28.251 	Pos: 353
# Sold at 20180124 with price = 28.499 	Pos: 353
# Bought at 20180125 with price = 28.784 	Pos: 349
# Sold at 20180205 with price = 27.723 	Pos: 349
# Bought at 20180212 with price = 27.885 	Pos: 347
# Sold at 20180221 with price = 28.023 	Pos: 347
# Bought at 20180223 with price = 28.376 	Pos: 342
# Sold at 20180228 with price = 27.899 	Pos: 342
# Bought at 20180305 with price = 28.3 	Pos: 337
# Sold at 20180312 with price = 28.853 	Pos: 337
# Bought at 20180328 with price = 27.414 	Pos: 355
# Sold at 20180412 with price = 27.44 	Pos: 355
# Bought at 20180510 with price = 24.936 	Pos: 390
# Sold at 20180517 with price = 24.891 	Pos: 390
# Bought at 20180518 with price = 25.063 	Pos: 387
# Sold at 20180525 with price = 25.296 	Pos: 387
# Bought at 20180529 with price = 25.22 	Pos: 388
# Sold at 20180531 with price = 25.313 	Pos: 388
# Bought at 20180601 with price = 25.391 	Pos: 386
# Sold at 20180612 with price = 25.716 	Pos: 386
# Bought at 20180625 with price = 24.728 	Pos: 401
# Sold at 20180711 with price = 25.372 	Pos: 401
# Bought at 20180724 with price = 24.612 	Pos: 413
# Sold at 20180725 with price = 24.029 	Pos: 413
# Bought at 20180726 with price = 24.099 	Pos: 411
# Sold at 20180822 with price = 25.871 	Pos: 411
# Bought at 20180905 with price = 25.428 	Pos: 418
# Sold at 20180926 with price = 26.457 	Pos: 418
# Bought at 20180928 with price = 26.64 	Pos: 415
# Sold at 20181008 with price = 27.059 	Pos: 415
# Bought at 20181016 with price = 26.031 	Pos: 431
# Sold at 20181018 with price = 26.064 	Pos: 431
# Bought at 20181030 with price = 24.652 	Pos: 455
# Sold at 20181109 with price = 24.658 	Pos: 455
# Bought at 20181123 with price = 23.816 	Pos: 471
# Sold at 20181206 with price = 24.271 	Pos: 471
# Bought at 20181227 with price = 22.643 	Pos: 504
# ======= from 20180101 to 20181231 =========
# If buy at 20180108 with price = 28.912
# and do nothing
# Current Profit: -2063.257319999999
# Current Profit with model: 1575.9726595000247
# CAGR Performance: 36.39%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - T from 20190101
# Transforming Data... - T from 20190101
# Predicting... - T from 20190101
# Converting... - T from 20190101
# a
# b
# Backtesting... - T from 20190101
# Clearing trade_record...
# Start Iteration... - T from 20190101
# Start Backtesting...
# Bought at 20190108 with price = 25.214 	Pos: 396
# Sold at 20190110 with price = 24.821 	Pos: 396
# Bought at 20190111 with price = 25.068 	Pos: 392
# Sold at 20190116 with price = 24.944 	Pos: 392
# Bought at 20190208 with price = 24.152 	Pos: 404
# Sold at 20190226 with price = 25.5 	Pos: 404
# Bought at 20190308 with price = 24.479 	Pos: 420
# Sold at 20190321 with price = 25.313 	Pos: 420
# Bought at 20190322 with price = 25.394 	Pos: 419
# Sold at 20190412 with price = 26.72 	Pos: 419
# Bought at 20190430 with price = 25.759 	Pos: 434
# Sold at 20190501 with price = 25.683 	Pos: 434
# Bought at 20190510 with price = 25.176 	Pos: 442
# Sold at 20190523 with price = 26.812 	Pos: 442
# Bought at 20190605 with price = 26.38 	Pos: 449
# Sold at 20190612 with price = 26.729 	Pos: 449
# Bought at 20190613 with price = 26.828 	Pos: 447
# Sold at 20190709 with price = 28.411 	Pos: 447
# Bought at 20190724 with price = 28.279 	Pos: 448
# Sold at 20190731 with price = 29.037 	Pos: 448
# Bought at 20190808 with price = 28.995 	Pos: 449
# Sold at 20190813 with price = 29.137 	Pos: 449
# Bought at 20190816 with price = 29.483 	Pos: 443
# Sold at 20190821 with price = 29.684 	Pos: 443
# Bought at 20190829 with price = 29.625 	Pos: 443
# Sold at 20190913 with price = 31.748 	Pos: 443
# Bought at 20190920 with price = 31.698 	Pos: 444
# Sold at 20190924 with price = 31.436 	Pos: 444
# Bought at 20190930 with price = 31.959 	Pos: 436
# Sold at 20191001 with price = 31.452 	Pos: 436
# Bought at 20191007 with price = 31.73 	Pos: 432
# Sold at 20191022 with price = 32.442 	Pos: 432
# Bought at 20191028 with price = 32.86 	Pos: 426
# Sold at 20191107 with price = 33.587 	Pos: 426
# Bought at 20191127 with price = 32.219 	Pos: 443
# Sold at 20191129 with price = 31.998 	Pos: 443
# Bought at 20191202 with price = 31.751 	Pos: 446
# Sold at 20191210 with price = 32.458 	Pos: 446
# Bought at 20191211 with price = 32.611 	Pos: 444
# Sold at 20191224 with price = 33.288 	Pos: 444
# ======= from 20190101 to 20191231 =========
# If buy at 20190108 with price = 25.214
# and do nothing
# Current Profit: 3198.6476280000024
# Current Profit with model: 4781.797674500031
# CAGR Performance: 15.83%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - T from 20200101
# Transforming Data... - T from 20200101
# Predicting... - T from 20200101
# Converting... - T from 20200101
# a
# b
# Backtesting... - T from 20200101
# Clearing trade_record...
# Start Iteration... - T from 20200101
# Start Backtesting...
# Bought at 20200108 with price = 33.671 	Pos: 296
# Sold at 20200110 with price = 33.342 	Pos: 296
# Bought at 20200117 with price = 33.179 	Pos: 298
# Sold at 20200124 with price = 32.894 	Pos: 298
# Bought at 20200204 with price = 32.644 	Pos: 299
# Sold at 20200212 with price = 32.771 	Pos: 299
# Bought at 20200213 with price = 33.135 	Pos: 296
# Sold at 20200214 with price = 33.031 	Pos: 296
# Bought at 20200218 with price = 33.083 	Pos: 295
# Sold at 20200221 with price = 32.867 	Pos: 295
# Bought at 20200304 with price = 32.357 	Pos: 300
# Sold at 20200306 with price = 30.289 	Pos: 300
# Bought at 20200325 with price = 24.814 	Pos: 365
# Sold at 20200331 with price = 24.553 	Pos: 365
# Bought at 20200406 with price = 26.335 	Pos: 340
# Sold at 20200415 with price = 26.657 	Pos: 340
# Bought at 20200417 with price = 27.159 	Pos: 334
# Sold at 20200420 with price = 26.861 	Pos: 334
# Bought at 20200427 with price = 27.291 	Pos: 328
# Sold at 20200430 with price = 27.09 	Pos: 328
# Bought at 20200515 with price = 25.523 	Pos: 348
# Sold at 20200602 with price = 27.556 	Pos: 348
# Bought at 20200603 with price = 27.635 	Pos: 346
# Sold at 20200609 with price = 28.673 	Pos: 346
# Bought at 20200629 with price = 26.42 	Pos: 376
# Sold at 20200713 with price = 26.619 	Pos: 376
# Bought at 20200714 with price = 26.933 	Pos: 371
# Sold at 20200720 with price = 26.771 	Pos: 371
# Bought at 20200721 with price = 27.013 	Pos: 367
# Sold at 20200722 with price = 27.004 	Pos: 367
# Bought at 20200729 with price = 26.395 	Pos: 375
# Sold at 20200812 with price = 26.869 	Pos: 375
# Bought at 20200825 with price = 26.717 	Pos: 377
# Sold at 20200826 with price = 26.879 	Pos: 377
# Bought at 20200925 with price = 25.367 	Pos: 399
# Sold at 20201009 with price = 25.813 	Pos: 399
# Bought at 20201022 with price = 25.86 	Pos: 398
# Sold at 20201027 with price = 24.349 	Pos: 398
# Bought at 20201030 with price = 24.992 	Pos: 387
# Sold at 20201119 with price = 25.74 	Pos: 387
# Bought at 20201123 with price = 26.388 	Pos: 377
# Sold at 20201211 with price = 28.486 	Pos: 377
# Bought at 20201228 with price = 26.169 	Pos: 410
# ======= from 20200101 to 20201231 =========
# If buy at 20200108 with price = 33.671
# and do nothing
# Current Profit: -2290.399307999999
# Current Profit with model: 664.5361655000233
# CAGR Performance: 29.55%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - T from 20210101
# Transforming Data... - T from 20210101
# Predicting... - T from 20210101
# Converting... - T from 20210101
# a
# b
# Backtesting... - T from 20210101
# Clearing trade_record...
# Start Iteration... - T from 20210101
# Start Backtesting...
# Bought at 20210114 with price = 26.873 	Pos: 371
# Sold at 20210119 with price = 26.92 	Pos: 371
# Bought at 20210122 with price = 26.697 	Pos: 374
# Sold at 20210127 with price = 26.947 	Pos: 374
# Bought at 20210203 with price = 26.475 	Pos: 380
# Sold at 20210210 with price = 26.465 	Pos: 380
# Bought at 20210211 with price = 26.549 	Pos: 379
# Sold at 20210219 with price = 26.911 	Pos: 379
# Bought at 20210303 with price = 26.706 	Pos: 381
# Sold at 20210312 with price = 27.866 	Pos: 381
# Bought at 20210315 with price = 27.616 	Pos: 384
# Sold at 20210408 with price = 28.371 	Pos: 384
# Bought at 20210414 with price = 28.117 	Pos: 388
# Sold at 20210507 with price = 30.524 	Pos: 388
# Bought at 20210521 with price = 28.371 	Pos: 417
# Sold at 20210525 with price = 27.852 	Pos: 417
# Bought at 20210610 with price = 27.588 	Pos: 420
# Sold at 20210614 with price = 27.437 	Pos: 420
# Bought at 20210615 with price = 27.645 	Pos: 417
# Sold at 20210616 with price = 27.418 	Pos: 417
# Bought at 20210624 with price = 27.096 	Pos: 421
# Sold at 20210707 with price = 27.18 	Pos: 421
# Bought at 20210712 with price = 27.382 	Pos: 418
# Sold at 20210713 with price = 27.17 	Pos: 418
# Bought at 20210722 with price = 26.891 	Pos: 421
# Sold at 20210728 with price = 27.102 	Pos: 421
# Bought at 20210729 with price = 27.276 	Pos: 418
# Sold at 20210802 with price = 26.996 	Pos: 418
# Bought at 20210803 with price = 26.958 	Pos: 419
# Sold at 20210804 with price = 26.795 	Pos: 419
# Bought at 20210810 with price = 26.996 	Pos: 415
# Sold at 20210813 with price = 27.054 	Pos: 415
# Bought at 20210830 with price = 26.141 	Pos: 429
# Sold at 20210909 with price = 26.42 	Pos: 429
# Bought at 20210913 with price = 26.487 	Pos: 428
# Sold at 20210914 with price = 26.295 	Pos: 428
# Bought at 20210915 with price = 26.497 	Pos: 424
# Sold at 20210917 with price = 26.266 	Pos: 424
# Bought at 20210923 with price = 26.103 	Pos: 426
# Sold at 20210929 with price = 26.42 	Pos: 426
# Bought at 20211004 with price = 26.247 	Pos: 428
# Sold at 20211006 with price = 26.462 	Pos: 428
# Bought at 20211015 with price = 25.051 	Pos: 452
# Sold at 20211022 with price = 24.924 	Pos: 452
# Bought at 20211102 with price = 24.62 	Pos: 457
# Sold at 20211103 with price = 24.63 	Pos: 457
# Bought at 20211110 with price = 24.492 	Pos: 459
# Sold at 20211111 with price = 24.453 	Pos: 459
# Bought at 20211203 with price = 23.12 	Pos: 485
# Sold at 20211209 with price = 22.522 	Pos: 485
# Bought at 20211210 with price = 22.258 	Pos: 491
# ======= from 20210101 to 20211231 =========
# If buy at 20210108 with price = 26.679
# and do nothing
# Current Profit: -921.6629729999986
# Current Profit with model: 1901.0520865000399
# CAGR Performance: 28.23%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Runninng stock: TMUS
# TMUS Data loaded...
# Getting Data... - TMUS from 20120101
# Transforming Data... - TMUS from 20120101
# Predicting... - TMUS from 20120101
# Converting... - TMUS from 20120101
# a
# b
# Backtesting... - TMUS from 20120101
# Clearing trade_record...
# Start Iteration... - TMUS from 20120101
# Start Backtesting...
# Bought at 20120110 with price = 11.005 	Pos: 908
# Sold at 20120124 with price = 11.461 	Pos: 908
# Bought at 20120125 with price = 11.877 	Pos: 875
# Sold at 20120228 with price = 14.414 	Pos: 875
# Bought at 20120309 with price = 13.676 	Pos: 921
# Sold at 20120313 with price = 13.367 	Pos: 921
# Bought at 20120316 with price = 13.367 	Pos: 920
# Sold at 20120319 with price = 13.394 	Pos: 920
# Bought at 20120509 with price = 10.2 	Pos: 1207
# Sold at 20120511 with price = 9.3273 	Pos: 1207
# Bought at 20120521 with price = 8.616 	Pos: 1306
# Sold at 20120522 with price = 8.5489 	Pos: 1306
# Bought at 20120523 with price = 8.5623 	Pos: 1303
# Sold at 20120529 with price = 8.7368 	Pos: 1303
# Bought at 20120619 with price = 7.945 	Pos: 1431
# Sold at 20120626 with price = 7.5692 	Pos: 1431
# Bought at 20120627 with price = 7.5424 	Pos: 1435
# Sold at 20120801 with price = 11.703 	Pos: 1435
# Bought at 20120806 with price = 11.582 	Pos: 1448
# Sold at 20120822 with price = 13.031 	Pos: 1448
# Bought at 20120829 with price = 13.005 	Pos: 1450
# Sold at 20120830 with price = 13.045 	Pos: 1450
# Bought at 20120831 with price = 13.018 	Pos: 1451
# Sold at 20121004 with price = 17.111 	Pos: 1451
# Bought at 20121005 with price = 16.991 	Pos: 1460
# Sold at 20121008 with price = 16.897 	Pos: 1460
# Bought at 20121112 with price = 13.34 	Pos: 1847
# Sold at 20121121 with price = 14.266 	Pos: 1847
# Bought at 20121130 with price = 14.333 	Pos: 1837
# Sold at 20121204 with price = 13.367 	Pos: 1837
# Bought at 20121206 with price = 13.971 	Pos: 1756
# Sold at 20121211 with price = 13.662 	Pos: 1756
# ======= from 20120101 to 20121231 =========
# If buy at 20120109 with price = 11.193
# and do nothing
# Current Profit: 1718.3519220000017
# Current Profit with model: 13980.148952000021
# CAGR Performance: 122.62%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - TMUS from 20130101
# Transforming Data... - TMUS from 20130101
# Predicting... - TMUS from 20130101
# Converting... - TMUS from 20130101
# a
# b
# Backtesting... - TMUS from 20130101
# Clearing trade_record...
# Start Iteration... - TMUS from 20130101
# Start Backtesting...
# Bought at 20130110 with price = 13.058 	Pos: 765
# Sold at 20130111 with price = 13.152 	Pos: 765
# Bought at 20130122 with price = 12.642 	Pos: 795
# Sold at 20130201 with price = 13.179 	Pos: 795
# Bought at 20130208 with price = 13.273 	Pos: 789
# Sold at 20130215 with price = 13.944 	Pos: 789
# Bought at 20130228 with price = 13.179 	Pos: 834
# Sold at 20130311 with price = 14.051 	Pos: 834
# Bought at 20130315 with price = 13.743 	Pos: 851
# Sold at 20130409 with price = 15.08 	Pos: 851
# Bought at 20130418 with price = 15.11 	Pos: 849
# Sold at 20130522 with price = 19.26 	Pos: 849
# Bought at 20130529 with price = 21.04 	Pos: 776
# Sold at 20130603 with price = 20.74 	Pos: 776
# Bought at 20130607 with price = 21.42 	Pos: 751
# Sold at 20130619 with price = 22.25 	Pos: 751
# Bought at 20130620 with price = 22.98 	Pos: 726
# Sold at 20130624 with price = 22.35 	Pos: 726
# Bought at 20130625 with price = 23.1 	Pos: 702
# Sold at 20130701 with price = 23.77 	Pos: 702
# Bought at 20130709 with price = 24.09 	Pos: 692
# Sold at 20130715 with price = 25.29 	Pos: 692
# Bought at 20130802 with price = 24.66 	Pos: 709
# Sold at 20130806 with price = 24.2 	Pos: 709
# Bought at 20130823 with price = 23.97 	Pos: 715
# Sold at 20130827 with price = 23.44 	Pos: 715
# Bought at 20130830 with price = 23.54 	Pos: 711
# Sold at 20130913 with price = 24.94 	Pos: 711
# Bought at 20130918 with price = 25.34 	Pos: 699
# Sold at 20130930 with price = 26.35 	Pos: 699
# Bought at 20131001 with price = 26.34 	Pos: 699
# Sold at 20131004 with price = 26.33 	Pos: 699
# Bought at 20131011 with price = 26.13 	Pos: 703
# Sold at 20131022 with price = 27.34 	Pos: 703
# Bought at 20131121 with price = 26.71 	Pos: 719
# Sold at 20131122 with price = 26.58 	Pos: 719
# Bought at 20131211 with price = 26.11 	Pos: 731
# Sold at 20131212 with price = 25.59 	Pos: 731
# Bought at 20131213 with price = 27.01 	Pos: 692
# Sold at 20131230 with price = 33.23 	Pos: 692
# ======= from 20130101 to 20131231 =========
# If buy at 20130108 with price = 12.575
# and do nothing
# Current Profit: 16395.077725000003
# Current Profit with model: 13003.60293950004
# CAGR Performance: -33.91%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - TMUS from 20140101
# Transforming Data... - TMUS from 20140101
# Predicting... - TMUS from 20140101
# Converting... - TMUS from 20140101
# a
# b
# Backtesting... - TMUS from 20140101
# Clearing trade_record...
# Start Iteration... - TMUS from 20140101
# Start Backtesting...
# Bought at 20140108 with price = 33.5 	Pos: 298
# Sold at 20140109 with price = 32.9 	Pos: 298
# Bought at 20140117 with price = 32.99 	Pos: 297
# Sold at 20140123 with price = 32.5 	Pos: 297
# Bought at 20140205 with price = 31.24 	Pos: 308
# Sold at 20140206 with price = 29.75 	Pos: 308
# Bought at 20140211 with price = 30.42 	Pos: 301
# Sold at 20140225 with price = 30.51 	Pos: 301
# Bought at 20140303 with price = 30.98 	Pos: 296
# Sold at 20140310 with price = 31.3 	Pos: 296
# Bought at 20140311 with price = 31.11 	Pos: 298
# Sold at 20140317 with price = 30.74 	Pos: 298
# Bought at 20140318 with price = 31.24 	Pos: 293
# Sold at 20140326 with price = 31.97 	Pos: 293
# Bought at 20140331 with price = 33.12 	Pos: 282
# Sold at 20140403 with price = 33.43 	Pos: 282
# Bought at 20140417 with price = 30.38 	Pos: 311
# Sold at 20140423 with price = 29.93 	Pos: 311
# Bought at 20140429 with price = 29.16 	Pos: 318
# Sold at 20140602 with price = 34.39 	Pos: 318
# Bought at 20140617 with price = 33.06 	Pos: 331
# Sold at 20140618 with price = 32.86 	Pos: 331
# Bought at 20140619 with price = 33.25 	Pos: 327
# Sold at 20140702 with price = 33.34 	Pos: 327
# Bought at 20140714 with price = 32.97 	Pos: 330
# Sold at 20140715 with price = 32.19 	Pos: 330
# Bought at 20140728 with price = 31.77 	Pos: 334
# Sold at 20140805 with price = 30.89 	Pos: 334
# Bought at 20140819 with price = 29.07 	Pos: 355
# Sold at 20140909 with price = 30.32 	Pos: 355
# Bought at 20140915 with price = 30.27 	Pos: 355
# Sold at 20140916 with price = 30.31 	Pos: 355
# Bought at 20140926 with price = 28.65 	Pos: 375
# Sold at 20141001 with price = 28.13 	Pos: 375
# Bought at 20141003 with price = 29.37 	Pos: 359
# Sold at 20141008 with price = 28.66 	Pos: 359
# Bought at 20141017 with price = 26.55 	Pos: 387
# Sold at 20141104 with price = 28.67 	Pos: 387
# Bought at 20141110 with price = 28.86 	Pos: 384
# Sold at 20141112 with price = 28.34 	Pos: 384
# Bought at 20141120 with price = 28.04 	Pos: 388
# Sold at 20141128 with price = 29.0 	Pos: 388
# Bought at 20141215 with price = 25.12 	Pos: 447
# ======= from 20140101 to 20141231 =========
# If buy at 20140108 with price = 33.5
# and do nothing
# Current Profit: -1912.1915
# Current Profit with model: 2132.6114450000205
# CAGR Performance: 40.45%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - TMUS from 20150101
# Transforming Data... - TMUS from 20150101
# Predicting... - TMUS from 20150101
# Converting... - TMUS from 20150101
# a
# b
# Backtesting... - TMUS from 20150101
# Clearing trade_record...
# Start Iteration... - TMUS from 20150101
# Start Backtesting...
# Bought at 20150108 with price = 29.16 	Pos: 342
# Sold at 20150127 with price = 30.94 	Pos: 342
# Bought at 20150202 with price = 30.56 	Pos: 346
# Sold at 20150218 with price = 32.45 	Pos: 346
# Bought at 20150220 with price = 31.75 	Pos: 353
# Sold at 20150303 with price = 33.02 	Pos: 353
# Bought at 20150316 with price = 32.31 	Pos: 361
# Sold at 20150323 with price = 33.18 	Pos: 361
# Bought at 20150402 with price = 32.81 	Pos: 364
# Sold at 20150408 with price = 32.77 	Pos: 364
# Bought at 20150415 with price = 31.93 	Pos: 374
# Sold at 20150427 with price = 34.33 	Pos: 374
# Bought at 20150507 with price = 33.49 	Pos: 383
# Sold at 20150508 with price = 33.71 	Pos: 383
# Bought at 20150511 with price = 33.72 	Pos: 382
# Sold at 20150603 with price = 40.45 	Pos: 382
# Bought at 20150604 with price = 39.31 	Pos: 393
# Sold at 20150609 with price = 38.84 	Pos: 393
# Bought at 20150612 with price = 38.59 	Pos: 395
# Sold at 20150619 with price = 39.37 	Pos: 395
# Bought at 20150707 with price = 38.51 	Pos: 403
# Sold at 20150708 with price = 39.47 	Pos: 403
# Bought at 20150710 with price = 39.13 	Pos: 406
# Sold at 20150714 with price = 39.5 	Pos: 406
# Bought at 20150728 with price = 37.0 	Pos: 433
# Sold at 20150806 with price = 40.3 	Pos: 433
# Bought at 20150810 with price = 41.22 	Pos: 423
# Sold at 20150814 with price = 41.17 	Pos: 423
# Bought at 20150827 with price = 39.78 	Pos: 438
# Sold at 20150901 with price = 39.33 	Pos: 438
# Bought at 20150904 with price = 39.88 	Pos: 431
# Sold at 20150909 with price = 39.48 	Pos: 431
# Bought at 20150910 with price = 39.36 	Pos: 432
# Sold at 20150921 with price = 42.52 	Pos: 432
# Bought at 20150922 with price = 42.48 	Pos: 432
# Sold at 20150923 with price = 42.76 	Pos: 432
# Bought at 20151002 with price = 40.87 	Pos: 452
# Sold at 20151007 with price = 40.36 	Pos: 452
# Bought at 20151013 with price = 40.09 	Pos: 454
# Sold at 20151014 with price = 39.67 	Pos: 454
# Bought at 20151015 with price = 40.38 	Pos: 446
# Sold at 20151021 with price = 40.22 	Pos: 446
# Bought at 20151103 with price = 38.78 	Pos: 462
# Sold at 20151106 with price = 39.62 	Pos: 462
# Bought at 20151113 with price = 38.23 	Pos: 478
# Sold at 20151117 with price = 37.61 	Pos: 478
# Bought at 20151207 with price = 36.66 	Pos: 490
# Sold at 20151230 with price = 39.53 	Pos: 490
# ======= from 20150101 to 20151231 =========
# If buy at 20150108 with price = 29.16
# and do nothing
# Current Profit: 3541.553640000002
# Current Profit with model: 9381.273400000035
# CAGR Performance: 58.4%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - TMUS from 20160101
# Transforming Data... - TMUS from 20160101
# Predicting... - TMUS from 20160101
# Converting... - TMUS from 20160101
# a
# b
# Backtesting... - TMUS from 20160101
# Clearing trade_record...
# Start Iteration... - TMUS from 20160101
# Start Backtesting...
# Bought at 20160125 with price = 38.17 	Pos: 261
# Sold at 20160128 with price = 39.44 	Pos: 261
# Bought at 20160212 with price = 35.78 	Pos: 288
# Sold at 20160219 with price = 35.56 	Pos: 288
# Bought at 20160223 with price = 36.16 	Pos: 283
# Sold at 20160229 with price = 37.03 	Pos: 283
# Bought at 20160301 with price = 38.54 	Pos: 271
# Sold at 20160304 with price = 38.24 	Pos: 271
# Bought at 20160321 with price = 36.9 	Pos: 281
# Sold at 20160406 with price = 38.75 	Pos: 281
# Bought at 20160412 with price = 39.12 	Pos: 278
# Sold at 20160426 with price = 39.45 	Pos: 278
# Bought at 20160506 with price = 39.58 	Pos: 277
# Sold at 20160606 with price = 43.25 	Pos: 277
# Bought at 20160620 with price = 42.22 	Pos: 283
# Sold at 20160623 with price = 41.29 	Pos: 283
# Bought at 20160628 with price = 42.7 	Pos: 274
# Sold at 20160706 with price = 43.21 	Pos: 274
# Bought at 20160707 with price = 43.2 	Pos: 273
# Sold at 20160805 with price = 47.73 	Pos: 273
# Bought at 20160901 with price = 46.75 	Pos: 279
# Sold at 20160902 with price = 47.15 	Pos: 279
# Bought at 20160906 with price = 46.98 	Pos: 280
# Sold at 20160907 with price = 46.64 	Pos: 280
# Bought at 20160915 with price = 47.06 	Pos: 277
# Sold at 20160919 with price = 46.25 	Pos: 277
# Bought at 20160922 with price = 46.98 	Pos: 272
# Sold at 20160927 with price = 46.78 	Pos: 272
# Bought at 20161012 with price = 45.59 	Pos: 279
# Sold at 20161028 with price = 49.63 	Pos: 279
# Bought at 20161031 with price = 49.68 	Pos: 278
# Sold at 20161101 with price = 49.25 	Pos: 278
# Bought at 20161103 with price = 48.79 	Pos: 281
# Sold at 20161130 with price = 54.11 	Pos: 281
# Bought at 20161202 with price = 54.6 	Pos: 278
# Sold at 20161209 with price = 56.65 	Pos: 278
# Bought at 20161215 with price = 57.53 	Pos: 273
# Sold at 20161223 with price = 58.1 	Pos: 273
# ======= from 20160101 to 20161231 =========
# If buy at 20160108 with price = 39.96
# and do nothing
# Current Profit: 4470.005000000001
# Current Profit with model: 5905.318770000034
# CAGR Performance: 14.35%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - TMUS from 20170101
# Transforming Data... - TMUS from 20170101
# Predicting... - TMUS from 20170101
# Converting... - TMUS from 20170101
# a
# b
# Backtesting... - TMUS from 20170101
# Clearing trade_record...
# Start Iteration... - TMUS from 20170101
# Start Backtesting...
# Bought at 20170112 with price = 57.25 	Pos: 174
# Sold at 20170130 with price = 61.25 	Pos: 174
# Bought at 20170208 with price = 61.71 	Pos: 173
# Sold at 20170213 with price = 61.24 	Pos: 173
# Bought at 20170216 with price = 60.54 	Pos: 174
# Sold at 20170223 with price = 62.1 	Pos: 174
# Bought at 20170302 with price = 62.22 	Pos: 174
# Sold at 20170306 with price = 62.53 	Pos: 174
# Bought at 20170313 with price = 61.8 	Pos: 176
# Sold at 20170331 with price = 64.2 	Pos: 176
# Bought at 20170407 with price = 63.89 	Pos: 176
# Sold at 20170501 with price = 68.56 	Pos: 176
# Bought at 20170512 with price = 65.61 	Pos: 184
# Sold at 20170517 with price = 63.75 	Pos: 184
# Bought at 20170518 with price = 66.71 	Pos: 176
# Sold at 20170526 with price = 67.61 	Pos: 176
# Bought at 20170710 with price = 60.74 	Pos: 196
# Sold at 20170725 with price = 62.34 	Pos: 196
# Bought at 20170726 with price = 62.39 	Pos: 195
# Sold at 20170727 with price = 61.41 	Pos: 195
# Bought at 20170801 with price = 63.22 	Pos: 189
# Sold at 20170808 with price = 63.63 	Pos: 189
# Bought at 20170814 with price = 63.79 	Pos: 189
# Sold at 20170817 with price = 62.87 	Pos: 189
# Bought at 20170822 with price = 64.2 	Pos: 185
# Sold at 20170828 with price = 63.31 	Pos: 185
# Bought at 20170830 with price = 64.25 	Pos: 182
# Sold at 20170901 with price = 64.17 	Pos: 182
# Bought at 20170918 with price = 62.01 	Pos: 188
# Sold at 20170922 with price = 64.11 	Pos: 188
# Bought at 20171006 with price = 62.31 	Pos: 193
# Sold at 20171009 with price = 61.69 	Pos: 193
# Bought at 20171024 with price = 61.95 	Pos: 192
# Sold at 20171025 with price = 62.18 	Pos: 192
# Bought at 20171110 with price = 56.8 	Pos: 210
# Sold at 20171129 with price = 61.89 	Pos: 210
# Bought at 20171205 with price = 60.53 	Pos: 215
# Sold at 20171214 with price = 62.47 	Pos: 215
# Bought at 20171218 with price = 63.52 	Pos: 211
# ======= from 20170101 to 20171231 =========
# If buy at 20170109 with price = 55.72
# and do nothing
# Current Profit: 1495.0330600000016
# Current Profit with model: 3546.5035150000294
# CAGR Performance: 20.51%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - TMUS from 20180101
# Transforming Data... - TMUS from 20180101
# Predicting... - TMUS from 20180101
# Converting... - TMUS from 20180101
# a
# b
# Backtesting... - TMUS from 20180101
# Clearing trade_record...
# Start Iteration... - TMUS from 20180101
# Start Backtesting...
# Bought at 20180108 with price = 66.0 	Pos: 151
# Sold at 20180111 with price = 64.16 	Pos: 151
# Bought at 20180119 with price = 63.75 	Pos: 152
# Sold at 20180126 with price = 64.75 	Pos: 152
# Bought at 20180214 with price = 59.32 	Pos: 166
# Sold at 20180222 with price = 59.39 	Pos: 166
# Bought at 20180223 with price = 60.0 	Pos: 164
# Sold at 20180313 with price = 65.23 	Pos: 164
# Bought at 20180329 with price = 60.4 	Pos: 177
# Sold at 20180402 with price = 60.06 	Pos: 177
# Bought at 20180404 with price = 60.13 	Pos: 176
# Sold at 20180416 with price = 63.0 	Pos: 176
# Bought at 20180417 with price = 63.08 	Pos: 176
# Sold at 20180418 with price = 62.65 	Pos: 176
# Bought at 20180510 with price = 57.05 	Pos: 193
# Sold at 20180524 with price = 57.1 	Pos: 193
# Bought at 20180601 with price = 56.8 	Pos: 194
# Sold at 20180620 with price = 60.24 	Pos: 194
# Bought at 20180622 with price = 60.53 	Pos: 193
# Sold at 20180625 with price = 59.71 	Pos: 193
# Bought at 20180628 with price = 59.88 	Pos: 192
# Sold at 20180711 with price = 60.28 	Pos: 192
# Bought at 20180725 with price = 59.1 	Pos: 196
# Sold at 20180810 with price = 64.94 	Pos: 196
# Bought at 20180813 with price = 65.78 	Pos: 193
# Sold at 20180817 with price = 65.74 	Pos: 193
# Bought at 20180820 with price = 65.77 	Pos: 193
# Sold at 20180822 with price = 65.5 	Pos: 193
# Bought at 20180827 with price = 65.85 	Pos: 191
# Sold at 20180906 with price = 65.33 	Pos: 191
# Bought at 20180907 with price = 64.98 	Pos: 192
# Sold at 20181001 with price = 70.16 	Pos: 192
# Bought at 20181015 with price = 67.68 	Pos: 199
# Sold at 20181022 with price = 69.08 	Pos: 199
# Bought at 20181030 with price = 67.37 	Pos: 204
# Sold at 20181109 with price = 68.69 	Pos: 204
# Bought at 20181116 with price = 68.53 	Pos: 204
# Sold at 20181119 with price = 67.74 	Pos: 204
# Bought at 20181126 with price = 67.24 	Pos: 205
# Sold at 20181130 with price = 68.5 	Pos: 205
# Bought at 20181213 with price = 65.83 	Pos: 214
# Sold at 20181214 with price = 65.73 	Pos: 214
# Bought at 20181227 with price = 62.7 	Pos: 224
# ======= from 20180101 to 20181231 =========
# If buy at 20180108 with price = 66.0
# and do nothing
# Current Profit: -409.66300000000047
# Current Profit with model: 4193.663630000021
# CAGR Performance: 46.03%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - TMUS from 20190101
# Transforming Data... - TMUS from 20190101
# Predicting... - TMUS from 20190101
# Converting... - TMUS from 20190101
# a
# b
# Backtesting... - TMUS from 20190101
# Clearing trade_record...
# Start Iteration... - TMUS from 20190101
# Start Backtesting...
# Bought at 20190108 with price = 68.65 	Pos: 145
# Sold at 20190110 with price = 67.83 	Pos: 145
# Bought at 20190118 with price = 66.75 	Pos: 147
# Sold at 20190129 with price = 67.74 	Pos: 147
# Bought at 20190130 with price = 68.41 	Pos: 146
# Sold at 20190204 with price = 69.7 	Pos: 146
# Bought at 20190208 with price = 68.17 	Pos: 149
# Sold at 20190225 with price = 71.44 	Pos: 149
# Bought at 20190311 with price = 71.47 	Pos: 149
# Sold at 20190319 with price = 72.8 	Pos: 149
# Bought at 20190403 with price = 69.08 	Pos: 156
# Sold at 20190417 with price = 73.22 	Pos: 156
# Bought at 20190423 with price = 73.39 	Pos: 156
# Sold at 20190425 with price = 74.73 	Pos: 156
# Bought at 20190430 with price = 73.14 	Pos: 159
# Sold at 20190502 with price = 73.71 	Pos: 159
# Bought at 20190503 with price = 73.88 	Pos: 159
# Sold at 20190507 with price = 73.96 	Pos: 159
# Bought at 20190510 with price = 74.38 	Pos: 158
# Sold at 20190522 with price = 76.26 	Pos: 158
# Bought at 20190605 with price = 76.14 	Pos: 158
# Sold at 20190611 with price = 75.83 	Pos: 158
# Bought at 20190617 with price = 75.94 	Pos: 157
# Sold at 20190621 with price = 76.02 	Pos: 157
# Bought at 20190701 with price = 74.4 	Pos: 161
# Sold at 20190716 with price = 79.23 	Pos: 161
# Bought at 20190722 with price = 77.74 	Pos: 163
# Sold at 20190729 with price = 81.7 	Pos: 163
# Bought at 20190808 with price = 77.6 	Pos: 172
# Sold at 20190812 with price = 76.8 	Pos: 172
# Bought at 20190813 with price = 76.77 	Pos: 172
# Sold at 20190814 with price = 76.45 	Pos: 172
# Bought at 20190815 with price = 77.89 	Pos: 168
# Sold at 20190820 with price = 78.07 	Pos: 168
# Bought at 20190821 with price = 78.31 	Pos: 168
# Sold at 20190822 with price = 77.64 	Pos: 168
# Bought at 20190829 with price = 78.38 	Pos: 166
# Sold at 20190916 with price = 79.73 	Pos: 166
# Bought at 20190917 with price = 80.21 	Pos: 165
# Sold at 20190920 with price = 80.02 	Pos: 165
# Bought at 20191007 with price = 77.78 	Pos: 169
# Sold at 20191023 with price = 81.25 	Pos: 169
# Bought at 20191024 with price = 81.68 	Pos: 168
# Sold at 20191030 with price = 83.35 	Pos: 168
# Bought at 20191118 with price = 78.2 	Pos: 179
# Sold at 20191119 with price = 76.85 	Pos: 179
# Bought at 20191120 with price = 77.84 	Pos: 177
# Sold at 20191121 with price = 77.95 	Pos: 177
# Bought at 20191122 with price = 78.74 	Pos: 175
# Sold at 20191129 with price = 78.58 	Pos: 175
# Bought at 20191213 with price = 75.53 	Pos: 182
# ======= from 20190101 to 20191231 =========
# If buy at 20190108 with price = 68.65
# and do nothing
# Current Profit: 1342.0728749999998
# Current Profit with model: 4202.66031500003
# CAGR Performance: 28.61%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - TMUS from 20200101
# Transforming Data... - TMUS from 20200101
# Predicting... - TMUS from 20200101
# Converting... - TMUS from 20200101
# a
# b
# Backtesting... - TMUS from 20200101
# Clearing trade_record...
# Start Iteration... - TMUS from 20200101
# Start Backtesting...
# Bought at 20200108 with price = 79.77 	Pos: 125
# Sold at 20200123 with price = 82.29 	Pos: 125
# Bought at 20200130 with price = 80.59 	Pos: 127
# Sold at 20200218 with price = 101.16 	Pos: 127
# Bought at 20200324 with price = 77.77 	Pos: 165
# Sold at 20200413 with price = 87.19 	Pos: 165
# Bought at 20200414 with price = 87.92 	Pos: 164
# Sold at 20200420 with price = 89.25 	Pos: 164
# Bought at 20200506 with price = 90.35 	Pos: 162
# Sold at 20200513 with price = 92.54 	Pos: 162
# Bought at 20200515 with price = 98.16 	Pos: 152
# Sold at 20200520 with price = 98.75 	Pos: 152
# Bought at 20200527 with price = 97.52 	Pos: 154
# Sold at 20200611 with price = 104.25 	Pos: 154
# Bought at 20200615 with price = 104.0 	Pos: 154
# Sold at 20200616 with price = 103.0 	Pos: 154
# Bought at 20200617 with price = 103.82 	Pos: 153
# Sold at 20200624 with price = 109.78 	Pos: 153
# Bought at 20200702 with price = 106.6 	Pos: 157
# Sold at 20200707 with price = 106.25 	Pos: 157
# Bought at 20200708 with price = 106.66 	Pos: 156
# Sold at 20200709 with price = 105.8155 	Pos: 156
# Bought at 20200717 with price = 105.4 	Pos: 157
# Sold at 20200722 with price = 105.21 	Pos: 157
# Bought at 20200727 with price = 105.0 	Pos: 157
# Sold at 20200813 with price = 115.6998 	Pos: 157
# Bought at 20200817 with price = 117.68 	Pos: 154
# Sold at 20200818 with price = 116.69 	Pos: 154
# Bought at 20200831 with price = 116.63 	Pos: 154
# Sold at 20200901 with price = 117.83 	Pos: 154
# Bought at 20200915 with price = 116.41 	Pos: 156
# Sold at 20200917 with price = 112.21 	Pos: 156
# Bought at 20200925 with price = 112.87 	Pos: 155
# Sold at 20201002 with price = 113.46 	Pos: 155
# Bought at 20201005 with price = 113.61 	Pos: 154
# Sold at 20201006 with price = 113.02 	Pos: 154
# Bought at 20201008 with price = 115.5833 	Pos: 151
# Sold at 20201014 with price = 115.81 	Pos: 151
# Bought at 20201029 with price = 108.86 	Pos: 160
# Sold at 20201123 with price = 127.4705 	Pos: 160
# Bought at 20201125 with price = 129.12 	Pos: 158
# Sold at 20201202 with price = 131.65 	Pos: 158
# Bought at 20201218 with price = 130.0 	Pos: 160
# Sold at 20201229 with price = 133.52 	Pos: 160
# ======= from 20200101 to 20201231 =========
# If buy at 20200108 with price = 79.77
# and do nothing
# Current Profit: 6667.514374999999
# Current Profit with model: 11392.97429255004
# CAGR Performance: 47.25%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - TMUS from 20210101
# Transforming Data... - TMUS from 20210101
# Predicting... - TMUS from 20210101
# Converting... - TMUS from 20210101
# a
# b
# Backtesting... - TMUS from 20210101
# Clearing trade_record...
# Start Iteration... - TMUS from 20210101
# Start Backtesting...
# Bought at 20210108 with price = 134.0 	Pos: 74
# Sold at 20210111 with price = 132.88 	Pos: 74
# Bought at 20210119 with price = 130.12 	Pos: 76
# Sold at 20210125 with price = 130.02 	Pos: 76
# Bought at 20210201 with price = 128.63 	Pos: 76
# Sold at 20210204 with price = 129.02 	Pos: 76
# Bought at 20210225 with price = 119.75 	Pos: 82
# Sold at 20210303 with price = 119.19 	Pos: 82
# Bought at 20210304 with price = 120.02 	Pos: 82
# Sold at 20210311 with price = 126.57 	Pos: 82
# Bought at 20210325 with price = 123.87 	Pos: 83
# Sold at 20210409 with price = 128.49 	Pos: 83
# Bought at 20210412 with price = 130.3 	Pos: 82
# Sold at 20210421 with price = 132.0 	Pos: 82
# Bought at 20210422 with price = 131.75 	Pos: 82
# Sold at 20210503 with price = 130.83 	Pos: 82
# Bought at 20210505 with price = 133.68 	Pos: 80
# Sold at 20210512 with price = 137.07 	Pos: 80
# Bought at 20210514 with price = 140.15 	Pos: 78
# Sold at 20210517 with price = 139.98 	Pos: 78
# Bought at 20210524 with price = 137.97 	Pos: 79
# Sold at 20210614 with price = 145.38 	Pos: 79
# Bought at 20210617 with price = 146.23 	Pos: 79
# Sold at 20210618 with price = 145.97 	Pos: 79
# Bought at 20210621 with price = 145.71 	Pos: 79
# Sold at 20210623 with price = 145.38 	Pos: 79
# Bought at 20210624 with price = 145.79 	Pos: 79
# Sold at 20210625 with price = 145.27 	Pos: 79
# Bought at 20210628 with price = 144.69 	Pos: 79
# Sold at 20210709 with price = 146.19 	Pos: 79
# Bought at 20210712 with price = 146.81 	Pos: 78
# Sold at 20210716 with price = 147.5009 	Pos: 78
# Bought at 20210728 with price = 145.5 	Pos: 79
# Sold at 20210730 with price = 144.87 	Pos: 79
# Bought at 20210809 with price = 143.295 	Pos: 80
# Sold at 20210812 with price = 144.3 	Pos: 80
# Bought at 20210820 with price = 141.51 	Pos: 82
# Sold at 20210823 with price = 142.3 	Pos: 82
# Bought at 20210922 with price = 128.26 	Pos: 91
# Sold at 20210928 with price = 126.55 	Pos: 91
# Bought at 20211014 with price = 119.61 	Pos: 96
# Sold at 20211021 with price = 117.4 	Pos: 96
# Bought at 20211027 with price = 116.89 	Pos: 96
# Sold at 20211108 with price = 120.92 	Pos: 96
# Bought at 20211202 with price = 110.52 	Pos: 105
# Sold at 20211222 with price = 120.7101 	Pos: 105
# ======= from 20210101 to 20211231 =========
# If buy at 20210108 with price = 134.0
# and do nothing
# Current Profit: -1298.4779999999992
# Current Profit with model: 2737.2338446500253
# CAGR Performance: 40.36%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Runninng stock: VZ
# VZ Data loaded...
# Getting Data... - VZ from 20120101
# Transforming Data... - VZ from 20120101
# Predicting... - VZ from 20120101
# Converting... - VZ from 20120101
# a
# b
# Backtesting... - VZ from 20120101
# Clearing trade_record...
# Start Iteration... - VZ from 20120101
# Start Backtesting...
# Bought at 20120110 with price = 24.322 	Pos: 410
# Sold at 20120117 with price = 24.562 	Pos: 410
# Bought at 20120130 with price = 23.876 	Pos: 422
# Sold at 20120209 with price = 23.794 	Pos: 422
# Bought at 20120213 with price = 24.002 	Pos: 418
# Sold at 20120223 with price = 24.084 	Pos: 418
# Bought at 20120227 with price = 24.041 	Pos: 418
# Sold at 20120316 with price = 24.905 	Pos: 418
# Bought at 20120413 with price = 23.87 	Pos: 436
# Sold at 20120503 with price = 25.919 	Pos: 436
# Bought at 20120510 with price = 26.104 	Pos: 432
# Sold at 20120523 with price = 26.415 	Pos: 432
# Bought at 20120525 with price = 26.631 	Pos: 428
# Sold at 20120530 with price = 26.491 	Pos: 428
# Bought at 20120605 with price = 26.396 	Pos: 429
# Sold at 20120620 with price = 27.715 	Pos: 429
# Bought at 20120622 with price = 27.878 	Pos: 426
# Sold at 20120718 with price = 29.13 	Pos: 426
# Bought at 20120726 with price = 28.88 	Pos: 430
# Sold at 20120801 with price = 29.145 	Pos: 430
# Bought at 20120829 with price = 27.774 	Pos: 450
# Sold at 20120917 with price = 28.892 	Pos: 450
# Bought at 20120918 with price = 29.1 	Pos: 447
# Sold at 20121008 with price = 30.439 	Pos: 447
# Bought at 20121018 with price = 30.053 	Pos: 452
# Sold at 20121022 with price = 29.028 	Pos: 452
# Bought at 20121119 with price = 27.917 	Pos: 470
# Sold at 20121127 with price = 27.977 	Pos: 470
# Bought at 20121128 with price = 28.594 	Pos: 459
# Sold at 20121212 with price = 29.315 	Pos: 459
# ======= from 20120101 to 20121231 =========
# If buy at 20120109 with price = 24.354
# and do nothing
# Current Profit: 1399.2574299999997
# Current Profit with model: 3461.660291500013
# CAGR Performance: 20.62%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - VZ from 20130101
# Transforming Data... - VZ from 20130101
# Predicting... - VZ from 20130101
# Converting... - VZ from 20130101
# a
# b
# Backtesting... - VZ from 20130101
# Clearing trade_record...
# Start Iteration... - VZ from 20130101
# Start Backtesting...
# Bought at 20130118 with price = 28.441 	Pos: 351
# Sold at 20130327 with price = 32.4 	Pos: 351
# Bought at 20130403 with price = 32.409 	Pos: 350
# Sold at 20130404 with price = 32.434 	Pos: 350
# Bought at 20130405 with price = 32.74 	Pos: 347
# Sold at 20130417 with price = 34.121 	Pos: 347
# Bought at 20130418 with price = 34.293 	Pos: 345
# Sold at 20130501 with price = 35.081 	Pos: 345
# Bought at 20130507 with price = 35.308 	Pos: 342
# Sold at 20130513 with price = 35.089 	Pos: 342
# Bought at 20130605 with price = 32.285 	Pos: 372
# Sold at 20130612 with price = 33.342 	Pos: 372
# Bought at 20130613 with price = 33.811 	Pos: 366
# Sold at 20130619 with price = 33.211 	Pos: 366
# Bought at 20130625 with price = 33.954 	Pos: 358
# Sold at 20130701 with price = 33.656 	Pos: 358
# Bought at 20130703 with price = 34.27 	Pos: 351
# Sold at 20130710 with price = 34.433 	Pos: 351
# Bought at 20130724 with price = 33.954 	Pos: 355
# Sold at 20130729 with price = 35.063 	Pos: 355
# Bought at 20130830 with price = 30.733 	Pos: 405
# Sold at 20130903 with price = 30.865 	Pos: 405
# Bought at 20130909 with price = 31.03 	Pos: 403
# Sold at 20130919 with price = 32.807 	Pos: 403
# Bought at 20131008 with price = 31.552 	Pos: 418
# Sold at 20131009 with price = 31.851 	Pos: 418
# Bought at 20131010 with price = 31.959 	Pos: 416
# Sold at 20131028 with price = 34.561 	Pos: 416
# Bought at 20131030 with price = 34.848 	Pos: 412
# Sold at 20131031 with price = 34.682 	Pos: 412
# Bought at 20131114 with price = 34.247 	Pos: 417
# Sold at 20131120 with price = 34.547 	Pos: 417
# Bought at 20131218 with price = 33.252 	Pos: 433
# Sold at 20131230 with price = 33.82 	Pos: 433
# ======= from 20130101 to 20131231 =========
# If buy at 20130108 with price = 28.335
# and do nothing
# Current Profit: 1925.7330399999992
# Current Profit with model: 4657.88890750003
# CAGR Performance: 27.32%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - VZ from 20140101
# Transforming Data... - VZ from 20140101
# Predicting... - VZ from 20140101
# Converting... - VZ from 20140101
# a
# b
# Backtesting... - VZ from 20140101
# Clearing trade_record...
# Start Iteration... - VZ from 20140101
# Start Backtesting...
# Bought at 20140115 with price = 33.31 	Pos: 300
# Sold at 20140121 with price = 32.74 	Pos: 300
# Bought at 20140207 with price = 32.304 	Pos: 303
# Sold at 20140214 with price = 32.073 	Pos: 303
# Bought at 20140220 with price = 32.818 	Pos: 296
# Sold at 20140224 with price = 32.039 	Pos: 296
# Bought at 20140227 with price = 32.749 	Pos: 289
# Sold at 20140305 with price = 32.757 	Pos: 289
# Bought at 20140318 with price = 32.179 	Pos: 294
# Sold at 20140410 with price = 33.044 	Pos: 294
# Bought at 20140417 with price = 33.337 	Pos: 291
# Sold at 20140422 with price = 33.01 	Pos: 291
# Bought at 20140429 with price = 32.592 	Pos: 295
# Sold at 20140513 with price = 33.5 	Pos: 295
# Bought at 20140515 with price = 33.994 	Pos: 290
# Sold at 20140603 with price = 34.418 	Pos: 290
# Bought at 20140609 with price = 34.508 	Pos: 289
# Sold at 20140611 with price = 34.384 	Pos: 289
# Bought at 20140617 with price = 34.203 	Pos: 290
# Sold at 20140624 with price = 34.293 	Pos: 290
# Bought at 20140701 with price = 34.559 	Pos: 288
# Sold at 20140724 with price = 36.024 	Pos: 288
# Bought at 20140812 with price = 34.577 	Pos: 300
# Sold at 20140815 with price = 34.601 	Pos: 300
# Bought at 20140820 with price = 34.466 	Pos: 301
# Sold at 20140904 with price = 35.079 	Pos: 301
# Bought at 20140916 with price = 34.601 	Pos: 304
# Sold at 20140923 with price = 35.265 	Pos: 304
# Bought at 20141003 with price = 35.226 	Pos: 304
# Sold at 20141008 with price = 35.491 	Pos: 304
# Bought at 20141017 with price = 34.281 	Pos: 315
# Sold at 20141111 with price = 35.916 	Pos: 315
# Bought at 20141112 with price = 36.135 	Pos: 313
# Sold at 20141113 with price = 36.556 	Pos: 313
# Bought at 20141217 with price = 33.739 	Pos: 338
# Sold at 20141229 with price = 33.893 	Pos: 338
# ======= from 20140101 to 20141231 =========
# If buy at 20140108 with price = 33.427
# and do nothing
# Current Profit: 41.94566350000241
# Current Profit with model: 1482.1117705000197
# CAGR Performance: 14.4%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - VZ from 20150101
# Transforming Data... - VZ from 20150101
# Predicting... - VZ from 20150101
# Converting... - VZ from 20150101
# a
# b
# Backtesting... - VZ from 20150101
# Clearing trade_record...
# Start Iteration... - VZ from 20150101
# Start Backtesting...
# Bought at 20150108 with price = 34.087 	Pos: 293
# Sold at 20150122 with price = 34.563 	Pos: 293
# Bought at 20150129 with price = 33.078 	Pos: 306
# Sold at 20150213 with price = 35.381 	Pos: 306
# Bought at 20150224 with price = 35.627 	Pos: 303
# Sold at 20150302 with price = 35.691 	Pos: 303
# Bought at 20150312 with price = 35.012 	Pos: 309
# Sold at 20150324 with price = 35.639 	Pos: 309
# Bought at 20150330 with price = 35.43 	Pos: 310
# Sold at 20150430 with price = 37.005 	Pos: 310
# Bought at 20150511 with price = 36.035 	Pos: 318
# Sold at 20150512 with price = 36.232 	Pos: 318
# Bought at 20150611 with price = 34.852 	Pos: 331
# Sold at 20150612 with price = 34.405 	Pos: 331
# Bought at 20150616 with price = 34.67 	Pos: 328
# Sold at 20150622 with price = 34.931 	Pos: 328
# Bought at 20150623 with price = 34.744 	Pos: 329
# Sold at 20150624 with price = 34.763 	Pos: 329
# Bought at 20150702 with price = 34.348 	Pos: 333
# Sold at 20150720 with price = 34.7 	Pos: 333
# Bought at 20150728 with price = 33.968 	Pos: 340
# Sold at 20150814 with price = 34.915 	Pos: 340
# Bought at 20150827 with price = 34.015 	Pos: 348
# Sold at 20150901 with price = 33.601 	Pos: 348
# Bought at 20150908 with price = 34.153 	Pos: 342
# Sold at 20150910 with price = 33.556 	Pos: 342
# Bought at 20150911 with price = 33.807 	Pos: 339
# Sold at 20150914 with price = 33.91 	Pos: 339
# Bought at 20151002 with price = 31.932 	Pos: 360
# Sold at 20151103 with price = 34.844 	Pos: 360
# Bought at 20151117 with price = 33.723 	Pos: 372
# Sold at 20151120 with price = 33.893 	Pos: 372
# Bought at 20151201 with price = 33.998 	Pos: 370
# Sold at 20151202 with price = 33.577 	Pos: 370
# Bought at 20151207 with price = 34.164 	Pos: 363
# Sold at 20151210 with price = 33.657 	Pos: 363
# Bought at 20151214 with price = 34.051 	Pos: 359
# Sold at 20151221 with price = 34.561 	Pos: 359
# Bought at 20151222 with price = 34.794 	Pos: 356
# Sold at 20151228 with price = 35.141 	Pos: 356
# ======= from 20150101 to 20151231 =========
# If buy at 20150108 with price = 34.087
# and do nothing
# Current Profit: 203.62225449999823
# Current Profit with model: 2524.877431500021
# CAGR Performance: 23.21%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - VZ from 20160101
# Transforming Data... - VZ from 20160101
# Predicting... - VZ from 20160101
# Converting... - VZ from 20160101
# a
# b
# Backtesting... - VZ from 20160101
# Clearing trade_record...
# Start Iteration... - VZ from 20160101
# Start Backtesting...
# Bought at 20160114 with price = 33.35 	Pos: 299
# Sold at 20160204 with price = 38.106 	Pos: 299
# Bought at 20160205 with price = 38.319 	Pos: 297
# Sold at 20160208 with price = 37.91 	Pos: 297
# Bought at 20160212 with price = 38.046 	Pos: 296
# Sold at 20160322 with price = 40.232 	Pos: 296
# Bought at 20160324 with price = 40.558 	Pos: 293
# Sold at 20160331 with price = 40.379 	Pos: 293
# Bought at 20160419 with price = 39.908 	Pos: 296
# Sold at 20160420 with price = 38.691 	Pos: 296
# Bought at 20160427 with price = 39.258 	Pos: 292
# Sold at 20160429 with price = 39.199 	Pos: 292
# Bought at 20160502 with price = 39.115 	Pos: 292
# Sold at 20160503 with price = 38.63 	Pos: 292
# Bought at 20160510 with price = 39.396 	Pos: 286
# Sold at 20160511 with price = 39.199 	Pos: 286
# Bought at 20160525 with price = 38.148 	Pos: 294
# Sold at 20160708 with price = 43.093 	Pos: 294
# Bought at 20160713 with price = 42.994 	Pos: 294
# Sold at 20160714 with price = 43.325 	Pos: 294
# Bought at 20160825 with price = 40.693 	Pos: 313
# Sold at 20160826 with price = 40.473 	Pos: 313
# Bought at 20160830 with price = 40.366 	Pos: 313
# Sold at 20160831 with price = 40.303 	Pos: 313
# Bought at 20160901 with price = 40.813 	Pos: 309
# Sold at 20160908 with price = 41.07 	Pos: 309
# Bought at 20160915 with price = 40.11 	Pos: 316
# Sold at 20160916 with price = 40.11 	Pos: 316
# Bought at 20160919 with price = 39.886 	Pos: 318
# Sold at 20160927 with price = 40.437 	Pos: 318
# Bought at 20161027 with price = 37.965 	Pos: 338
# Sold at 20161028 with price = 37.715 	Pos: 338
# Bought at 20161107 with price = 37.182 	Pos: 343
# Sold at 20161109 with price = 37.415 	Pos: 343
# Bought at 20161116 with price = 37.488 	Pos: 342
# ...
# Sold at 20150204 with price = 105.63 	Pos: 84
# Bought at 20150212 with price = 105.06 	Pos: 85
# Sold at 20150225 with price = 110.04 	Pos: 85
# Bought at 20150316 with price = 93.315 	Pos: 100
# Sold at 20150410 with price = 109.24 	Pos: 100
# Bought at 20150423 with price = 104.71 	Pos: 104
# Sold at 20150513 with price = 102.58 	Pos: 104
# Bought at 20150515 with price = 104.21 	Pos: 102
# Sold at 20150609 with price = 115.33 	Pos: 102
# Bought at 20150616 with price = 111.92 	Pos: 105
# Sold at 20150707 with price = 114.31 	Pos: 105
# Bought at 20150710 with price = 113.51 	Pos: 106
# Sold at 20150717 with price = 113.51 	Pos: 106
# Bought at 20150722 with price = 114.67 	Pos: 105
# Sold at 20150723 with price = 114.01 	Pos: 105
# Bought at 20150729 with price = 114.21 	Pos: 104
# Sold at 20150804 with price = 114.78 	Pos: 104
# Bought at 20150805 with price = 116.31 	Pos: 103
# Sold at 20150806 with price = 113.76 	Pos: 103
# Bought at 20150814 with price = 113.3 	Pos: 103
# Sold at 20150820 with price = 112.7 	Pos: 103
# Bought at 20150826 with price = 116.21 	Pos: 100
# Sold at 20150902 with price = 118.04 	Pos: 100
# Bought at 20150903 with price = 116.21 	Pos: 102
# Sold at 20150904 with price = 118.0 	Pos: 102
# Bought at 20150916 with price = 114.55 	Pos: 104
# Sold at 20150918 with price = 111.69 	Pos: 104
# Bought at 20150930 with price = 100.96 	Pos: 116
# Sold at 20151001 with price = 98.108 	Pos: 116
# Bought at 20151002 with price = 100.97 	Pos: 112
# Sold at 20151012 with price = 99.168 	Pos: 112
# Bought at 20151013 with price = 99.71 	Pos: 111
# Sold at 20151014 with price = 99.52 	Pos: 111
# Bought at 20151016 with price = 99.75 	Pos: 111
# Sold at 20151019 with price = 99.24 	Pos: 111
# Bought at 20151028 with price = 89.599 	Pos: 123
# Sold at 20151109 with price = 90.172 	Pos: 123
# Bought at 20151117 with price = 84.845 	Pos: 131
# Sold at 20151124 with price = 92.264 	Pos: 131
# Bought at 20151223 with price = 73.294 	Pos: 164
# Sold at 20151224 with price = 72.234 	Pos: 164
# Bought at 20151228 with price = 73.056 	Pos: 162
# Sold at 20151230 with price = 72.402 	Pos: 162
# ======= from 20150101 to 20151231 =========
# If buy at 20150108 with price = 117.86
# and do nothing
# Current Profit: -3823.4221199999993
# Current Profit with model: 1784.2335780000376
# CAGR Performance: 56.08%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - PVH from 20160101
# Transforming Data... - PVH from 20160101
# Predicting... - PVH from 20160101
# Converting... - PVH from 20160101
# a
# b
# Backtesting... - PVH from 20160101
# Clearing trade_record...
# Start Iteration... - PVH from 20160101
# Start Backtesting...
# Bought at 20160121 with price = 69.207 	Pos: 144
# Sold at 20160204 with price = 76.172 	Pos: 144
# Bought at 20160212 with price = 73.742 	Pos: 148
# Sold at 20160309 with price = 84.668 	Pos: 148
# Bought at 20160310 with price = 86.129 	Pos: 146
# Sold at 20160401 with price = 98.438 	Pos: 146
# Bought at 20160413 with price = 94.237 	Pos: 152
# Sold at 20160419 with price = 94.246 	Pos: 152
# Bought at 20160420 with price = 95.419 	Pos: 150
# Sold at 20160422 with price = 94.791 	Pos: 150
# Bought at 20160517 with price = 85.361 	Pos: 166
# Sold at 20160606 with price = 95.002 	Pos: 166
# Bought at 20160607 with price = 96.475 	Pos: 164
# Sold at 20160608 with price = 95.391 	Pos: 164
# Bought at 20160615 with price = 95.928 	Pos: 163
# Sold at 20160622 with price = 101.14 	Pos: 163
# Bought at 20160630 with price = 93.744 	Pos: 175
# Sold at 20160715 with price = 97.934 	Pos: 175
# Bought at 20160720 with price = 99.24 	Pos: 173
# Sold at 20160725 with price = 99.84 	Pos: 173
# Bought at 20160808 with price = 97.325 	Pos: 177
# Sold at 20160825 with price = 107.23 	Pos: 177
# Bought at 20160830 with price = 107.22 	Pos: 177
# Sold at 20160909 with price = 106.63 	Pos: 177
# Bought at 20160915 with price = 105.95 	Pos: 178
# Sold at 20160916 with price = 107.42 	Pos: 178
# Bought at 20160919 with price = 108.09 	Pos: 177
# Sold at 20160923 with price = 107.46 	Pos: 177
# Bought at 20160928 with price = 105.78 	Pos: 179
# Sold at 20161011 with price = 112.16 	Pos: 179
# Bought at 20161031 with price = 106.87 	Pos: 188
# Sold at 20161102 with price = 106.58 	Pos: 188
# Bought at 20161104 with price = 105.33 	Pos: 190
# Sold at 20161114 with price = 105.1 	Pos: 190
# Bought at 20161117 with price = 109.26 	Pos: 182
# Sold at 20161121 with price = 107.81 	Pos: 182
# Bought at 20161122 with price = 107.65 	Pos: 183
# Sold at 20161123 with price = 108.91 	Pos: 183
# Bought at 20161229 with price = 90.21 	Pos: 220
# ======= from 20160101 to 20161231 =========
# If buy at 20160108 with price = 69.933
# and do nothing
# Current Profit: 2874.368757
# Current Profit with model: 9913.75365750002
# CAGR Performance: 70.39%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - PVH from 20170101
# Transforming Data... - PVH from 20170101
# Predicting... - PVH from 20170101
# Converting... - PVH from 20170101
# a
# b
# Backtesting... - PVH from 20170101
# Clearing trade_record...
# Start Iteration... - PVH from 20170101
# Start Backtesting...
# Bought at 20170118 with price = 92.456 	Pos: 108
# Sold at 20170119 with price = 91.352 	Pos: 108
# Bought at 20170209 with price = 87.536 	Pos: 112
# Sold at 20170216 with price = 87.646 	Pos: 112
# Bought at 20170222 with price = 90.934 	Pos: 108
# Sold at 20170228 with price = 91.946 	Pos: 108
# Bought at 20170308 with price = 90.666 	Pos: 109
# Sold at 20170331 with price = 102.87 	Pos: 109
# Bought at 20170420 with price = 100.12 	Pos: 112
# Sold at 20170421 with price = 99.428 	Pos: 112
# Bought at 20170424 with price = 101.81 	Pos: 109
# Sold at 20170428 with price = 100.43 	Pos: 109
# Bought at 20170505 with price = 102.7 	Pos: 107
# Sold at 20170510 with price = 101.38 	Pos: 107
# Bought at 20170519 with price = 100.82 	Pos: 107
# Sold at 20170531 with price = 105.46 	Pos: 107
# Bought at 20170609 with price = 104.79 	Pos: 108
# Sold at 20170615 with price = 104.9 	Pos: 108
# Bought at 20170619 with price = 105.02 	Pos: 108
# Sold at 20170703 with price = 114.02 	Pos: 108
# Bought at 20170711 with price = 111.66 	Pos: 110
# Sold at 20170810 with price = 120.69 	Pos: 110
# Bought at 20170823 with price = 127.37 	Pos: 104
# Sold at 20170830 with price = 125.93 	Pos: 104
# Bought at 20170831 with price = 125.57 	Pos: 104
# Sold at 20170907 with price = 127.94 	Pos: 104
# Bought at 20171002 with price = 126.37 	Pos: 105
# Sold at 20171003 with price = 125.7 	Pos: 105
# Bought at 20171004 with price = 126.57 	Pos: 105
# Sold at 20171006 with price = 125.26 	Pos: 105
# Bought at 20171018 with price = 123.54 	Pos: 106
# Sold at 20171025 with price = 129.48 	Pos: 106
# Bought at 20171110 with price = 126.6 	Pos: 108
# Sold at 20171124 with price = 134.82 	Pos: 108
# Bought at 20171215 with price = 133.73 	Pos: 109
# Sold at 20171226 with price = 136.27 	Pos: 109
# Bought at 20171227 with price = 136.11 	Pos: 109
# ======= from 20170101 to 20171231 =========
# If buy at 20170109 with price = 92.186
# and do nothing
# Current Profit: 4848.973955999998
# Current Profit with model: 5008.666641000027
# CAGR Performance: 1.6%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - PVH from 20180101
# Transforming Data... - PVH from 20180101
# Predicting... - PVH from 20180101
# Converting... - PVH from 20180101
# a
# b
# Backtesting... - PVH from 20180101
# Clearing trade_record...
# Start Iteration... - PVH from 20180101
# Start Backtesting...
# Bought at 20180108 with price = 141.32 	Pos: 70
# Sold at 20180201 with price = 152.58 	Pos: 70
# Bought at 20180212 with price = 145.52 	Pos: 74
# Sold at 20180216 with price = 145.98 	Pos: 74
# Bought at 20180223 with price = 148.71 	Pos: 72
# Sold at 20180226 with price = 149.9 	Pos: 72
# Bought at 20180308 with price = 140.19 	Pos: 77
# Sold at 20180321 with price = 141.61 	Pos: 77
# Bought at 20180322 with price = 141.57 	Pos: 77
# Sold at 20180418 with price = 160.12 	Pos: 77
# Bought at 20180419 with price = 159.2 	Pos: 77
# Sold at 20180420 with price = 159.37 	Pos: 77
# Bought at 20180508 with price = 151.03 	Pos: 82
# Sold at 20180612 with price = 165.23 	Pos: 82
# Bought at 20180706 with price = 145.87 	Pos: 92
# Sold at 20180727 with price = 152.88 	Pos: 92
# Bought at 20180806 with price = 152.08 	Pos: 93
# Sold at 20180813 with price = 152.27 	Pos: 93
# Bought at 20180820 with price = 151.58 	Pos: 93
# Sold at 20180824 with price = 154.95 	Pos: 93
# Bought at 20180910 with price = 135.81 	Pos: 106
# Sold at 20180928 with price = 143.93 	Pos: 106
# Bought at 20181016 with price = 129.16 	Pos: 118
# Sold at 20181018 with price = 125.88 	Pos: 118
# Bought at 20181025 with price = 118.82 	Pos: 125
# Sold at 20181107 with price = 123.43 	Pos: 125
# Bought at 20181123 with price = 110.89 	Pos: 139
# Sold at 20181127 with price = 109.91 	Pos: 139
# Bought at 20181221 with price = 87.832 	Pos: 174
# ======= from 20180101 to 20181231 =========
# If buy at 20180108 with price = 141.32
# and do nothing
# Current Profit: -3442.3662000000004
# Current Profit with model: 6085.610461000017
# CAGR Performance: 95.28%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - PVH from 20190101
# Transforming Data... - PVH from 20190101
# Predicting... - PVH from 20190101
# Converting... - PVH from 20190101
# a
# b
# Backtesting... - PVH from 20190101
# Clearing trade_record...
# Start Iteration... - PVH from 20190101
# Start Backtesting...
# Bought at 20190108 with price = 102.49 	Pos: 97
# Sold at 20190123 with price = 103.83 	Pos: 97
# Bought at 20190125 with price = 106.58 	Pos: 94
# Sold at 20190215 with price = 112.55 	Pos: 94
# Bought at 20190219 with price = 112.66 	Pos: 94
# Sold at 20190226 with price = 115.07 	Pos: 94
# Bought at 20190312 with price = 112.09 	Pos: 97
# Sold at 20190314 with price = 112.4 	Pos: 97
# Bought at 20190321 with price = 107.93 	Pos: 100
# Sold at 20190409 with price = 126.35 	Pos: 100
# Bought at 20190411 with price = 126.96 	Pos: 100
# Sold at 20190418 with price = 131.57 	Pos: 100
# Bought at 20190604 with price = 91.425 	Pos: 144
# Sold at 20190606 with price = 87.625 	Pos: 144
# Bought at 20190620 with price = 90.236 	Pos: 139
# Sold at 20190627 with price = 92.839 	Pos: 139
# Bought at 20190628 with price = 96.937 	Pos: 133
# Sold at 20190702 with price = 93.857 	Pos: 133
# Bought at 20190716 with price = 87.905 	Pos: 142
# Sold at 20190717 with price = 89.26 	Pos: 142
# Bought at 20190820 with price = 72.368 	Pos: 175
# Sold at 20190823 with price = 69.677 	Pos: 175
# Bought at 20190826 with price = 70.873 	Pos: 172
# Sold at 20190913 with price = 89.15 	Pos: 172
# Bought at 20190925 with price = 87.165 	Pos: 176
# Sold at 20190926 with price = 86.895 	Pos: 176
# Bought at 20191007 with price = 82.266 	Pos: 186
# Sold at 20191008 with price = 81.798 	Pos: 186
# Bought at 20191009 with price = 82.815 	Pos: 183
# Sold at 20191025 with price = 91.126 	Pos: 183
# Bought at 20191031 with price = 87.884 	Pos: 190
# Sold at 20191113 with price = 96.941 	Pos: 190
# Bought at 20191114 with price = 98.339 	Pos: 187
# Sold at 20191120 with price = 97.541 	Pos: 187
# Bought at 20191122 with price = 100.49 	Pos: 181
# Sold at 20191127 with price = 96.681 	Pos: 181
# Bought at 20191204 with price = 97.949 	Pos: 179
# Sold at 20191218 with price = 106.27 	Pos: 179
# ======= from 20190101 to 20191231 =========
# If buy at 20190108 with price = 102.49
# and do nothing
# Current Profit: 123.06923500000084
# Current Profit with model: 9016.759486500036
# CAGR Performance: 88.94%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - PVH from 20200101
# Transforming Data... - PVH from 20200101
# Predicting... - PVH from 20200101
# Converting... - PVH from 20200101
# a
# b
# Backtesting... - PVH from 20200101
# Clearing trade_record...
# Start Iteration... - PVH from 20200101
# Start Backtesting...
# Bought at 20200324 with price = 36.49 	Pos: 273
# Sold at 20200330 with price = 37.919 	Pos: 273
# Bought at 20200406 with price = 43.644 	Pos: 237
# Sold at 20200413 with price = 47.581 	Pos: 237
# Bought at 20200423 with price = 40.107 	Pos: 281
# Sold at 20200430 with price = 46.981 	Pos: 281
# Bought at 20200518 with price = 43.904 	Pos: 300
# Sold at 20200601 with price = 48.561 	Pos: 300
# Bought at 20200602 with price = 51.378 	Pos: 284
# Sold at 20200610 with price = 53.756 	Pos: 284
# Bought at 20200629 with price = 48.551 	Pos: 314
# Sold at 20200630 with price = 47.851 	Pos: 314
# Bought at 20200702 with price = 48.699 	Pos: 308
# Sold at 20200706 with price = 45.552 	Pos: 308
# Bought at 20200710 with price = 44.693 	Pos: 314
# Sold at 20200721 with price = 48.051 	Pos: 314
# Bought at 20200722 with price = 48.959 	Pos: 307
# Sold at 20200730 with price = 50.129 	Pos: 307
# Bought at 20200804 with price = 48.59 	Pos: 317
# Sold at 20200817 with price = 54.116 	Pos: 317
# Bought at 20200821 with price = 49.919 	Pos: 343
# Sold at 20200916 with price = 70.771 	Pos: 343
# Bought at 20201002 with price = 62.838 	Pos: 386
# Sold at 20201012 with price = 64.896 	Pos: 386
# Bought at 20201022 with price = 65.826 	Pos: 380
# Sold at 20201023 with price = 64.496 	Pos: 380
# Bought at 20201103 with price = 62.169 	Pos: 394
# Sold at 20201130 with price = 82.282 	Pos: 394
# Bought at 20201201 with price = 80.473 	Pos: 402
# Sold at 20201216 with price = 94.572 	Pos: 402
# Bought at 20201217 with price = 95.671 	Pos: 397
# Sold at 20201218 with price = 93.583 	Pos: 397
# Bought at 20201228 with price = 94.822 	Pos: 392
# ======= from 20200101 to 20201231 =========
# If buy at 20200108 with price = 106.34
# and do nothing
# Current Profit: -1104.0188099999996
# Current Profit with model: 27062.901782000044
# CAGR Performance: 281.67%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - PVH from 20210101
# Transforming Data... - PVH from 20210101
# Predicting... - PVH from 20210101
# Converting... - PVH from 20210101
# a
# b
# Backtesting... - PVH from 20210101
# Clearing trade_record...
# Start Iteration... - PVH from 20210101
# Start Backtesting...
# Bought at 20210108 with price = 101.75 	Pos: 98
# Sold at 20210111 with price = 105.12 	Pos: 98
# Bought at 20210202 with price = 86.368 	Pos: 119
# Sold at 20210212 with price = 96.56 	Pos: 119
# Bought at 20210222 with price = 97.2 	Pos: 118
# Sold at 20210316 with price = 106.15 	Pos: 118
# Bought at 20210326 with price = 101.06 	Pos: 124
# Sold at 20210401 with price = 102.33 	Pos: 124
# Bought at 20210405 with price = 103.55 	Pos: 122
# Sold at 20210414 with price = 109.06 	Pos: 122
# Bought at 20210421 with price = 108.18 	Pos: 123
# Sold at 20210507 with price = 118.68 	Pos: 123
# Bought at 20210514 with price = 113.28 	Pos: 129
# Sold at 20210520 with price = 110.49 	Pos: 129
# Bought at 20210525 with price = 111.25 	Pos: 128
# Sold at 20210601 with price = 114.1 	Pos: 128
# Bought at 20210608 with price = 112.77 	Pos: 129
# Sold at 20210609 with price = 111.39 	Pos: 129
# Bought at 20210611 with price = 112.54 	Pos: 128
# Sold at 20210614 with price = 108.95 	Pos: 128
# Bought at 20210623 with price = 107.65 	Pos: 129
# Sold at 20210629 with price = 104.95 	Pos: 129
# Bought at 20210630 with price = 108.74 	Pos: 124
# Sold at 20210706 with price = 105.59 	Pos: 124
# Bought at 20210721 with price = 101.71 	Pos: 129
# Sold at 20210816 with price = 110.38 	Pos: 129
# Bought at 20210823 with price = 107.47 	Pos: 132
# Sold at 20210903 with price = 114.81 	Pos: 132
# Bought at 20210922 with price = 109.28 	Pos: 139
# Sold at 20210928 with price = 112.86 	Pos: 139
# Bought at 20211006 with price = 107.04 	Pos: 146
# Sold at 20211007 with price = 106.34 	Pos: 146
# Bought at 20211012 with price = 107.1 	Pos: 145
# Sold at 20211027 with price = 109.54 	Pos: 145
# Bought at 20211028 with price = 108.82 	Pos: 146
# Sold at 20211109 with price = 121.92 	Pos: 146
# Bought at 20211207 with price = 104.02 	Pos: 171
# Sold at 20211209 with price = 103.76 	Pos: 171
# Bought at 20211217 with price = 95.672 	Pos: 185
# ======= from 20210101 to 20211231 =========
# If buy at 20210108 with price = 101.75
# and do nothing
# Current Profit: 365.4542500000007
# Current Profit with model: 9601.686794000034
# CAGR Performance: 92.36%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Backtesting Completed...
