# %% [markdown]
# # Import Package

# %%
import pandas as pd
import numpy as np
import os
from math import floor
from operator import add

# %%
from google.colab import drive
drive.mount('/content/drive')

volatility_folder = "/content/drive/MyDrive/fyp/Final report/4. Backtesting/Volatility_result/"
backtest_summary_folder = volatility_folder + "backtest_summary/"
record_folder = volatility_folder + "trade_record/"
user_test_folder = volatility_folder + "user_test/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Calculate model-stock volatility based on the year

# %%
def get_sd_file(start_year,end_year):
  summary_to_process = list(filter(lambda file: "_sd" not in file and "_mean" not in file,os.listdir(backtest_summary_folder)))
  for file in summary_to_process:
    df = pd.read_csv(backtest_summary_folder+file,index_col = 0)
    df = df[(df["Range_Start"] >= start_year*10000+101) & (df["Range_Start"] <= end_year*10000+101)]
    new_sd_summary = df.groupby(["Sector","Stock"])[["Sector",
                                                    "Stock",
                                                    "CAGR_Performance(in %)",
                                                    "MDD_Performance(in %)"]].std()
                                                    
    new_sd_summary = new_sd_summary.reset_index()
    new_sd_summary.dropna(inplace = True)
    new_sd_summary.to_csv(backtest_summary_folder+file[:-4]+"_sd.csv")
    print("Exported... for",file)

get_sd_file(2012,2018)
# Out:
# Exported... for [5]backtest_summary_SVC.csv
# Exported... for [5]backtest_summary_SVR.csv
# Exported... for backtest_summary_twap.csv
# Exported... for backtest_summary_CNN_LSTM_CLASS.csv
# Exported... for backtest_summary_CNN_LSTM_REG.csv
# Exported... for backtest_summary_CAT.csv
# Exported... for backtest_summary_Xgb.csv

# %% [markdown]
# # Make Volatility Summary

# %%
model_bactest_summary_list = {"[5]SVC":"[5]backtest_summary_SVC_sd.csv",
                              "[5]SVR":"[5]backtest_summary_SVR_sd.csv",
                              "CNN_LSTM_CLASS":"backtest_summary_CNN_LSTM_CLASS_sd.csv",
                              "CNN_LSTM_REG":"backtest_summary_CNN_LSTM_REG_sd.csv",
                              "CAT":"backtest_summary_CAT_sd.csv",
                              "XGB":"backtest_summary_Xgb_sd.csv",
                              "TWAP":"backtest_summary_twap_sd.csv"}

volatility_summary = pd.DataFrame(columns=["Sector","Stock","Model","Volatility"])

for model,file in model_bactest_summary_list.items():
    df = pd.read_csv(backtest_summary_folder+file,index_col = 0) # Read the model-stock volatility
    df = df.rename(columns={"CAGR_Performance(in %)":"Volatility"}) # Use CAGR Performance SD as volatility
    df = df[["Sector","Stock","Volatility"]] # Only Keep necessary columns
    df["Model"] = model # Record which model
    
    # Reorder the col
    volatility_summary = volatility_summary.append(df,ignore_index = True)
    
    # Standardize sector format
    volatility_summary["Sector"] = list(map(lambda sector: sector.title(), volatility_summary["Sector"]))

volatility_summary = volatility_summary.sort_values(by=["Volatility"],ascending = [False])
volatility_summary.to_csv(volatility_folder+"Stock_Model_Volatility_summary.csv",index = False)   
print("Export Completed...")
# Out:
# Export Completed...

# %% [markdown]
# # Statistics on Volatility Summary

# %%
print("VolatilityMax:",max(volatility_summary["Volatility"]))
print("VolatilityMin:",min(volatility_summary["Volatility"]))
print("VolatilityMean:",np.mean(volatility_summary["Volatility"]))
# Out:
# VolatilityMax: 153.05928468593936
# VolatilityMin: 0.9475230867899735
# VolatilityMean: 24.28400589176513

# %% [markdown]
# # Set cut off and show counting

# %%
# Below cutoff_1 => Low Risk Level
# Between cutoff_1 and cutoff_2 => Medium Risk Level
# above cutoff_2 => High Risk Level
cutoff_1 = 13
cutoff_2 = 30

low = volatility_summary[(volatility_summary["Volatility"] <= cutoff_1)]["Volatility"].count() 
medium = volatility_summary[(volatility_summary["Volatility"] > cutoff_1) & (volatility_summary["Volatility"] <= cutoff_2)]["Volatility"].count() 
high = volatility_summary[volatility_summary["Volatility"] > cutoff_2]["Volatility"].count() 

# Count of stock in each level
print("Low Level:\t",low)
print("Medium Level:\t", medium)
print("High Level\t", high)
# Out:
# Low Level:	 83
# Medium Level:	 157
# High Level	 75

# %% [markdown]
# # Assign risk_level

# %%
# Append the risk level column

def classify_risk_level(volatility):
    global cutoff_1
    global cutoff_2
    if volatility <= cutoff_1:
        return "low"
    elif volatility <= cutoff_2:
        return "medium"
    else:
        return "high"
    
volatility_summary["risk_level"] = volatility_summary["Volatility"].apply(classify_risk_level)

# %%
volatility_summary
# Out:
#                  Sector Stock           Model  Volatility risk_level
# 300      Semiconductors   AMD            TWAP  153.059285       high
# 75       Semiconductors   AMD          [5]SVR  115.584027       high
# 210      Semiconductors   AMD             CAT  107.803002       high
# 120      Semiconductors   AMD  CNN_LSTM_CLASS  106.605977       high
# 192       Entertainment  NFLX             CAT  102.724870       high
# ..                  ...   ...             ...         ...        ...
# 136             Airline    GD    CNN_LSTM_REG    5.337012        low
# 144  Energy & Resources    DD    CNN_LSTM_REG    4.644089        low
# 175   Telecommunication     T    CNN_LSTM_REG    4.365728        low
# 159         Real Estate   SPG    CNN_LSTM_REG    3.556537        low
# 171        Social Media  SNAP    CNN_LSTM_REG    0.947523        low
#
# [315 rows x 5 columns]

# %% [markdown]
# # Get dummy user

# %%
user_df = pd.read_csv(volatility_folder + "user.csv",index_col = 0)

def get_risk_level_by_id(user_df, uid):
  return user_df.loc[uid,"risk_level"]

# %%
user_df
# Out:
#         age  portion    item      risk                              why  \
# 1     31-45    0-20%  20-40k    10-20%         2. Only source of profit
# 2     18-22  81-100%   0-10k    10-20%  1. Stock as a part of portfolio
# 3     31-45    0-20%  20-40k    10-20%    3. As a part of experience :)
# 4     18-22  81-100%  10-20k    10-20%    3. As a part of experience :)
# 5     31-45   61-80%  10-20k  over 30%    3. As a part of experience :)
# ...     ...      ...     ...       ...                              ...
# 996   31-45  81-100%  10-20k  over 30%         2. Only source of profit
# 997   46-65   21-40%  40-80k    10-20%  1. Stock as a part of portfolio
# 998     >65  81-100%  20-40k    10-20%    3. As a part of experience :)
# 999   23-30  81-100%  20-40k  over 30%         2. Only source of profit
# 1000  18-22   41-60%    >80k    20-30%         2. Only source of profit
#
#                               term  bearing  \
# 1     Short Term (within 3 months)        1
# 2          Regular (6month~1 year)        1
# 3     Short Term (within 3 months)        6
# 4     Short Term (within 3 months)        2
# 5         Long (More than 3 years)        6
# ...                            ...      ...
# 996        Regular (6month~1 year)        1
# 997          Quite Long (1~3 year)        9
# 998        Regular (6month~1 year)       10
# 999   Short Term (within 3 months)        9
# 1000         Quite Long (1~3 year)        6
#
#                                                  types profit_exp  conf  \
# 1                                              ['ETF']       >80%     7
# 2                                  ['Leverage', 'ETF']     40-80%     9
# 3                 ['Fund', 'ETF', 'Individual Stocks']     10-20%     3
# 4     ['Fund', 'Individual Stocks', 'Leverage', 'ETF']     20-40%     6
# 5                                             ['Fund']       >80%     8
# ...                                                ...        ...   ...
# 996                                           ['Fund']     20-40%    10
# 997   ['Fund', 'Individual Stocks', 'Leverage', 'ETF']     10-20%     8
# 998                        ['Fund', 'Leverage', 'ETF']      0-10%     7
# 999          ['Individual Stocks', 'Fund', 'Leverage']       >80%     2
# 1000  ['Individual Stocks', 'Leverage', 'ETF', 'Fund']       >80%    10
#
#                                                   res_1  \
# 1     2. Sell majority of stock and take some time b...
# 2           5. Remain calm and keep the portfolio as is
# 3                        1. Sell everything and give up
# 4     2. Sell majority of stock and take some time b...
# 5          3. Take out 50%, and wait before the rebound
# ...                                                 ...
# 996         5. Remain calm and keep the portfolio as is
# 997   4. Volatility is inevitable, so only sell the ...
# 998   2. Sell majority of stock and take some time b...
# 999   4. Volatility is inevitable, so only sell the ...
# 1000                     1. Sell everything and give up
#
#                                                   res_2         tf1  \
# 1                    1. Sell everything and gain profit   Long term
# 2          3. Take out 50%, and wait for further growth  Short term
# 3     4. Volatility is inevitable, so only sell the ...  Don't know
# 4                           5. Keep the portfolio as is   Long term
# 5          3. Take out 50%, and wait for further growth  Short term
# ...                                                 ...         ...
# 996                         5. Keep the portfolio as is  Don't know
# 997                  1. Sell everything and gain profit  Don't know
# 998                  1. Sell everything and gain profit  Short term
# 999                  1. Sell everything and gain profit  Short term
# 1000                 1. Sell everything and gain profit   Long term
#
#              tf2         tf3         tf4  \
# 1           True       False        True
# 2          False  Don't know  Don't know
# 3          False       False  Don't know
# 4     Don't know       False        True
# 5          False       False       False
# ...          ...         ...         ...
# 996        False        True  Don't know
# 997        False        True       False
# 998         True        True  Don't know
# 999         True       False        True
# 1000       False        True        True
#
#                                              stock_type risk_level
# 1     ['Telecommunication', 'Franchise', 'Traveling'...        low
# 2                       ['Semiconductors', 'Traveling']     medium
# 3     ['Entertainment', 'Energy & Resources', 'Trave...        low
# 4     ['Cloud Computing', 'BlockChain', 'Real Estate...     medium
# 5     ['Luxury goods', 'Semiconductors', 'Airline', ...     medium
# ...                                                 ...        ...
# 996          ['Semiconductors', 'Traveling', 'Airline']     medium
# 997   ['Social Media', 'Luxury goods', 'Franchise', ...     medium
# 998   ['Entertainment', 'Retail', 'Airline', 'Semico...       high
# 999                                    ['Luxury goods']       high
# 1000  ['Social Media', 'Franchise', 'Airline', 'Clou...     medium
#
# [1000 rows x 18 columns]

# %% [markdown]
# # Get the top X stock-model list by User ID

# %%
def get_user_sector_stock_by_id(user_df,volatility_summary,uid,top = -1):
    uid_want = user_df[user_df.index == uid]
    uid_want_stock = uid_want.loc[uid,"stock_type"]
    uid_risk_lv = uid_want.loc[uid,"risk_level"]

    sector_list = list(uid_want_stock[1:-1].split(","))
    sector_list = list(map(lambda sector: sector.replace("'",""),sector_list))
    sector_list = list(map(lambda sector: sector.title(),sector_list))
    sector_list = list(map(lambda sector: sector.strip(),sector_list))

    volatility_okay = volatility_summary.loc[(volatility_summary["risk_level"]==uid_risk_lv) & (volatility_summary["Sector"].isin(sector_list))]
    volatility_okay = volatility_okay.sort_values(by=["Volatility"],ascending=[False])
    volatility_okay = volatility_okay.reset_index(drop=True)
    if top > -1:
        volatility_okay = volatility_okay.head(top)
    return volatility_okay

# %%
get_user_sector_stock_by_id(user_df,volatility_summary,13)
# Out:
#                Sector  Stock           Model  Volatility risk_level
# 0   Telecommunication      T            TWAP   12.952671        low
# 1        Luxury Goods     EL    CNN_LSTM_REG   12.746988        low
# 2   Telecommunication      T             CAT   12.556685        low
# 3   Telecommunication     VZ          [5]SVR   12.384909        low
# 4   Telecommunication   CHTR    CNN_LSTM_REG   12.348033        low
# 5        Luxury Goods     EL  CNN_LSTM_CLASS   12.282841        low
# 6   Telecommunication  CMCSA             XGB   12.140834        low
# 7             Airline     GD  CNN_LSTM_CLASS   11.880257        low
# 8   Telecommunication     VZ             CAT   11.706905        low
# 9           Franchise    YUM             CAT   11.386209        low
# 10            Airline     BA    CNN_LSTM_REG   11.335239        low
# 11            Airline    LMT            TWAP   11.004978        low
# 12          Franchise    YUM  CNN_LSTM_CLASS   10.706351        low
# 13  Telecommunication     VZ          [5]SVC   10.395978        low
# 14  Telecommunication  CMCSA  CNN_LSTM_CLASS   10.391511        low
# 15  Telecommunication      T  CNN_LSTM_CLASS    9.744189        low
# 16          Franchise    YUM    CNN_LSTM_REG    9.093985        low
# 17  Telecommunication  CMCSA    CNN_LSTM_REG    8.872765        low
# 18  Telecommunication     VZ            TWAP    8.842665        low
# 19          Franchise    MCD  CNN_LSTM_CLASS    8.680293        low
# 20  Telecommunication     VZ             XGB    8.287723        low
# 21          Franchise   SBUX    CNN_LSTM_REG    6.946042        low
# 22  Telecommunication     VZ  CNN_LSTM_CLASS    6.665373        low
# 23          Franchise    MCD    CNN_LSTM_REG    6.564508        low
# 24            Airline    LMT    CNN_LSTM_REG    6.521925        low
# 25  Telecommunication     VZ    CNN_LSTM_REG    6.520802        low
# 26          Franchise    DPZ    CNN_LSTM_REG    5.857851        low
# 27            Airline     GD    CNN_LSTM_REG    5.337012        low
# 28  Telecommunication      T    CNN_LSTM_REG    4.365728        low

# %% [markdown]
# # User Portfolio Setting

# %%
max_num_stock = 3
user_id = 1

# Set up for the column naming
total_cash_col = []
total_value_col =[]
total_cum_profit = []
for i in range(max_num_stock):
    total_cash_col.append("Cash_Bal_"+str(i+1))
    total_value_col.append("Value_"+str(i+1))
    total_cum_profit.append("Cum_Profit_"+str(i+1))

# %%
# Function to use

def sector_sync(ori_sector):
    sector_speacial_handle = {"Blockchain":"BlockChain","Luxury Goods":"Luxury goods"}
    for k,v in sector_speacial_handle.items():
        if ori_sector == k:
            return v
    return ori_sector

def stock_sync(ori_stock):
    sector_speacial_handle = {}
    for k,v in sector_speacial_handle.items():
        if ori_stock == k:
            return v
    return ori_stock



def get_buy_and_hold_result(summary,capital = 10000,handle_fee = 0.0005):
    num_stock = sum(list(map(lambda col: "Price_" in col,summary.columns)))
    dp = 3
    #print(num_stock)
    for i in range(num_stock):
        #print("***",i)
        balance = capital
        price_series = summary["Price_"+str(i+1)]
        #print(price_series)
        bnh_series = []
        total_capital = []
        
        # Get the first price (if not found then go to next day)
        j = 0
        first_day_price = price_series.iloc[j]
        while np.isnan(first_day_price) and j < len(price_series)-1:
            j = j+1
            bnh_series.append(0)
            total_capital.append(0)
            first_day_price = price_series.iloc[j]
        
        #print(j,len(price_series)-1)
        if j == len(price_series)-1:
          continue
                  
        # Buy at first day (j day)
        buy_pos = floor(balance/first_day_price)
        total_amt = buy_pos*first_day_price*(1+handle_fee)
        while balance < total_amt:
            buy_pos = buy_pos - 1
            total_amt = buy_pos*first_day_price*(1+handle_fee)
        balance = balance - total_amt
        bnh_series.append(balance+buy_pos*first_day_price) 
        total_capital.append(capital)
        
        # Hold during the year (from j+1 day to n-1 day)
        for k in range(j+1,len(price_series)-1):
            bnh_series.append(balance+buy_pos*price_series.iloc[k])
            total_capital.append(capital)
        
        # Sell at last day (n day)
        last_day_price = price_series.iloc[-1]
        total_amt = buy_pos*last_day_price*(1-handle_fee)
        buy_pos = 0
        balance = balance + total_amt
        bnh_series.append(balance)
        total_capital.append(capital)        
        
        summary["Buy&Hold_"+str(i+1)] = pd.Series(bnh_series,index = price_series.index)
        if i == 0:
            summary["Buy&Hold_Total"] = summary["Buy&Hold_"+str(i+1)]
            summary["Capital_Bal"] = pd.Series(total_capital,index = price_series.index)
            #print("First stock")
        else:
            summary["Buy&Hold_Total"] = summary["Buy&Hold_Total"] + summary["Buy&Hold_"+str(i+1)]
            summary["Capital_Bal"] = summary["Capital_Bal"] + pd.Series(total_capital,index = price_series.index)
            #print("other two stock")
        summary.drop(columns=["Buy&Hold_"+str(i+1)],inplace = True)
        
        #print(summary)
    summary["Portfolio_CAGR"]= ((summary["Total_Value"]-summary["Capital_Bal"])/summary["Capital_Bal"]*100).round(dp).astype(str)+"%"
    summary["Buy&Hold_CAGR"]= ((summary["Buy&Hold_Total"]-summary["Capital_Bal"])/summary["Capital_Bal"]*100).round(dp).astype(str)+"%"
    summary["Portfolio_Performance"] = ((summary["Total_Value"]-summary["Buy&Hold_Total"])/summary["Capital_Bal"]*100).round(dp).astype(str)+"%"
    
    return summary

# %% [markdown]
# # User Portfolio Backtesting

# %%
year_list = [2019, 2020, 2021]
num_user = 1000
col_to_get_from_backtest = ["Action","Price","Pos_Bal","Cash_Bal","Cum_Profit","Total_Bal"]
col_to_fillna_in_backtest = ["Action","Price","Pos_Bal","Cash_Bal","Cum_Profit","Value","Sector","Stock"]

for year in year_list:
    skipped_list = []
    print("*****************")
    print("***** "+str(year)+" ******")
    print("*****************")
    user_portfo_summary = pd.DataFrame(columns=["UserID","Risk_Level","Year","Portfolio_Performance","Stock_Count"])
    for i in range(num_user):
        user_id = i+1 # Update the User ID

        # Create empty dataframe
        user_portfolio = pd.DataFrame()

        # Get top X from available model-stock-list
        top_X_list = get_user_sector_stock_by_id(user_df,volatility_summary,user_id,top = max_num_stock)
        #if user_id == -1:
        #print(top_X_list)
        
        if len(top_X_list)==0: # Skip that
            print("User", user_id, "is skipped")
            skipped_list.append(user_id)
            continue
        
        iter_num = len(top_X_list)

        # Get top X stock data
        for j in range(iter_num):
            # Get the stock name from top X list
            this_stock = (top_X_list.loc[j,"Model"],sector_sync(top_X_list.loc[j,"Sector"]),stock_sync(top_X_list.loc[j,"Stock"]))
            
            # Get the file path to read backtest
            filepath = list(filter(lambda f: (this_stock[0]+"_" in f) and ("_"+this_stock[1]+"-" in f) and ("-"+this_stock[2]+"_" in f) and (str(year) in f) ,os.listdir(record_folder)))
            #print(j,"--->",filepath)

            # Check if file exist
            try:
                assert(len(filepath)==1)
            except:
                iter_num = iter_num - 1
                print(filepath)
                print(this_stock)
                
            # Read the file
            this_record_df = pd.read_csv(record_folder + filepath[0],index_col = 0)
            get_data = this_record_df[col_to_get_from_backtest]
            get_data = get_data.rename(columns={"Total_Bal":"Value"})
            get_data["Model"] = this_stock[0]
            get_data["Sector"] = this_stock[1]
            get_data["Stock"] = this_stock[2]
            get_data = get_data.add_suffix("_"+str(j+1))
            if j == 0:
                user_portfolio = user_portfolio.append(get_data)
                #print(get_data)
            else:
                if len(get_data) > len(user_portfolio):
                    user_portfolio = user_portfolio.merge(get_data,how='right',left_index = True,right_index = True,suffixes=("", "_"))
                else:
                    user_portfolio = user_portfolio.merge(get_data,how='left',left_index = True,right_index = True,suffixes=("", "_"))

        for j in range(iter_num):
          user_portfolio[col_to_fillna_in_backtest[0]+"_"+str(j+1)].fillna(value = "Hold", inplace = True)
          for k in range(1,len(col_to_fillna_in_backtest)):
            user_portfolio[col_to_fillna_in_backtest[k]+"_"+str(j+1)].fillna(method ="ffill", inplace = True)

        user_portfolio["Total_Cash_Bal"] = user_portfolio[total_cash_col[:iter_num]].sum(axis=1)
        user_portfolio["Total_Value"] = user_portfolio[total_value_col[:iter_num]].sum(axis=1)
        user_portfolio["Total_Cum_Profit"] = user_portfolio[total_cum_profit[:iter_num]].sum(axis=1)
        #print(user_portfolio)
        user_portfolio = get_buy_and_hold_result(user_portfolio)
        user_portfolio.to_csv(user_test_folder+str(year)+"_test_user_"+str(user_id)+".csv")
        final_buyandhold_cagr = user_portfolio.loc[user_portfolio.index[-1],"Buy&Hold_CAGR"]
        final_portfolio_cagr = user_portfolio.loc[user_portfolio.index[-1],"Portfolio_CAGR"]
        final_portfolio_performance = user_portfolio.loc[user_portfolio.index[-1],"Portfolio_Performance"]

        risk_level = get_risk_level_by_id(user_df,user_id)
        user_portfo_summary = user_portfo_summary.append({"UserID":user_id,
                                                          "Risk_Level":risk_level,
                                                          "Year":year,
                                                          "Buy&Hold_CAGR":final_buyandhold_cagr,
                                                          "Portfolio_CAGR":final_portfolio_cagr,
                                                          "Portfolio_Performance":final_portfolio_performance,
                                                          "Stock_Count":iter_num},ignore_index = True)
        print("Finished Portfolio Backtesting in Year "+str(year)+" for User ID = "+str(user_id)+"\t| Risk Level: "+risk_level+"\t| Buy&Hold_CAGR: "+final_buyandhold_cagr+"   \t| Portfo_CAGR: "+final_portfolio_cagr+"\t| Portfo_Perf: "+final_portfolio_performance+"\t | Stock Count: "+str(iter_num))

        
    print("Finished all "+str(num_user)+" users in Year "+str(year)+"...")
    print("Skipped the following users:",skipped_list)
    user_portfo_summary.to_csv(volatility_folder+str(num_user)+"_users_in_"+str(year)+"_portfolio_summary.csv",index = False)
    print("Exported "+str(num_user)+" users summary in Year "+str(year)+"...")

print("**** Finsihed all ****")
# Out:
# *****************
# ***** 2019 ******
# *****************
# Finished Portfolio Backtesting in Year 2019 for User ID = 1	| Risk Level: low	| Buy&Hold_CAGR: 17.686%   	| Portfo_CAGR: 15.01%	| Portfo_Perf: -2.676%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 2	| Risk Level: medium	| Buy&Hold_CAGR: 37.224%   	| Portfo_CAGR: 45.546%	| Portfo_Perf: 8.323%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 3	| Risk Level: low	| Buy&Hold_CAGR: 27.072%   	| Portfo_CAGR: 27.395%	| Portfo_Perf: 0.323%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 4	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 5	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 6	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 7	| Risk Level: medium	| Buy&Hold_CAGR: 43.981%   	| Portfo_CAGR: 39.655%	| Portfo_Perf: -4.326%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 8	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 9	| Risk Level: low	| Buy&Hold_CAGR: 27.072%   	| Portfo_CAGR: 27.395%	| Portfo_Perf: 0.323%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 10	| Risk Level: medium	| Buy&Hold_CAGR: 47.726%   	| Portfo_CAGR: 79.077%	| Portfo_Perf: 31.351%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 11	| Risk Level: low	| Buy&Hold_CAGR: 27.072%   	| Portfo_CAGR: 27.395%	| Portfo_Perf: 0.323%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 12	| Risk Level: medium	| Buy&Hold_CAGR: 29.414%   	| Portfo_CAGR: 38.211%	| Portfo_Perf: 8.797%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 13	| Risk Level: low	| Buy&Hold_CAGR: 41.307%   	| Portfo_CAGR: 44.042%	| Portfo_Perf: 2.735%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 14	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 15	| Risk Level: low	| Buy&Hold_CAGR: 19.705%   	| Portfo_CAGR: 2.181%	| Portfo_Perf: -17.525%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 16	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 17	| Risk Level: low	| Buy&Hold_CAGR: 38.084%   	| Portfo_CAGR: 39.693%	| Portfo_Perf: 1.609%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 18	| Risk Level: low	| Buy&Hold_CAGR: 27.072%   	| Portfo_CAGR: 27.395%	| Portfo_Perf: 0.323%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 19	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 20	| Risk Level: medium	| Buy&Hold_CAGR: 3.404%   	| Portfo_CAGR: 40.885%	| Portfo_Perf: 37.481%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 21	| Risk Level: high	| Buy&Hold_CAGR: 14.743%   	| Portfo_CAGR: 34.011%	| Portfo_Perf: 19.268%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 22	| Risk Level: medium	| Buy&Hold_CAGR: 62.378%   	| Portfo_CAGR: 124.753%	| Portfo_Perf: 62.375%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 23	| Risk Level: low	| Buy&Hold_CAGR: 17.686%   	| Portfo_CAGR: 15.01%	| Portfo_Perf: -2.676%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 24	| Risk Level: low	| Buy&Hold_CAGR: 41.307%   	| Portfo_CAGR: 44.042%	| Portfo_Perf: 2.735%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 25	| Risk Level: medium	| Buy&Hold_CAGR: 14.064%   	| Portfo_CAGR: 29.334%	| Portfo_Perf: 15.27%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 26	| Risk Level: medium	| Buy&Hold_CAGR: 16.681%   	| Portfo_CAGR: 59.442%	| Portfo_Perf: 42.762%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 27	| Risk Level: low	| Buy&Hold_CAGR: 2.271%   	| Portfo_CAGR: 7.753%	| Portfo_Perf: 5.483%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 28	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 29	| Risk Level: medium	| Buy&Hold_CAGR: 3.404%   	| Portfo_CAGR: 40.885%	| Portfo_Perf: 37.481%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 30	| Risk Level: low	| Buy&Hold_CAGR: 24.64%   	| Portfo_CAGR: 24.334%	| Portfo_Perf: -0.307%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 31	| Risk Level: medium	| Buy&Hold_CAGR: 15.29%   	| Portfo_CAGR: 50.065%	| Portfo_Perf: 34.775%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 32	| Risk Level: low	| Buy&Hold_CAGR: 28.698%   	| Portfo_CAGR: 27.308%	| Portfo_Perf: -1.39%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 33	| Risk Level: medium	| Buy&Hold_CAGR: 16.58%   	| Portfo_CAGR: 55.067%	| Portfo_Perf: 38.487%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 34	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 35	| Risk Level: medium	| Buy&Hold_CAGR: 12.646%   	| Portfo_CAGR: 48.823%	| Portfo_Perf: 36.177%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 36	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 37	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 38	| Risk Level: high	| Buy&Hold_CAGR: 14.059%   	| Portfo_CAGR: 48.689%	| Portfo_Perf: 34.63%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 39	| Risk Level: low	| Buy&Hold_CAGR: 14.463%   	| Portfo_CAGR: 10.661%	| Portfo_Perf: -3.802%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 40	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 41	| Risk Level: medium	| Buy&Hold_CAGR: 27.096%   	| Portfo_CAGR: 46.323%	| Portfo_Perf: 19.227%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 42	| Risk Level: medium	| Buy&Hold_CAGR: 43.284%   	| Portfo_CAGR: 46.518%	| Portfo_Perf: 3.234%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 43	| Risk Level: medium	| Buy&Hold_CAGR: 16.58%   	| Portfo_CAGR: 55.067%	| Portfo_Perf: 38.487%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 44	| Risk Level: medium	| Buy&Hold_CAGR: 3.699%   	| Portfo_CAGR: 14.879%	| Portfo_Perf: 11.179%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 45	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 46	| Risk Level: medium	| Buy&Hold_CAGR: 29.414%   	| Portfo_CAGR: 38.211%	| Portfo_Perf: 8.797%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 47	| Risk Level: medium	| Buy&Hold_CAGR: 16.953%   	| Portfo_CAGR: 50.694%	| Portfo_Perf: 33.741%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 48	| Risk Level: medium	| Buy&Hold_CAGR: 38.768%   	| Portfo_CAGR: 32.405%	| Portfo_Perf: -6.363%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 49	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 50	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 51	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 52	| Risk Level: low	| Buy&Hold_CAGR: 26.331%   	| Portfo_CAGR: 36.328%	| Portfo_Perf: 9.997%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 53	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 54	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 55	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 56	| Risk Level: low	| Buy&Hold_CAGR: 24.64%   	| Portfo_CAGR: 24.334%	| Portfo_Perf: -0.307%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 57	| Risk Level: low	| Buy&Hold_CAGR: 46.747%   	| Portfo_CAGR: 45.216%	| Portfo_Perf: -1.531%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 58	| Risk Level: medium	| Buy&Hold_CAGR: 3.404%   	| Portfo_CAGR: 40.885%	| Portfo_Perf: 37.481%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 59	| Risk Level: low	| Buy&Hold_CAGR: 46.747%   	| Portfo_CAGR: 45.216%	| Portfo_Perf: -1.531%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 60	| Risk Level: high	| Buy&Hold_CAGR: 32.942%   	| Portfo_CAGR: 30.598%	| Portfo_Perf: -2.344%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 61	| Risk Level: low	| Buy&Hold_CAGR: 24.114%   	| Portfo_CAGR: 32.322%	| Portfo_Perf: 8.208%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 62	| Risk Level: medium	| Buy&Hold_CAGR: 17.605%   	| Portfo_CAGR: 50.664%	| Portfo_Perf: 33.059%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 63	| Risk Level: medium	| Buy&Hold_CAGR: 19.088%   	| Portfo_CAGR: 40.862%	| Portfo_Perf: 21.774%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 64	| Risk Level: medium	| Buy&Hold_CAGR: -8.321%   	| Portfo_CAGR: 27.417%	| Portfo_Perf: 35.738%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 65	| Risk Level: medium	| Buy&Hold_CAGR: 27.096%   	| Portfo_CAGR: 46.323%	| Portfo_Perf: 19.227%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 66	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 67	| Risk Level: medium	| Buy&Hold_CAGR: 29.491%   	| Portfo_CAGR: 59.844%	| Portfo_Perf: 30.353%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 68	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 69	| Risk Level: medium	| Buy&Hold_CAGR: 16.216%   	| Portfo_CAGR: 28.305%	| Portfo_Perf: 12.089%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 70	| Risk Level: medium	| Buy&Hold_CAGR: 47.648%   	| Portfo_CAGR: 57.444%	| Portfo_Perf: 9.795%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 71	| Risk Level: low	| Buy&Hold_CAGR: 29.67%   	| Portfo_CAGR: 48.13%	| Portfo_Perf: 18.46%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 72	| Risk Level: medium	| Buy&Hold_CAGR: 29.414%   	| Portfo_CAGR: 38.211%	| Portfo_Perf: 8.797%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 73	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 74	| Risk Level: medium	| Buy&Hold_CAGR: 12.646%   	| Portfo_CAGR: 48.823%	| Portfo_Perf: 36.177%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 75	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 76	| Risk Level: high	| Buy&Hold_CAGR: 8.291%   	| Portfo_CAGR: 42.751%	| Portfo_Perf: 34.46%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 77	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 78	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 79	| Risk Level: medium	| Buy&Hold_CAGR: 19.864%   	| Portfo_CAGR: 36.244%	| Portfo_Perf: 16.38%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 80	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 81	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 82	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 83	| Risk Level: medium	| Buy&Hold_CAGR: 43.714%   	| Portfo_CAGR: 51.199%	| Portfo_Perf: 7.485%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 84	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 85	| Risk Level: medium	| Buy&Hold_CAGR: 40.871%   	| Portfo_CAGR: 53.485%	| Portfo_Perf: 12.614%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 86	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 87	| Risk Level: medium	| Buy&Hold_CAGR: 62.378%   	| Portfo_CAGR: 124.753%	| Portfo_Perf: 62.375%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 88	| Risk Level: medium	| Buy&Hold_CAGR: 40.871%   	| Portfo_CAGR: 53.485%	| Portfo_Perf: 12.614%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 89	| Risk Level: medium	| Buy&Hold_CAGR: 25.049%   	| Portfo_CAGR: 27.285%	| Portfo_Perf: 2.235%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 90	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 91	| Risk Level: medium	| Buy&Hold_CAGR: 3.404%   	| Portfo_CAGR: 40.885%	| Portfo_Perf: 37.481%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 92	| Risk Level: medium	| Buy&Hold_CAGR: 34.472%   	| Portfo_CAGR: 43.261%	| Portfo_Perf: 8.789%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 93	| Risk Level: medium	| Buy&Hold_CAGR: 20.249%   	| Portfo_CAGR: 51.906%	| Portfo_Perf: 31.657%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 94	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 95	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 96	| Risk Level: medium	| Buy&Hold_CAGR: 62.952%   	| Portfo_CAGR: 68.657%	| Portfo_Perf: 5.705%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 97	| Risk Level: medium	| Buy&Hold_CAGR: 16.58%   	| Portfo_CAGR: 55.067%	| Portfo_Perf: 38.487%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 98	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 99	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 100	| Risk Level: low	| Buy&Hold_CAGR: 24.114%   	| Portfo_CAGR: 32.322%	| Portfo_Perf: 8.208%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 101	| Risk Level: medium	| Buy&Hold_CAGR: 16.681%   	| Portfo_CAGR: 59.442%	| Portfo_Perf: 42.762%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 102	| Risk Level: medium	| Buy&Hold_CAGR: 65.418%   	| Portfo_CAGR: 36.926%	| Portfo_Perf: -28.492%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 103	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 104	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 105	| Risk Level: high	| Buy&Hold_CAGR: 2.287%   	| Portfo_CAGR: 14.827%	| Portfo_Perf: 12.54%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 106	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 107	| Risk Level: medium	| Buy&Hold_CAGR: 91.813%   	| Portfo_CAGR: 107.026%	| Portfo_Perf: 15.213%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 108	| Risk Level: low	| Buy&Hold_CAGR: 27.072%   	| Portfo_CAGR: 27.395%	| Portfo_Perf: 0.323%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 109	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 110	| Risk Level: high	| Buy&Hold_CAGR: 6.183%   	| Portfo_CAGR: 24.716%	| Portfo_Perf: 18.533%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 111	| Risk Level: high	| Buy&Hold_CAGR: 14.059%   	| Portfo_CAGR: 48.689%	| Portfo_Perf: 34.63%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 112	| Risk Level: medium	| Buy&Hold_CAGR: 43.714%   	| Portfo_CAGR: 51.199%	| Portfo_Perf: 7.485%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 113	| Risk Level: medium	| Buy&Hold_CAGR: 29.414%   	| Portfo_CAGR: 38.211%	| Portfo_Perf: 8.797%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 114	| Risk Level: medium	| Buy&Hold_CAGR: 20.249%   	| Portfo_CAGR: 51.906%	| Portfo_Perf: 31.657%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 115	| Risk Level: high	| Buy&Hold_CAGR: 2.287%   	| Portfo_CAGR: 14.827%	| Portfo_Perf: 12.54%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 116	| Risk Level: high	| Buy&Hold_CAGR: 38.527%   	| Portfo_CAGR: 25.788%	| Portfo_Perf: -12.739%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 117	| Risk Level: medium	| Buy&Hold_CAGR: 35.476%   	| Portfo_CAGR: 43.135%	| Portfo_Perf: 7.659%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 118	| Risk Level: low	| Buy&Hold_CAGR: 28.698%   	| Portfo_CAGR: 27.308%	| Portfo_Perf: -1.39%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 119	| Risk Level: medium	| Buy&Hold_CAGR: 43.284%   	| Portfo_CAGR: 46.518%	| Portfo_Perf: 3.234%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 120	| Risk Level: medium	| Buy&Hold_CAGR: 3.404%   	| Portfo_CAGR: 40.885%	| Portfo_Perf: 37.481%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 121	| Risk Level: medium	| Buy&Hold_CAGR: 20.249%   	| Portfo_CAGR: 51.906%	| Portfo_Perf: 31.657%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 122	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 123	| Risk Level: medium	| Buy&Hold_CAGR: 37.224%   	| Portfo_CAGR: 45.546%	| Portfo_Perf: 8.323%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 124	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 125	| Risk Level: medium	| Buy&Hold_CAGR: 24.233%   	| Portfo_CAGR: 37.15%	| Portfo_Perf: 12.917%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 126	| Risk Level: low	| Buy&Hold_CAGR: 24.64%   	| Portfo_CAGR: 24.334%	| Portfo_Perf: -0.307%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 127	| Risk Level: medium	| Buy&Hold_CAGR: 20.249%   	| Portfo_CAGR: 51.906%	| Portfo_Perf: 31.657%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 128	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 129	| Risk Level: medium	| Buy&Hold_CAGR: 16.953%   	| Portfo_CAGR: 50.694%	| Portfo_Perf: 33.741%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 130	| Risk Level: medium	| Buy&Hold_CAGR: 20.249%   	| Portfo_CAGR: 51.906%	| Portfo_Perf: 31.657%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 131	| Risk Level: medium	| Buy&Hold_CAGR: 32.859%   	| Portfo_CAGR: 34.621%	| Portfo_Perf: 1.761%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 132	| Risk Level: medium	| Buy&Hold_CAGR: 17.605%   	| Portfo_CAGR: 50.664%	| Portfo_Perf: 33.059%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 133	| Risk Level: medium	| Buy&Hold_CAGR: 16.58%   	| Portfo_CAGR: 55.067%	| Portfo_Perf: 38.487%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 134	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 135	| Risk Level: low	| Buy&Hold_CAGR: 27.072%   	| Portfo_CAGR: 27.395%	| Portfo_Perf: 0.323%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 136	| Risk Level: medium	| Buy&Hold_CAGR: 16.58%   	| Portfo_CAGR: 55.067%	| Portfo_Perf: 38.487%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 137	| Risk Level: medium	| Buy&Hold_CAGR: 40.871%   	| Portfo_CAGR: 53.485%	| Portfo_Perf: 12.614%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 138	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 139	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 140	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 141	| Risk Level: high	| Buy&Hold_CAGR: 2.287%   	| Portfo_CAGR: 14.827%	| Portfo_Perf: 12.54%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 142	| Risk Level: medium	| Buy&Hold_CAGR: 43.284%   	| Portfo_CAGR: 46.518%	| Portfo_Perf: 3.234%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 143	| Risk Level: low	| Buy&Hold_CAGR: 0.645%   	| Portfo_CAGR: 6.85%	| Portfo_Perf: 6.204%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 144	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 145	| Risk Level: medium	| Buy&Hold_CAGR: 34.472%   	| Portfo_CAGR: 43.261%	| Portfo_Perf: 8.789%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 146	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 147	| Risk Level: medium	| Buy&Hold_CAGR: 25.049%   	| Portfo_CAGR: 27.285%	| Portfo_Perf: 2.235%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 148	| Risk Level: medium	| Buy&Hold_CAGR: 29.414%   	| Portfo_CAGR: 38.211%	| Portfo_Perf: 8.797%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 149	| Risk Level: low	| Buy&Hold_CAGR: 24.114%   	| Portfo_CAGR: 32.322%	| Portfo_Perf: 8.208%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 150	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 151	| Risk Level: medium	| Buy&Hold_CAGR: 11.278%   	| Portfo_CAGR: 33.527%	| Portfo_Perf: 22.248%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 152	| Risk Level: low	| Buy&Hold_CAGR: 17.904%   	| Portfo_CAGR: 21.929%	| Portfo_Perf: 4.025%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 153	| Risk Level: medium	| Buy&Hold_CAGR: 29.491%   	| Portfo_CAGR: 59.844%	| Portfo_Perf: 30.353%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 154	| Risk Level: medium	| Buy&Hold_CAGR: 40.871%   	| Portfo_CAGR: 53.485%	| Portfo_Perf: 12.614%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 155	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 156	| Risk Level: medium	| Buy&Hold_CAGR: 49.926%   	| Portfo_CAGR: 38.956%	| Portfo_Perf: -10.971%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 157	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 158	| Risk Level: low	| Buy&Hold_CAGR: 27.072%   	| Portfo_CAGR: 27.395%	| Portfo_Perf: 0.323%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 159	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 160	| Risk Level: medium	| Buy&Hold_CAGR: 20.249%   	| Portfo_CAGR: 51.906%	| Portfo_Perf: 31.657%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 161	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 162	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 163	| Risk Level: medium	| Buy&Hold_CAGR: 16.58%   	| Portfo_CAGR: 55.067%	| Portfo_Perf: 38.487%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 164	| Risk Level: medium	| Buy&Hold_CAGR: 16.238%   	| Portfo_CAGR: 24.029%	| Portfo_Perf: 7.791%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 165	| Risk Level: medium	| Buy&Hold_CAGR: 2.036%   	| Portfo_CAGR: 25.589%	| Portfo_Perf: 23.552%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 166	| Risk Level: medium	| Buy&Hold_CAGR: 51.296%   	| Portfo_CAGR: 65.382%	| Portfo_Perf: 14.087%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 167	| Risk Level: medium	| Buy&Hold_CAGR: 24.233%   	| Portfo_CAGR: 37.15%	| Portfo_Perf: 12.917%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 168	| Risk Level: medium	| Buy&Hold_CAGR: 6.747%   	| Portfo_CAGR: 27.595%	| Portfo_Perf: 20.848%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 169	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 170	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 171	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 172	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 173	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 174	| Risk Level: medium	| Buy&Hold_CAGR: 16.58%   	| Portfo_CAGR: 55.067%	| Portfo_Perf: 38.487%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 175	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 176	| Risk Level: medium	| Buy&Hold_CAGR: 35.84%   	| Portfo_CAGR: 69.897%	| Portfo_Perf: 34.057%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 177	| Risk Level: medium	| Buy&Hold_CAGR: 44.718%   	| Portfo_CAGR: 51.072%	| Portfo_Perf: 6.354%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 178	| Risk Level: medium	| Buy&Hold_CAGR: 82.674%   	| Portfo_CAGR: 85.899%	| Portfo_Perf: 3.225%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 179	| Risk Level: medium	| Buy&Hold_CAGR: 17.605%   	| Portfo_CAGR: 50.664%	| Portfo_Perf: 33.059%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 180	| Risk Level: medium	| Buy&Hold_CAGR: 20.249%   	| Portfo_CAGR: 51.906%	| Portfo_Perf: 31.657%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 181	| Risk Level: medium	| Buy&Hold_CAGR: 11.278%   	| Portfo_CAGR: 33.527%	| Portfo_Perf: 22.248%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 182	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 183	| Risk Level: high	| Buy&Hold_CAGR: 57.319%   	| Portfo_CAGR: 18.664%	| Portfo_Perf: -38.655%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 184	| Risk Level: medium	| Buy&Hold_CAGR: 16.681%   	| Portfo_CAGR: 59.442%	| Portfo_Perf: 42.762%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 185	| Risk Level: medium	| Buy&Hold_CAGR: 3.404%   	| Portfo_CAGR: 40.885%	| Portfo_Perf: 37.481%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 186	| Risk Level: low	| Buy&Hold_CAGR: 24.114%   	| Portfo_CAGR: 32.322%	| Portfo_Perf: 8.208%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 187	| Risk Level: medium	| Buy&Hold_CAGR: 46.126%   	| Portfo_CAGR: 62.205%	| Portfo_Perf: 16.078%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 188	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 189	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 190	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 191	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 192	| Risk Level: medium	| Buy&Hold_CAGR: 37.224%   	| Portfo_CAGR: 45.546%	| Portfo_Perf: 8.323%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 193	| Risk Level: medium	| Buy&Hold_CAGR: 40.871%   	| Portfo_CAGR: 53.485%	| Portfo_Perf: 12.614%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 194	| Risk Level: medium	| Buy&Hold_CAGR: 29.414%   	| Portfo_CAGR: 38.211%	| Portfo_Perf: 8.797%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 195	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 196	| Risk Level: low	| Buy&Hold_CAGR: 48.78%   	| Portfo_CAGR: 52.116%	| Portfo_Perf: 3.336%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 197	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 198	| Risk Level: medium	| Buy&Hold_CAGR: 3.404%   	| Portfo_CAGR: 40.885%	| Portfo_Perf: 37.481%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 199	| Risk Level: medium	| Buy&Hold_CAGR: 91.813%   	| Portfo_CAGR: 107.026%	| Portfo_Perf: 15.213%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 200	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 201	| Risk Level: medium	| Buy&Hold_CAGR: 11.278%   	| Portfo_CAGR: 33.527%	| Portfo_Perf: 22.248%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 202	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 203	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 204	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 205	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 206	| Risk Level: medium	| Buy&Hold_CAGR: 91.813%   	| Portfo_CAGR: 107.026%	| Portfo_Perf: 15.213%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 207	| Risk Level: medium	| Buy&Hold_CAGR: -1.26%   	| Portfo_CAGR: 24.377%	| Portfo_Perf: 25.636%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 208	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 209	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 210	| Risk Level: low	| Buy&Hold_CAGR: 38.084%   	| Portfo_CAGR: 39.693%	| Portfo_Perf: 1.609%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 211	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 212	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 213	| Risk Level: medium	| Buy&Hold_CAGR: 27.096%   	| Portfo_CAGR: 46.323%	| Portfo_Perf: 19.227%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 214	| Risk Level: high	| Buy&Hold_CAGR: 2.287%   	| Portfo_CAGR: 14.827%	| Portfo_Perf: 12.54%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 215	| Risk Level: medium	| Buy&Hold_CAGR: 19.864%   	| Portfo_CAGR: 36.244%	| Portfo_Perf: 16.38%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 216	| Risk Level: high	| Buy&Hold_CAGR: 56.027%   	| Portfo_CAGR: 51.145%	| Portfo_Perf: -4.882%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 217	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 218	| Risk Level: medium	| Buy&Hold_CAGR: 30.881%   	| Portfo_CAGR: 68.056%	| Portfo_Perf: 37.175%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 219	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 220	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 221	| Risk Level: high	| Buy&Hold_CAGR: 11.876%   	| Portfo_CAGR: 15.446%	| Portfo_Perf: 3.57%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 222	| Risk Level: medium	| Buy&Hold_CAGR: 29.513%   	| Portfo_CAGR: 52.759%	| Portfo_Perf: 23.246%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 223	| Risk Level: low	| Buy&Hold_CAGR: 28.698%   	| Portfo_CAGR: 27.308%	| Portfo_Perf: -1.39%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 224	| Risk Level: medium	| Buy&Hold_CAGR: 32.859%   	| Portfo_CAGR: 34.621%	| Portfo_Perf: 1.761%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 225	| Risk Level: medium	| Buy&Hold_CAGR: 19.088%   	| Portfo_CAGR: 40.862%	| Portfo_Perf: 21.774%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 226	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 227	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 228	| Risk Level: medium	| Buy&Hold_CAGR: 3.404%   	| Portfo_CAGR: 40.885%	| Portfo_Perf: 37.481%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 229	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 230	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# User 231 is skipped
# Finished Portfolio Backtesting in Year 2019 for User ID = 232	| Risk Level: medium	| Buy&Hold_CAGR: 16.58%   	| Portfo_CAGR: 55.067%	| Portfo_Perf: 38.487%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 233	| Risk Level: medium	| Buy&Hold_CAGR: 19.739%   	| Portfo_CAGR: 20.717%	| Portfo_Perf: 0.978%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 234	| Risk Level: low	| Buy&Hold_CAGR: 13.099%   	| Portfo_CAGR: 22.945%	| Portfo_Perf: 9.847%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 235	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 236	| Risk Level: medium	| Buy&Hold_CAGR: 25.049%   	| Portfo_CAGR: 27.285%	| Portfo_Perf: 2.235%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 237	| Risk Level: high	| Buy&Hold_CAGR: 2.287%   	| Portfo_CAGR: 14.827%	| Portfo_Perf: 12.54%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 238	| Risk Level: medium	| Buy&Hold_CAGR: 11.278%   	| Portfo_CAGR: 33.527%	| Portfo_Perf: 22.248%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 239	| Risk Level: low	| Buy&Hold_CAGR: 14.463%   	| Portfo_CAGR: 10.661%	| Portfo_Perf: -3.802%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 240	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 241	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 242	| Risk Level: medium	| Buy&Hold_CAGR: 7.986%   	| Portfo_CAGR: 25.325%	| Portfo_Perf: 17.339%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 243	| Risk Level: medium	| Buy&Hold_CAGR: 35.84%   	| Portfo_CAGR: 69.897%	| Portfo_Perf: 34.057%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 244	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 245	| Risk Level: medium	| Buy&Hold_CAGR: 3.404%   	| Portfo_CAGR: 40.885%	| Portfo_Perf: 37.481%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 246	| Risk Level: low	| Buy&Hold_CAGR: 27.072%   	| Portfo_CAGR: 27.395%	| Portfo_Perf: 0.323%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 247	| Risk Level: medium	| Buy&Hold_CAGR: 12.646%   	| Portfo_CAGR: 48.823%	| Portfo_Perf: 36.177%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 248	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 249	| Risk Level: medium	| Buy&Hold_CAGR: 17.605%   	| Portfo_CAGR: 50.664%	| Portfo_Perf: 33.059%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 250	| Risk Level: medium	| Buy&Hold_CAGR: 34.472%   	| Portfo_CAGR: 43.261%	| Portfo_Perf: 8.789%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 251	| Risk Level: medium	| Buy&Hold_CAGR: 15.29%   	| Portfo_CAGR: 50.065%	| Portfo_Perf: 34.775%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 252	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 253	| Risk Level: low	| Buy&Hold_CAGR: 27.072%   	| Portfo_CAGR: 27.395%	| Portfo_Perf: 0.323%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 254	| Risk Level: high	| Buy&Hold_CAGR: 2.287%   	| Portfo_CAGR: 14.827%	| Portfo_Perf: 12.54%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 255	| Risk Level: medium	| Buy&Hold_CAGR: 16.58%   	| Portfo_CAGR: 55.067%	| Portfo_Perf: 38.487%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 256	| Risk Level: high	| Buy&Hold_CAGR: 39.96%   	| Portfo_CAGR: 12.034%	| Portfo_Perf: -27.926%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 257	| Risk Level: medium	| Buy&Hold_CAGR: 3.404%   	| Portfo_CAGR: 40.885%	| Portfo_Perf: 37.481%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 258	| Risk Level: low	| Buy&Hold_CAGR: 24.114%   	| Portfo_CAGR: 32.322%	| Portfo_Perf: 8.208%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 259	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 260	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 261	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 262	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 263	| Risk Level: medium	| Buy&Hold_CAGR: 17.849%   	| Portfo_CAGR: 43.133%	| Portfo_Perf: 25.284%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 264	| Risk Level: medium	| Buy&Hold_CAGR: 24.233%   	| Portfo_CAGR: 37.15%	| Portfo_Perf: 12.917%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 265	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 266	| Risk Level: medium	| Buy&Hold_CAGR: 16.58%   	| Portfo_CAGR: 55.067%	| Portfo_Perf: 38.487%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 267	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 268	| Risk Level: high	| Buy&Hold_CAGR: 119.499%   	| Portfo_CAGR: 80.756%	| Portfo_Perf: -38.743%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 269	| Risk Level: medium	| Buy&Hold_CAGR: 47.726%   	| Portfo_CAGR: 79.077%	| Portfo_Perf: 31.351%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 270	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 271	| Risk Level: medium	| Buy&Hold_CAGR: 12.941%   	| Portfo_CAGR: 22.816%	| Portfo_Perf: 9.875%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 272	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 273	| Risk Level: medium	| Buy&Hold_CAGR: 20.172%   	| Portfo_CAGR: 30.273%	| Portfo_Perf: 10.101%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 274	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 275	| Risk Level: medium	| Buy&Hold_CAGR: 15.212%   	| Portfo_CAGR: 28.432%	| Portfo_Perf: 13.219%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2019 for User ID = 276	| Risk Level: medium	| Buy&Hold_CAGR: 49.926%   	| Portfo_CAGR: 38.956%	| Portfo_Perf: -10.971%	 | Stock Count: 3
# ...
# Finished Portfolio Backtesting in Year 2021 for User ID = 910	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 911	| Risk Level: low	| Buy&Hold_CAGR: 66.222%   	| Portfo_CAGR: 48.32%	| Portfo_Perf: -17.901%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 912	| Risk Level: medium	| Buy&Hold_CAGR: 5.338%   	| Portfo_CAGR: 31.208%	| Portfo_Perf: 25.87%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 913	| Risk Level: medium	| Buy&Hold_CAGR: 56.223%   	| Portfo_CAGR: 76.261%	| Portfo_Perf: 20.039%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 914	| Risk Level: medium	| Buy&Hold_CAGR: 6.298%   	| Portfo_CAGR: 45.072%	| Portfo_Perf: 38.774%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 915	| Risk Level: medium	| Buy&Hold_CAGR: 8.066%   	| Portfo_CAGR: 46.608%	| Portfo_Perf: 38.542%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 916	| Risk Level: medium	| Buy&Hold_CAGR: 6.598%   	| Portfo_CAGR: 47.423%	| Portfo_Perf: 40.825%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 917	| Risk Level: low	| Buy&Hold_CAGR: 79.996%   	| Portfo_CAGR: 56.903%	| Portfo_Perf: -23.092%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 918	| Risk Level: medium	| Buy&Hold_CAGR: 59.982%   	| Portfo_CAGR: 79.127%	| Portfo_Perf: 19.144%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 919	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 920	| Risk Level: low	| Buy&Hold_CAGR: 60.559%   	| Portfo_CAGR: 40.0%	| Portfo_Perf: -20.559%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 921	| Risk Level: medium	| Buy&Hold_CAGR: 3.591%   	| Portfo_CAGR: 25.629%	| Portfo_Perf: 22.038%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 922	| Risk Level: medium	| Buy&Hold_CAGR: 13.476%   	| Portfo_CAGR: 48.003%	| Portfo_Perf: 34.527%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 923	| Risk Level: low	| Buy&Hold_CAGR: 42.74%   	| Portfo_CAGR: 24.907%	| Portfo_Perf: -17.833%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 924	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 925	| Risk Level: medium	| Buy&Hold_CAGR: 6.598%   	| Portfo_CAGR: 47.423%	| Portfo_Perf: 40.825%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 926	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 927	| Risk Level: medium	| Buy&Hold_CAGR: 49.507%   	| Portfo_CAGR: 65.755%	| Portfo_Perf: 16.248%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 928	| Risk Level: high	| Buy&Hold_CAGR: 12.044%   	| Portfo_CAGR: 34.002%	| Portfo_Perf: 21.958%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 929	| Risk Level: medium	| Buy&Hold_CAGR: 7.436%   	| Portfo_CAGR: 30.497%	| Portfo_Perf: 23.061%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 930	| Risk Level: medium	| Buy&Hold_CAGR: 5.338%   	| Portfo_CAGR: 31.208%	| Portfo_Perf: 25.87%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 931	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 932	| Risk Level: medium	| Buy&Hold_CAGR: 47.331%   	| Portfo_CAGR: 40.687%	| Portfo_Perf: -6.645%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 933	| Risk Level: medium	| Buy&Hold_CAGR: 59.137%   	| Portfo_CAGR: 62.142%	| Portfo_Perf: 3.005%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 934	| Risk Level: medium	| Buy&Hold_CAGR: 6.598%   	| Portfo_CAGR: 47.423%	| Portfo_Perf: 40.825%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 935	| Risk Level: medium	| Buy&Hold_CAGR: 8.754%   	| Portfo_CAGR: 39.936%	| Portfo_Perf: 31.182%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 936	| Risk Level: medium	| Buy&Hold_CAGR: 14.216%   	| Portfo_CAGR: 60.075%	| Portfo_Perf: 45.859%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 937	| Risk Level: high	| Buy&Hold_CAGR: 19.992%   	| Portfo_CAGR: 55.414%	| Portfo_Perf: 35.422%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 938	| Risk Level: low	| Buy&Hold_CAGR: 66.222%   	| Portfo_CAGR: 48.32%	| Portfo_Perf: -17.901%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 939	| Risk Level: high	| Buy&Hold_CAGR: 53.138%   	| Portfo_CAGR: 72.835%	| Portfo_Perf: 19.697%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 940	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 941	| Risk Level: low	| Buy&Hold_CAGR: 12.533%   	| Portfo_CAGR: 15.368%	| Portfo_Perf: 2.835%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 942	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 943	| Risk Level: high	| Buy&Hold_CAGR: 53.138%   	| Portfo_CAGR: 72.835%	| Portfo_Perf: 19.697%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 944	| Risk Level: medium	| Buy&Hold_CAGR: 3.591%   	| Portfo_CAGR: 25.629%	| Portfo_Perf: 22.038%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 945	| Risk Level: medium	| Buy&Hold_CAGR: 2.221%   	| Portfo_CAGR: 25.477%	| Portfo_Perf: 23.255%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 946	| Risk Level: medium	| Buy&Hold_CAGR: 0.573%   	| Portfo_CAGR: 26.354%	| Portfo_Perf: 25.781%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 947	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 948	| Risk Level: medium	| Buy&Hold_CAGR: 19.827%   	| Portfo_CAGR: 55.78%	| Portfo_Perf: 35.954%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 949	| Risk Level: medium	| Buy&Hold_CAGR: 32.532%   	| Portfo_CAGR: 65.258%	| Portfo_Perf: 32.726%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 950	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 951	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 952	| Risk Level: low	| Buy&Hold_CAGR: 79.996%   	| Portfo_CAGR: 56.903%	| Portfo_Perf: -23.092%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 953	| Risk Level: low	| Buy&Hold_CAGR: 29.875%   	| Portfo_CAGR: 29.407%	| Portfo_Perf: -0.468%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 954	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 955	| Risk Level: high	| Buy&Hold_CAGR: 53.138%   	| Portfo_CAGR: 72.835%	| Portfo_Perf: 19.697%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 956	| Risk Level: medium	| Buy&Hold_CAGR: 55.042%   	| Portfo_CAGR: 68.799%	| Portfo_Perf: 13.756%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 957	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 958	| Risk Level: medium	| Buy&Hold_CAGR: 16.344%   	| Portfo_CAGR: 69.011%	| Portfo_Perf: 52.666%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 959	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 960	| Risk Level: medium	| Buy&Hold_CAGR: 6.598%   	| Portfo_CAGR: 47.423%	| Portfo_Perf: 40.825%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 961	| Risk Level: high	| Buy&Hold_CAGR: -12.585%   	| Portfo_CAGR: 16.196%	| Portfo_Perf: 28.781%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 962	| Risk Level: medium	| Buy&Hold_CAGR: 6.696%   	| Portfo_CAGR: 18.425%	| Portfo_Perf: 11.729%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 963	| Risk Level: low	| Buy&Hold_CAGR: 66.222%   	| Portfo_CAGR: 48.32%	| Portfo_Perf: -17.901%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 964	| Risk Level: low	| Buy&Hold_CAGR: 47.193%   	| Portfo_CAGR: 25.717%	| Portfo_Perf: -21.476%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 965	| Risk Level: medium	| Buy&Hold_CAGR: 8.066%   	| Portfo_CAGR: 46.608%	| Portfo_Perf: 38.542%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 966	| Risk Level: high	| Buy&Hold_CAGR: 19.992%   	| Portfo_CAGR: 55.414%	| Portfo_Perf: 35.422%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 967	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 968	| Risk Level: medium	| Buy&Hold_CAGR: 10.748%   	| Portfo_CAGR: 32.603%	| Portfo_Perf: 21.855%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 969	| Risk Level: medium	| Buy&Hold_CAGR: 3.591%   	| Portfo_CAGR: 25.629%	| Portfo_Perf: 22.038%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 970	| Risk Level: medium	| Buy&Hold_CAGR: 3.969%   	| Portfo_CAGR: 31.057%	| Portfo_Perf: 27.088%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 971	| Risk Level: high	| Buy&Hold_CAGR: 53.138%   	| Portfo_CAGR: 72.835%	| Portfo_Perf: 19.697%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 972	| Risk Level: medium	| Buy&Hold_CAGR: 6.598%   	| Portfo_CAGR: 47.423%	| Portfo_Perf: 40.825%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 973	| Risk Level: medium	| Buy&Hold_CAGR: 82.806%   	| Portfo_CAGR: 116.084%	| Portfo_Perf: 33.278%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 974	| Risk Level: medium	| Buy&Hold_CAGR: 2.064%   	| Portfo_CAGR: 66.036%	| Portfo_Perf: 63.972%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 975	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 976	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 977	| Risk Level: medium	| Buy&Hold_CAGR: 9.001%   	| Portfo_CAGR: 27.024%	| Portfo_Perf: 18.023%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 978	| Risk Level: medium	| Buy&Hold_CAGR: 37.843%   	| Portfo_CAGR: 67.436%	| Portfo_Perf: 29.593%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 979	| Risk Level: low	| Buy&Hold_CAGR: 47.193%   	| Portfo_CAGR: 25.717%	| Portfo_Perf: -21.476%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 980	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 981	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 982	| Risk Level: medium	| Buy&Hold_CAGR: 6.598%   	| Portfo_CAGR: 47.423%	| Portfo_Perf: 40.825%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 983	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 984	| Risk Level: medium	| Buy&Hold_CAGR: 5.24%   	| Portfo_CAGR: 60.207%	| Portfo_Perf: 54.966%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 985	| Risk Level: low	| Buy&Hold_CAGR: 79.996%   	| Portfo_CAGR: 56.903%	| Portfo_Perf: -23.092%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 986	| Risk Level: high	| Buy&Hold_CAGR: 53.138%   	| Portfo_CAGR: 72.835%	| Portfo_Perf: 19.697%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 987	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 988	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 989	| Risk Level: medium	| Buy&Hold_CAGR: 49.507%   	| Portfo_CAGR: 65.755%	| Portfo_Perf: 16.248%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 990	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 991	| Risk Level: high	| Buy&Hold_CAGR: -9.209%   	| Portfo_CAGR: 28.113%	| Portfo_Perf: 37.322%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 992	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 993	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 994	| Risk Level: medium	| Buy&Hold_CAGR: 14.216%   	| Portfo_CAGR: 60.075%	| Portfo_Perf: 45.859%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 995	| Risk Level: medium	| Buy&Hold_CAGR: 6.598%   	| Portfo_CAGR: 47.423%	| Portfo_Perf: 40.825%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 996	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 997	| Risk Level: medium	| Buy&Hold_CAGR: 3.871%   	| Portfo_CAGR: 32.024%	| Portfo_Perf: 28.153%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 998	| Risk Level: high	| Buy&Hold_CAGR: 53.138%   	| Portfo_CAGR: 72.835%	| Portfo_Perf: 19.697%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 999	| Risk Level: high	| Buy&Hold_CAGR: 14.072%   	| Portfo_CAGR: 42.72%	| Portfo_Perf: 28.649%	 | Stock Count: 3
# Finished Portfolio Backtesting in Year 2021 for User ID = 1000	| Risk Level: medium	| Buy&Hold_CAGR: 6.696%   	| Portfo_CAGR: 18.425%	| Portfo_Perf: 11.729%	 | Stock Count: 3
# Finished all 1000 users in Year 2021...
# Skipped the following users: [231, 285, 520, 568, 660, 710, 822]
# Exported 1000 users summary in Year 2021...
# **** Finsihed all ****

# %% [markdown]
# # Portfolio Backtest Statistics

# %%
num_user = 1000
year_list = [2019, 2020, 2021]
levels = ["Low","Medium","High"]
attrs = ["Buy&Hold_CAGR","Portfolio_CAGR","Portfolio_Performance"]

for year in year_list:
  user_portfo_summary = pd.read_csv(volatility_folder+str(num_user)+"_users_in_"+str(year)+"_portfolio_summary.csv",index_col = None)
  for level in levels:
    msg = "====== "+level+" Level in "+str(year)+" ======"
    print("="*len(msg))
    print(msg)
    print("="*len(msg))
    count = len(user_portfo_summary[user_portfo_summary["Risk_Level"] == level.lower()])
    print("Count:",count,"\t| Percent:",str(round(count/num_user,4)*100)+"%")
    for attr in attrs:
      if attr != attrs[2]:
        print("*** Max ("+attr+"):",user_portfo_summary[user_portfo_summary["Risk_Level"] == level.lower()][attr].apply(lambda num: float(num[:-1])).max())
        print("*** Min ("+attr+"):",user_portfo_summary[user_portfo_summary["Risk_Level"] == level.lower()][attr].apply(lambda num: float(num[:-1])).min())
      print("*** Mean ("+attr+"):",user_portfo_summary[user_portfo_summary["Risk_Level"] == level.lower()][attr].apply(lambda num: float(num[:-1])).mean())
      print("* * * * * * * * * * * *")
# Out:
# ===============================
# ====== Low Level in 2019 ======
# ===============================
# Count: 139 	| Percent: 13.900000000000002%
# *** Max (Buy&Hold_CAGR): 55.905
# *** Min (Buy&Hold_CAGR): -20.036
# *** Mean (Buy&Hold_CAGR): 25.083654676259
# * * * * * * * * * * * *
# *** Max (Portfolio_CAGR): 61.003
# *** Min (Portfolio_CAGR): -20.842
# *** Mean (Portfolio_CAGR): 26.668237410071963
# * * * * * * * * * * * *
# *** Mean (Portfolio_Performance): 1.5845755395683463
# * * * * * * * * * * * *
# ==================================
# ====== Medium Level in 2019 ======
# ==================================
# Count: 706 	| Percent: 70.6%
# *** Max (Buy&Hold_CAGR): 91.813
# *** Min (Buy&Hold_CAGR): -19.014
# *** Mean (Buy&Hold_CAGR): 21.61472804532574
# * * * * * * * * * * * *
# *** Max (Portfolio_CAGR): 124.753
# *** Min (Portfolio_CAGR): 4.597
# *** Mean (Portfolio_CAGR): 38.81873937677064
# * * * * * * * * * * * *
# *** Mean (Portfolio_Performance): 17.20362039660044
# * * * * * * * * * * * *
# ================================
# ====== High Level in 2019 ======
# ================================
# Count: 148 	| Percent: 14.799999999999999%
# *** Max (Buy&Hold_CAGR): 119.499
# *** Min (Buy&Hold_CAGR): 2.287
# *** Mean (Buy&Hold_CAGR): 77.95062837837827
# * * * * * * * * * * * *
# *** Max (Portfolio_CAGR): 80.756
# *** Min (Portfolio_CAGR): 9.712
# *** Mean (Portfolio_CAGR): 56.37861486486497
# * * * * * * * * * * * *
# *** Mean (Portfolio_Performance): -21.572006756756746
# * * * * * * * * * * * *
# ===============================
# ====== Low Level in 2020 ======
# ===============================
# Count: 139 	| Percent: 13.900000000000002%
# *** Max (Buy&Hold_CAGR): 25.747
# *** Min (Buy&Hold_CAGR): -31.801
# *** Mean (Buy&Hold_CAGR): -4.087525179856115
# * * * * * * * * * * * *
# *** Max (Portfolio_CAGR): 58.526
# *** Min (Portfolio_CAGR): -16.05
# *** Mean (Portfolio_CAGR): 19.49244604316547
# * * * * * * * * * * * *
# *** Mean (Portfolio_Performance): 23.58022302158274
# * * * * * * * * * * * *
# ==================================
# ====== Medium Level in 2020 ======
# ==================================
# Count: 706 	| Percent: 70.6%
# *** Max (Buy&Hold_CAGR): 98.763
# *** Min (Buy&Hold_CAGR): -27.313
# *** Mean (Buy&Hold_CAGR): 10.297599150141583
# * * * * * * * * * * * *
# *** Max (Portfolio_CAGR): 137.33
# *** Min (Portfolio_CAGR): -0.444
# *** Mean (Portfolio_CAGR): 63.029879603399365
# * * * * * * * * * * * *
# *** Mean (Portfolio_Performance): 52.732702549575265
# * * * * * * * * * * * *
# ================================
# ====== High Level in 2020 ======
# ================================
# Count: 148 	| Percent: 14.799999999999999%
# *** Max (Buy&Hold_CAGR): 87.4
# *** Min (Buy&Hold_CAGR): 16.695
# *** Mean (Buy&Hold_CAGR): 69.75737162162153
# * * * * * * * * * * * *
# *** Max (Portfolio_CAGR): 130.694
# *** Min (Portfolio_CAGR): 2.408
# *** Mean (Portfolio_CAGR): 89.97451351351363
# * * * * * * * * * * * *
# *** Mean (Portfolio_Performance): 20.217162162162193
# * * * * * * * * * * * *
# ===============================
# ====== Low Level in 2021 ======
# ===============================
# Count: 139 	| Percent: 13.900000000000002%
# *** Max (Buy&Hold_CAGR): 85.653
# *** Min (Buy&Hold_CAGR): -12.178
# *** Mean (Buy&Hold_CAGR): 36.71926618705034
# * * * * * * * * * * * *
# *** Max (Portfolio_CAGR): 58.032
# *** Min (Portfolio_CAGR): 0.202
# *** Mean (Portfolio_CAGR): 28.249517985611533
# * * * * * * * * * * * *
# *** Mean (Portfolio_Performance): -8.469661870503597
# * * * * * * * * * * * *
# ==================================
# ====== Medium Level in 2021 ======
# ==================================
# Count: 706 	| Percent: 70.6%
# *** Max (Buy&Hold_CAGR): 82.806
# *** Min (Buy&Hold_CAGR): -3.884
# *** Mean (Buy&Hold_CAGR): 10.783719546742235
# * * * * * * * * * * * *
# *** Max (Portfolio_CAGR): 116.084
# *** Min (Portfolio_CAGR): 6.555
# *** Mean (Portfolio_CAGR): 42.571974504249525
# * * * * * * * * * * * *
# *** Mean (Portfolio_Performance): 31.788202549574976
# * * * * * * * * * * * *
# ================================
# ====== High Level in 2021 ======
# ================================
# Count: 148 	| Percent: 14.799999999999999%
# *** Max (Buy&Hold_CAGR): 90.546
# *** Min (Buy&Hold_CAGR): -12.585
# *** Mean (Buy&Hold_CAGR): 35.890722972972945
# * * * * * * * * * * * *
# *** Max (Portfolio_CAGR): 114.285
# *** Min (Portfolio_CAGR): 16.196
# *** Mean (Portfolio_CAGR): 63.46731081081077
# * * * * * * * * * * * *
# *** Mean (Portfolio_Performance): 27.576601351351375
# * * * * * * * * * * * *
